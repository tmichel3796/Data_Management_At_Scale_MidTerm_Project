# %% [markdown]
# # COMBINE DATA

# %%
import polars as pl
import polars.selectors as cs
from glob import glob
from toolz import pipe
from functools import reduce
from operator import add, mul
import re
from columns import activity_columns, respondent_columns, roster_columns, who_columns

# %% [markdown]
# ## CONDUCT UNIONS

# %% [markdown]
# - In general the unioning in all file types is done in the same process...
#     - create paths
#     - create a dictionary of original column names
#     - create dictionary to assist with renaming columns
#
#     - create an example of what is considered a "correct table schema"
#     - pull the int columns from the "correct table"
#     - pull the string columns from the "correct table"
#     - combine the int and string columns and map to their typeh
#
#     - conduct renaming of columns and handle casting of data types, while also pulling in each table in one fell swoop.
#     - Find the common columns between tables
#     - remove columns that are not common to each table prior to unioning
#     - conduct the union

# %% [markdown]
# ### UNION ACTIVITY FILES

# %%
# create paths
(act_paths :=
 glob('./data/atusact*.dat') + glob('./data/*/atusact*.dat')
)
# Out:
# ['./data/atusact_2003.dat',
#  './data/atusact_2004.dat',
#  './data/atusact_2005.dat',
#  './data/atusact_2006.dat',
#  './data/atusact_2007.dat',
#  './data/atusact_2008.dat',
#  './data/atusact_2009.dat',
#  './data/atusact_2010.dat',
#  './data/atusact_2011.dat',
#  './data/atusact_2012.dat',
#  './data/atusact_2013.dat',
#  './data/atusact_2014.dat',
#  './data/atusact_2015.dat',
#  './data/atusact_2017.dat',
#  './data/atusact_2018.dat',
#  './data/atusact_2019.dat',
#  './data/atusact_2020.dat',
#  './data/atusact_2021.dat',
#  './data/atusact_2022.dat',
#  './data/atusact_2023.dat',
#  './data/atusact_2024.dat',
#  './data/atusact_2016/atusact_2016.dat']

# %%
#create a dictionary of original column names
(original_columns :=
 {p:{col: col
     for col in 
     pl.read_csv(p).columns
    }
  for p in act_paths
 }
)
# Out:
# {'./data/atusact_2003.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUACTDUR': 'TUACTDUR',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TEWHERE': 'TEWHERE',
#   'TXWHERE': 'TXWHERE',
#   'TR_03CC57': 'TR_03CC57',
#   'TUCUMDUR24': 'TUCUMDUR24'},
#  './data/atusact_2004.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUACTDUR': 'TUACTDUR',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCC5': 'TUCC5',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TEWHERE': 'TEWHERE',
#   'TXWHERE': 'TXWHERE',
#   'TUCC5B': 'TUCC5B',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN'},
#  './data/atusact_2005.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2006.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2007.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2008.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2009.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2010.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TRWBELIG': 'TRWBELIG',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2011.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2012.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TRWBELIG': 'TRWBELIG',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2013.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TRWBELIG': 'TRWBELIG',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2014.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2015.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2017.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2018.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2019.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2020.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2021.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE',
#   'TRWBELIG': 'TRWBELIG'},
#  './data/atusact_2022.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2023.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2024.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2016/atusact_2016.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'}}

# %%
#create dictionary to assist with renaming columns
(fixed_columns :=
 {**original_columns, 
  **{
      path:{col:col.upper() for col in original_columns.get(path,[])}
     for path in act_paths
     },  
}
)
# Out:
# {'./data/atusact_2003.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUACTDUR': 'TUACTDUR',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TEWHERE': 'TEWHERE',
#   'TXWHERE': 'TXWHERE',
#   'TR_03CC57': 'TR_03CC57',
#   'TUCUMDUR24': 'TUCUMDUR24'},
#  './data/atusact_2004.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUACTDUR': 'TUACTDUR',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCC5': 'TUCC5',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TEWHERE': 'TEWHERE',
#   'TXWHERE': 'TXWHERE',
#   'TUCC5B': 'TUCC5B',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN'},
#  './data/atusact_2005.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2006.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2007.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2008.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2009.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2010.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TRWBELIG': 'TRWBELIG',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2011.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2012.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TRWBELIG': 'TRWBELIG',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2013.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TRWBELIG': 'TRWBELIG',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2014.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2015.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2017.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2018.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2019.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2020.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2021.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE',
#   'TRWBELIG': 'TRWBELIG'},
#  './data/atusact_2022.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2023.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2024.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'},
#  './data/atusact_2016/atusact_2016.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TEWHERE': 'TEWHERE',
#   'TRTCCTOT_LN': 'TRTCCTOT_LN',
#   'TRTCC_LN': 'TRTCC_LN',
#   'TRTCOC_LN': 'TRTCOC_LN',
#   'TRTEC_LN': 'TRTEC_LN',
#   'TRTHH_LN': 'TRTHH_LN',
#   'TRTNOHH_LN': 'TRTNOHH_LN',
#   'TRTOHH_LN': 'TRTOHH_LN',
#   'TRTONHH_LN': 'TRTONHH_LN',
#   'TRTO_LN': 'TRTO_LN',
#   'TUACTDUR': 'TUACTDUR',
#   'TUACTDUR24': 'TUACTDUR24',
#   'TUCC5': 'TUCC5',
#   'TUCC5B': 'TUCC5B',
#   'TUCC7': 'TUCC7',
#   'TUCC8': 'TUCC8',
#   'TUCUMDUR': 'TUCUMDUR',
#   'TUCUMDUR24': 'TUCUMDUR24',
#   'TUDURSTOP': 'TUDURSTOP',
#   'TUEC24': 'TUEC24',
#   'TUSTARTTIM': 'TUSTARTTIM',
#   'TUSTOPTIME': 'TUSTOPTIME',
#   'TUTIER1CODE': 'TUTIER1CODE',
#   'TUTIER2CODE': 'TUTIER2CODE',
#   'TUTIER3CODE': 'TUTIER3CODE',
#   'TRCODE': 'TRCODE',
#   'TRTIER2': 'TRTIER2',
#   'TXWHERE': 'TXWHERE'}}

# %%
# create an example of what is considered a "correct table schema"
(example_correct_table := pl.read_csv(act_paths[0]).head()
)
# Out:
# shape: (5, 17)
# ┌─────────────┬────────────┬──────────┬───────────┬───┬─────────┬─────────┬───────────┬────────────┐
# │ TUCASEID    ┆ TUACTDUR24 ┆ TRTCC_LN ┆ TRTCOC_LN ┆ … ┆ TEWHERE ┆ TXWHERE ┆ TR_03CC57 ┆ TUCUMDUR24 │
# │ ---         ┆ ---        ┆ ---      ┆ ---       ┆   ┆ ---     ┆ ---     ┆ ---       ┆ ---        │
# │ i64         ┆ i64        ┆ i64      ┆ i64       ┆   ┆ i64     ┆ i64     ┆ i64       ┆ i64        │
# ╞═════════════╪════════════╪══════════╪═══════════╪═══╪═════════╪═════════╪═══════════╪════════════╡
# │ 20030100013 ┆ 60         ┆ -1       ┆ -1        ┆ … ┆ 9       ┆ 0       ┆ -1        ┆ 60         │
# │ 280         ┆            ┆          ┆           ┆   ┆         ┆         ┆           ┆            │
# │ 20030100013 ┆ 30         ┆ -1       ┆ -1        ┆ … ┆ -1      ┆ 0       ┆ -1        ┆ 90         │
# │ 280         ┆            ┆          ┆           ┆   ┆         ┆         ┆           ┆            │
# │ 20030100013 ┆ 600        ┆ -1       ┆ -1        ┆ … ┆ -1      ┆ 0       ┆ -1        ┆ 690        │
# │ 280         ┆            ┆          ┆           ┆   ┆         ┆         ┆           ┆            │
# │ 20030100013 ┆ 150        ┆ -1       ┆ -1        ┆ … ┆ 1       ┆ 0       ┆ -1        ┆ 840        │
# │ 280         ┆            ┆          ┆           ┆   ┆         ┆         ┆           ┆            │
# │ 20030100013 ┆ 5          ┆ -1       ┆ -1        ┆ … ┆ 1       ┆ 0       ┆ -1        ┆ 845        │
# │ 280         ┆            ┆          ┆           ┆   ┆         ┆         ┆           ┆            │
# └─────────────┴────────────┴──────────┴───────────┴───┴─────────┴─────────┴───────────┴────────────┘

# %%
# pull the int columns from the "correct table"
(int_columns := example_correct_table.select(cs.integer()).columns
)
# Out:
# ['TUCASEID',
#  'TUACTDUR24',
#  'TRTCC_LN',
#  'TRTCOC_LN',
#  'TUACTIVITY_N',
#  'TUTIER1CODE',
#  'TUTIER2CODE',
#  'TUTIER3CODE',
#  'TUACTDUR',
#  'TUCC8',
#  'TUCUMDUR',
#  'TEWHERE',
#  'TXWHERE',
#  'TR_03CC57',
#  'TUCUMDUR24']

# %%
# pull the string columns from the "correct table"
(str_columns := example_correct_table.select(cs.string()).columns
)
# Out:
# ['TUSTARTTIM', 'TUSTOPTIME']

# %%
#combine the int and string columns and map to their type
(col_and_types := {c: pl.String() for c in str_columns
} |    # Merge operator
{c:pl.Int64() for c in int_columns
 if c in activity_columns #pl.read_csv(p,n_rows=100).columns  # only cast columns that we need
        
}
 )
# Out:
# {'TUSTARTTIM': String,
#  'TUSTOPTIME': String,
#  'TUCASEID': Int64,
#  'TUACTDUR24': Int64,
#  'TUACTIVITY_N': Int64,
#  'TUTIER1CODE': Int64,
#  'TUTIER2CODE': Int64,
#  'TUTIER3CODE': Int64}

# %%
# conduct renaming of columns and handle casting of data types. IT also pulls in each table.
(dfs := [pl.read_csv(p)
       .rename(col_rename)
       .select([
            pl.col(c).cast(t)
            for c, t in col_and_types.items()
            if c in activity_columns  # only cast columns that exist
        ]) for p, col_rename in fixed_columns.items()]
)
# Out:
# [shape: (412_611, 6)
#  ┌────────────────┬────────────┬──────────────┬─────────────┬─────────────┬─────────────┐
#  │ TUCASEID       ┆ TUACTDUR24 ┆ TUACTIVITY_N ┆ TUTIER1CODE ┆ TUTIER2CODE ┆ TUTIER3CODE │
#  │ ---            ┆ ---        ┆ ---          ┆ ---         ┆ ---         ┆ ---         │
#  │ i64            ┆ i64        ┆ i64          ┆ i64         ┆ i64         ┆ i64         │
#  ╞════════════════╪════════════╪══════════════╪═════════════╪═════════════╪═════════════╡
#  │ 20030100013280 ┆ 60         ┆ 1            ┆ 13          ┆ 1           ┆ 24          │
#  │ 20030100013280 ┆ 30         ┆ 2            ┆ 1           ┆ 2           ┆ 1           │
#  │ 20030100013280 ┆ 600        ┆ 3            ┆ 1           ┆ 1           ┆ 1           │
#  │ 20030100013280 ┆ 150        ┆ 4            ┆ 12          ┆ 3           ┆ 3           │
#  │ 20030100013280 ┆ 5          ┆ 5            ┆ 11          ┆ 1           ┆ 1           │
#  │ …              ┆ …          ┆ …            ┆ …           ┆ …           ┆ …           │
#  │ 20031212033642 ┆ 50         ┆ 17           ┆ 2           ┆ 9           ┆ 1           │
#  │ 20031212033642 ┆ 90         ┆ 18           ┆ 12          ┆ 3           ┆ 3           │
#  │ 20031212033642 ┆ 10         ┆ 19           ┆ 1           ┆ 2           ┆ 1           │
#  │ 20031212033642 ┆ 80         ┆ 20           ┆ 12          ┆ 3           ┆ 3           │
#  │ 20031212033642 ┆ 240        ┆ 21           ┆ 1           ┆ 1           ┆ 1           │
#  └────────────────┴────────────┴──────────────┴─────────────┴─────────────┴─────────────┘,
#  shape: (279_042, 6)
#  ┌────────────────┬────────────┬──────────────┬─────────────┬─────────────┬─────────────┐
#  │ TUCASEID       ┆ TUACTDUR24 ┆ TUACTIVITY_N ┆ TUTIER1CODE ┆ TUTIER2CODE ┆ TUTIER3CODE │
#  │ ---            ┆ ---        ┆ ---          ┆ ---         ┆ ---         ┆ ---         │
#  │ i64            ┆ i64        ┆ i64          ┆ i64         ┆ i64         ┆ i64         │
#  ╞════════════════╪════════════╪══════════════╪═════════════╪═════════════╪═════════════╡
#  │ 20040101040003 ┆ 390        ┆ 1            ┆ 1           ┆ 1           ┆ 1           │
#  │ 20040101040003 ┆ 90         ┆ 2            ┆ 1           ┆ 2           ┆ 1           │
#  │ 
┆ 11          ┆ 1           ┆ 1           │
#  │ 20160101160045 ┆ 25         ┆ 4            ┆ 2           ┆ 2           ┆ 3           │
#  │ 20160101160045 ┆ 30         ┆ 5            ┆ 2           ┆ 1           ┆ 1           │
#  │ …              ┆ …          ┆ …            ┆ …           ┆ …           ┆ …           │
#  │ 20161212162509 ┆ 120        ┆ 7            ┆ 12          ┆ 1           ┆ 1           │
#  │ 20161212162509 ┆ 20         ┆ 8            ┆ 11          ┆ 1           ┆ 1           │
#  │ 20161212162509 ┆ 130        ┆ 9            ┆ 12          ┆ 3           ┆ 7           │
#  │ 20161212162509 ┆ 60         ┆ 10           ┆ 12          ┆ 3           ┆ 3           │
#  │ 20161212162509 ┆ 420        ┆ 11           ┆ 1           ┆ 1           ┆ 1           │
#  └────────────────┴────────────┴──────────────┴─────────────┴─────────────┴─────────────┘]

# %%
# Find the common columns between tables
(common_cols := set(dfs[0].columns))
# Out:
# {'TUACTDUR24',
#  'TUACTIVITY_N',
#  'TUCASEID',
#  'TUTIER1CODE',
#  'TUTIER2CODE',
#  'TUTIER3CODE'}

# %%
# remove columns that are not common to each table prior to unioning

for df in dfs[1:]:
    common_cols &= set(df.columns)

# %%
# conduct the union, and filter to smallest size.
(act_combined := pl.concat([df.select(sorted(common_cols)) for df in dfs]).filter(pl.col('TUTIER1CODE') == 2))
# Out:
# shape: (727_667, 6)
# ┌────────────┬──────────────┬────────────────┬─────────────┬─────────────┬─────────────┐
# │ TUACTDUR24 ┆ TUACTIVITY_N ┆ TUCASEID       ┆ TUTIER1CODE ┆ TUTIER2CODE ┆ TUTIER3CODE │
# │ ---        ┆ ---          ┆ ---            ┆ ---         ┆ ---         ┆ ---         │
# │ i64        ┆ i64          ┆ i64            ┆ i64         ┆ i64         ┆ i64         │
# ╞════════════╪══════════════╪════════════════╪═════════════╪═════════════╪═════════════╡
# │ 15         ┆ 7            ┆ 20030100013352 ┆ 2           ┆ 1           ┆ 4           │
# │ 180        ┆ 10           ┆ 20030100013352 ┆ 2           ┆ 2           ┆ 1           │
# │ 60         ┆ 14           ┆ 20030100013352 ┆ 2           ┆ 2           ┆ 3           │
# │ 20         ┆ 2            ┆ 20030100013848 ┆ 2           ┆ 2           ┆ 1           │
# │ 15         ┆ 4            ┆ 20030100013848 ┆ 2           ┆ 2           ┆ 3           │
# │ …          ┆ …            ┆ …              ┆ …           ┆ …           ┆ …           │
# │ 40         ┆ 14           ┆ 20161212162426 ┆ 2           ┆ 1           ┆ 1           │
# │ 10         ┆ 22           ┆ 20161212162426 ┆ 2           ┆ 1           ┆ 4           │
# │ 3          ┆ 23           ┆ 20161212162426 ┆ 2           ┆ 2           ┆ 1           │
# │ 5          ┆ 5            ┆ 20161212162456 ┆ 2           ┆ 2           ┆ 1           │
# │ 10         ┆ 7            ┆ 20161212162456 ┆ 2           ┆ 2           ┆ 1           │
# └────────────┴──────────────┴────────────────┴─────────────┴─────────────┴─────────────┘

# %%
# creates a filter that will be used to filter when unioning the who  files
(activity_filter := act_combined.select("TUACTIVITY_N","TUCASEID").unique())
# Out:
# shape: (727_667, 2)
# ┌──────────────┬────────────────┐
# │ TUACTIVITY_N ┆ TUCASEID       │
# │ ---          ┆ ---            │
# │ i64          ┆ i64            │
# ╞══════════════╪════════════════╡
# │ 7            ┆ 20161008162032 │
# │ 4            ┆ 20191009191790 │
# │ 12           ┆ 20051211050972 │
# │ 2            ┆ 20031211031774 │
# │ 21           ┆ 20100604101555 │
# │ …            ┆ …              │
# │ 4            ┆ 20140605142419 │
# │ 5            ┆ 20150302151000 │
# │ 15           ┆ 20141009140600 │
# │ 23           ┆ 20190403191922 │
# │ 18           ┆ 20040806040809 │
# └──────────────┴────────────────┘

# %% [markdown]
# ### UNION WHO FILES

# %%
# create paths
(who_paths :=
 glob('./data/atuswho*.dat') + glob('./data/*/atuswho*.dat')
)
# Out:
# ['./data/atuswho_2004.dat',
#  './data/atuswho_2005.dat',
#  './data/atuswho_2006.dat',
#  './data/atuswho_2007.dat',
#  './data/atuswho_2008.dat',
#  './data/atuswho_2009.dat',
#  './data/atuswho_2010.dat',
#  './data/atuswho_2011.dat',
#  './data/atuswho_2012.dat',
#  './data/atuswho_2013.dat',
#  './data/atuswho_2014.dat',
#  './data/atuswho_2015.dat',
#  './data/atuswho_2017.dat',
#  './data/atuswho_2018.dat',
#  './data/atuswho_2019.dat',
#  './data/atuswho_2020.dat',
#  './data/atuswho_2021.dat',
#  './data/atuswho_2022.dat',
#  './data/atuswho_2023.dat',
#  './data/atuswho_2024.dat',
#  './data/atuswho_2003/atuswho_2003.dat',
#  './data/atuswho_2016/atuswho_2016.dat']

# %%
#create a dictionary of original column names
(original_columns :=
 {p:{col: col
     for col in 
     pl.read_csv(p).columns
    }
  for p in who_paths
 }
)
# Out:
# {'./data/atuswho_2004.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TUWHO_CODE': 'TUWHO_CODE',
#   'TULINENO': 'TULINENO',
#   'TRWHONA': 'TRWHONA'},
#  './data/atuswho_2005.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2006.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2007.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2008.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2009.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2010.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2011.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2012.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2013.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2014.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2015.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2017.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2018.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2019.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2020.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2021.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2022.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2023.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2024.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2003/atuswho_2003.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TUWHO_CODE': 'TUWHO_CODE',
#   'TULINENO': 'TULINENO',
#   'TRWHONA': 'TRWHONA'},
#  './data/atuswho_2016/atuswho_2016.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'}}

# %%
#create dictionary to assist with renaming columns
(fixed_columns :=
 {**original_columns, 
  **{
      path:{col:col.upper() for col in original_columns.get(path,[])}
     for path in who_paths
     },  
}
)
# Out:
# {'./data/atuswho_2004.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TUWHO_CODE': 'TUWHO_CODE',
#   'TULINENO': 'TULINENO',
#   'TRWHONA': 'TRWHONA'},
#  './data/atuswho_2005.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2006.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2007.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2008.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2009.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2010.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2011.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2012.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2013.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2014.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2015.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2017.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2018.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2019.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2020.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2021.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2022.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2023.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2024.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'},
#  './data/atuswho_2003/atuswho_2003.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TUWHO_CODE': 'TUWHO_CODE',
#   'TULINENO': 'TULINENO',
#   'TRWHONA': 'TRWHONA'},
#  './data/atuswho_2016/atuswho_2016.dat': {'TUCASEID': 'TUCASEID',
#   'TUACTIVITY_N': 'TUACTIVITY_N',
#   'TRWHONA': 'TRWHONA',
#   'TULINENO': 'TULINENO',
#   'TUWHO_CODE': 'TUWHO_CODE'}}

# %%
# create an example of what is considered a "correct table schema"
(example_correct_table := pl.read_csv(who_paths[0]).head()
)
# Out:
# shape: (5, 5)
# ┌────────────────┬──────────────┬────────────┬──────────┬─────────┐
# │ TUCASEID       ┆ TUACTIVITY_N ┆ TUWHO_CODE ┆ TULINENO ┆ TRWHONA │
# │ ---            ┆ ---          ┆ ---        ┆ ---      ┆ ---     │
# │ i64            ┆ i64          ┆ i64        ┆ i64      ┆ i64     │
# ╞════════════════╪══════════════╪════════════╪══════════╪═════════╡
# │ 20040101040003 ┆ 1            ┆ -1         ┆ -1       ┆ 1       │
# │ 20040101040003 ┆ 2            ┆ -1         ┆ -1       ┆ 1       │
# │ 20040101040003 ┆ 3            ┆ 18         ┆ 1        ┆ 0       │
# │ 20040101040003 ┆ 4            ┆ 18         ┆ 1        ┆ 0       │
# │ 20040101040003 ┆ 5            ┆ 18         ┆ 1        ┆ 0       │
# └────────────────┴──────────────┴────────────┴──────────┴─────────┘

# %%
# pull the int columns from the "correct table"
(int_columns := example_correct_table.select(cs.integer()).columns
)
# Out:
# ['TUCASEID', 'TUACTIVITY_N', 'TUWHO_CODE', 'TULINENO', 'TRWHONA']

# %%
# pull the string columns from the "correct table"
(str_columns := example_correct_table.select(cs.string()).columns
)
# Out:
# []

# %%
#combine the int and string columns and map to their type
(col_and_types := {c: pl.String() for c in str_columns
} |    # Merge operator
{c:pl.Int64() for c in int_columns
 if c in who_columns   # only cast columns that we need
        
}
 )
# Out:
# {'TUCASEID': Int64, 'TUACTIVITY_N': Int64, 'TULINENO': Int64}

# %%
# conduct renaming of columns and handle casting of data types.IT also pulls in each table.
(dfs := [pl.read_csv(p)
       .rename(col_rename)
       .select([
            pl.col(c).cast(t)
            for c, t in col_and_types.items()
            if c in who_columns  # only cast columns that exist
        ]) for p, col_rename in fixed_columns.items()])
# Out:
# [shape: (354_485, 3)
#  ┌────────────────┬──────────────┬──────────┐
#  │ TUCASEID       ┆ TUACTIVITY_N ┆ TULINENO │
#  │ ---            ┆ ---          ┆ ---      │
#  │ i64            ┆ i64          ┆ i64      │
#  ╞════════════════╪══════════════╪══════════╡
#  │ 20040101040003 ┆ 1            ┆ -1       │
#  │ 20040101040003 ┆ 2            ┆ -1       │
#  │ 20040101040003 ┆ 3            ┆ 1        │
#  │ 20040101040003 ┆ 4            ┆ 1        │
#  │ 20040101040003 ┆ 5            ┆ 1        │
#  │ …              ┆ …            ┆ …        │
#  │ 20041212042565 ┆ 12           ┆ 3        │
#  │ 20041212042565 ┆ 13           ┆ 2        │
#  │ 20041212042565 ┆ 13           ┆ -1       │
#  │ 20041212042565 ┆ 14           ┆ 2        │
#  │ 20041212042565 ┆ 15           ┆ -1       │
#  └────────────────┴──────────────┴──────────┘,
#  shape: (342_235, 3)
#  ┌────────────────┬──────────────┬──────────┐
#  │ TUCASEID       ┆ TUACTIVITY_N ┆ TULINENO │
#  │ ---            ┆ ---          ┆ ---      │
#  │ i64            ┆ i64          ┆ i64      │
#  ╞════════════════╪══════════════╪══════════╡
#  │ 20050101050006 ┆ 1            ┆ -1       │
#  │ 20050101050006 ┆ 2            ┆ 1        │
#  │ 20050101050006 ┆ 3            ┆ 1        │
#  │ 20050101050006 ┆ 4            ┆ 1        │
#  │ 20050101050006 ┆ 5            ┆ 1        │
#  │ …              ┆ …            ┆ …        │
#  │ 20051212052534 ┆ 11           ┆ 3        │
#  │ 20051212052534 ┆ 12           ┆ 2        │
#  │ 20051212052534 ┆ 12           ┆ 4        │
#  │ 20051212052534 ┆ 12           ┆ 3        │
#  │ 20051212052534 ┆ 13           ┆ -1       │
#  └────────────────┴──────────────┴──────────┘,
#  shape: (343_514, 3)
#  ┌────────────────┬──────────────┬──────────┐
#  │ TUCASEID       ┆ TUACTIVITY_N ┆ TULINENO │
#  │ ---            ┆ ---          ┆ ---      │
#  │ i64            ┆ i64          ┆ i64      │
#  ╞════════════════╪══════════════╪══════════╡
#  │ 
┆ -1       │
#  └────────────────┴──────────────┴──────────┘,
#  shape: (229_798, 3)
#  ┌────────────────┬──────────────┬──────────┐
#  │ TUCASEID       ┆ TUACTIVITY_N ┆ TULINENO │
#  │ ---            ┆ ---          ┆ ---      │
#  │ i64            ┆ i64          ┆ i64      │
#  ╞════════════════╪══════════════╪══════════╡
#  │ 20190101190022 ┆ 1            ┆ -1       │
#  │ 20190101190022 ┆ 2            ┆ -1       │
#  │ 20190101190022 ┆ 3            ┆ 1        │
#  │ 20190101190022 ┆ 4            ┆ 1        │
#  │ 20190101190022 ┆ 5            ┆ 1        │
#  │ …              ┆ …            ┆ …        │
#  │ 20191212192270 ┆ 12           ┆ 4        │
#  │ 20191212192270 ┆ 13           ┆ 2        │
#  │ 20191212192270 ┆ 13           ┆ 3        │
#  │ 20191212192270 ┆ 13           ┆ 4        │
#  │ 20191212192270 ┆ 14           ┆ -1       │
#  └────────────────┴──────────────┴──────────┘,
#  shape: (190_341, 3)
#  ┌────────────────┬──────────────┬──────────┐
#  │ TUCASEID       ┆ TUACTIVITY_N ┆ TULINENO │
#  │ ---            ┆ ---          ┆ ---      │
#  │ i64            ┆ i64          ┆ i64      │
#  ╞════════════════╪══════════════╪══════════╡
#  │ 20200101200103 ┆ 1            ┆ -1       │
#  │ 20200101200103 ┆ 2            ┆ -1       │
#  │ 20200101200103 ┆ 3            ┆ 1        │
#  │ 20200101200103 ┆ 4            ┆ 1        │
#  │ 20200101200103 ┆ 5            ┆ -1       │
#  │ …              ┆ …            ┆ …        │
#  │ 20201212202329 ┆ 10           ┆ 1        │
#  │ 20201212202329 ┆ 11           ┆ -1       │
#  │ 20201212202329 ┆ 12           ┆ 1        │
#  │ 20201212202329 ┆ 13           ┆ 1        │
#  │ 20201212202329 ┆ 14           ┆ 1        │
#  └────────────────┴──────────────┴──────────┘,
#  shape: (201_874, 3)
#  ┌────────────────┬──────────────┬──────────┐
#  │ TUCASEID       ┆ TUACTIVITY_N ┆ TULINENO │
#  │ ---            ┆ ---          ┆ ---      │
#  │ i64            ┆ i64          ┆ i64      │
#  ╞════════════════╪══════════════╪══════════╡
#  │ 20210101210037 ┆ 1            ┆ -1       │
#  │ 20210101210037 ┆ 2            ┆ 1        │
#  │ 20210101210037 ┆ 3            ┆ 1        │
#  │ 20210101210037 ┆ 4            ┆ -1       │
#  │ 20210101210037 ┆ 5            ┆ 1        │
#  │ …              ┆ …            ┆ …        │
#  │ 20211212212591 ┆ 9            ┆ -1       │
#  │ 20211212212591 ┆ 10           ┆ -1       │
#  │ 20211212212591 ┆ 11           ┆ 1        │
#  │ 20211212212591 ┆ 12           ┆ 1        │
#  │ 20211212212591 ┆ 13           ┆ -1       │
#  └────────────────┴──────────────┴──────────┘,
#  shape: (176_200, 3)
#  ┌────────────────┬──────────────┬──────────┐
#  │ TUCASEID       ┆ TUACTIVITY_N ┆ TULINENO │
#  │ ---            ┆ ---          ┆ ---      │
#  │ i64            ┆ i64          ┆ i64      │
#  ╞════════════════╪══════════════╪══════════╡
#  │ 20220101220017 ┆ 1            ┆ -1       │
#  │ 20220101220017 ┆ 2            ┆ 2        │
#  │ 20220101220017 ┆ 2            ┆ 3        │
#  │ 20220101220017 ┆ 2            ┆ 4        │
#  │ 20220101220017 ┆ 2            ┆ 5        │
#  │ …              ┆ …            ┆ …        │
#  │ 20221212222501 ┆ 22           ┆ 1        │
#  │ 20221212222501 ┆ 23           ┆ 1        │
#  │ 20221212222501 ┆ 24           ┆ 1        │
#  │ 20221212222501 ┆ 25           ┆ 1        │
#  │ 20221212222501 ┆ 26           ┆ -1       │
#  └────────────────┴──────────────┴──────────┘,
#  shape: (182_600, 3)
#  ┌────────────────┬──────────────┬──────────┐
#  │ TUCASEID       ┆ TUACTIVITY_N ┆ TULINENO │
#  │ ---            ┆ ---          ┆ ---      │
#  │ i64            ┆ i64          ┆ i64      │
#  ╞════════════════╪══════════════╪══════════╡
#  │ 20230101230035 ┆ 1            ┆ -1       │
#  │ 20230101230035 ┆ 2            ┆ 1        │
#  │ 20230101230035 ┆ 3            ┆ -1       │
#  │ 20230101230035 ┆ 4            ┆ 1        │
#  │ 20230101230035 ┆ 5            ┆ 1        │
#  │ …              ┆ …            ┆ …        │
#  │ 20231212232280 ┆ 1            ┆ -1       │
#  │ 20231212232280 ┆ 2            ┆ 2        │
#  │ 20231212232280 ┆ 3            ┆ 2        │
#  │ 20231212232280 ┆ 4            ┆ 2        │
#  │ 20231212232280 ┆ 5            ┆ -1       │
#  └────────────────┴──────────────┴──────────┘,
#  shape: (167_653, 3)
#  ┌────────────────┬──────────────┬──────────┐
#  │ TUCASEID       ┆ TUACTIVITY_N ┆ TULINENO │
#  │ ---            ┆ ---          ┆ ---      │
#  │ i64            ┆ i64          ┆ i64      │
#  ╞════════════════╪══════════════╪══════════╡
#  │ 20240101240005 ┆ 1            ┆ -1       │
#  │ 20240101240005 ┆ 2            ┆ 2        │
#  │ 20240101240005 ┆ 3            ┆ 2        │
#  │ 20240101240005 ┆ 3            ┆ 3        │
#  │ 20240101240005 ┆ 3            ┆ 4        │
#  │ …              ┆ …            ┆ …        │
#  │ 20241212242303 ┆ 8            ┆ 2        │
#  │ 20241212242303 ┆ 9            ┆ 2        │
#  │ 20241212242303 ┆ 10           ┆ 2        │
#  │ 20241212242303 ┆ 11           ┆ 2        │
#  │ 20241212242303 ┆ 12           ┆ -1       │
#  └────────────────┴──────────────┴──────────┘,
#  shape: (526_548, 3)
#  ┌────────────────┬──────────────┬──────────┐
#  │ TUCASEID       ┆ TUACTIVITY_N ┆ TULINENO │
#  │ ---            ┆ ---          ┆ ---      │
#  │ i64            ┆ i64          ┆ i64      │
#  ╞════════════════╪══════════════╪══════════╡
#  │ 20030100013280 ┆ 1            ┆ 1        │
#  │ 20030100013280 ┆ 2            ┆ -1       │
#  │ 20030100013280 ┆ 3            ┆ -1       │
#  │ 20030100013280 ┆ 4            ┆ 1        │
#  │ 20030100013280 ┆ 5            ┆ 2        │
#  │ …              ┆ …            ┆ …        │
#  │ 20031212033642 ┆ 17           ┆ 2        │
#  │ 20031212033642 ┆ 18           ┆ 2        │
#  │ 20031212033642 ┆ 19           ┆ -1       │
#  │ 20031212033642 ┆ 20           ┆ 2        │
#  │ 20031212033642 ┆ 21           ┆ -1       │
#  └────────────────┴──────────────┴──────────┘,
#  shape: (263_523, 3)
#  ┌────────────────┬──────────────┬──────────┐
#  │ TUCASEID       ┆ TUACTIVITY_N ┆ TULINENO │
#  │ ---            ┆ ---          ┆ ---      │
#  │ i64            ┆ i64          ┆ i64      │
#  ╞════════════════╪══════════════╪══════════╡
#  │ 20160101160045 ┆ 1            ┆ -1       │
#  │ 20160101160045 ┆ 2            ┆ 1        │
#  │ 20160101160045 ┆ 3            ┆ 2        │
#  │ 20160101160045 ┆ 3            ┆ 3        │
#  │ 20160101160045 ┆ 4            ┆ 1        │
#  │ …              ┆ …            ┆ …        │
#  │ 20161212162509 ┆ 9            ┆ 2        │
#  │ 20161212162509 ┆ 9            ┆ 4        │
#  │ 20161212162509 ┆ 10           ┆ 2        │
#  │ 20161212162509 ┆ 10           ┆ 4        │
#  │ 20161212162509 ┆ 11           ┆ -1       │
#  └────────────────┴──────────────┴──────────┘]

# %%
# Find the common columns between tables
(common_cols := set(dfs[0].columns))
# Out:
# {'TUACTIVITY_N', 'TUCASEID', 'TULINENO'}

# %%
# remove columns that are not common to each table prior to unioning
for df in dfs[1:]: 
    common_cols &= set(df.columns)

# %%
# conduct the union IT'S  NOT IN THE FINAL FORM YET
(who_combiner := pl.concat([df.select(sorted(common_cols)) for df in dfs])
 )
# Out:
# shape: (6_221_596, 3)
# ┌──────────────┬────────────────┬──────────┐
# │ TUACTIVITY_N ┆ TUCASEID       ┆ TULINENO │
# │ ---          ┆ ---            ┆ ---      │
# │ i64          ┆ i64            ┆ i64      │
# ╞══════════════╪════════════════╪══════════╡
# │ 1            ┆ 20040101040003 ┆ -1       │
# │ 2            ┆ 20040101040003 ┆ -1       │
# │ 3            ┆ 20040101040003 ┆ 1        │
# │ 4            ┆ 20040101040003 ┆ 1        │
# │ 5            ┆ 20040101040003 ┆ 1        │
# │ …            ┆ …              ┆ …        │
# │ 9            ┆ 20161212162509 ┆ 2        │
# │ 9            ┆ 20161212162509 ┆ 4        │
# │ 10           ┆ 20161212162509 ┆ 2        │
# │ 10           ┆ 20161212162509 ┆ 4        │
# │ 11           ┆ 20161212162509 ┆ -1       │
# └──────────────┴────────────────┴──────────┘

# %%
# filtering out any entries that will not be used in the activity file 
#NOW IT'S IN THE FINAL FORM
(who_combined := who_combiner
    .join(activity_filter
           , on = ["TUCASEID", "TUACTIVITY_N"]
          , how = 'inner')
)
# note the extra filtration is why our numbers don't match up. I wanted to embrace your best practices of shrinking the dataset as small as possible.
# Out:
# shape: (867_714, 3)
# ┌──────────────┬────────────────┬──────────┐
# │ TUACTIVITY_N ┆ TUCASEID       ┆ TULINENO │
# │ ---          ┆ ---            ┆ ---      │
# │ i64          ┆ i64            ┆ i64      │
# ╞══════════════╪════════════════╪══════════╡
# │ 6            ┆ 20040101040003 ┆ 1        │
# │ 4            ┆ 20040101040060 ┆ 3        │
# │ 6            ┆ 20040101040060 ┆ 1        │
# │ 11           ┆ 20040101040060 ┆ 3        │
# │ 11           ┆ 20040101040060 ┆ -1       │
# │ …            ┆ …              ┆ …        │
# │ 22           ┆ 20161212162426 ┆ 1        │
# │ 23           ┆ 20161212162426 ┆ 2        │
# │ 23           ┆ 20161212162426 ┆ 3        │
# │ 5            ┆ 20161212162456 ┆ 1        │
# │ 7            ┆ 20161212162456 ┆ 1        │
# └──────────────┴────────────────┴──────────┘

# %% [markdown]
# ### UNION & FILTER ROSTER FILES
# Roster file filtered for only ages 25-64 and households with a married couple.

# %%
# create paths
(rost_paths :=
 glob('./data/atusrost*.dat') + glob('./data/*/atusrost*.dat')
)
# Out:
# ['./data/atusrost_2003.dat',
#  './data/atusrost_2004.dat',
#  './data/atusrost_2005.dat',
#  './data/atusrost_2006.dat',
#  './data/atusrost_2007.dat',
#  './data/atusrost_2008.dat',
#  './data/atusrost_2009.dat',
#  './data/atusrost_2010.dat',
#  './data/atusrost_2011.dat',
#  './data/atusrost_2012.dat',
#  './data/atusrost_2013.dat',
#  './data/atusrost_2014.dat',
#  './data/atusrost_2015.dat',
#  './data/atusrost_2017.dat',
#  './data/atusrost_2018.dat',
#  './data/atusrost_2019.dat',
#  './data/atusrost_2020.dat',
#  './data/atusrost_2021.dat',
#  './data/atusrost_2022.dat',
#  './data/atusrost_2023.dat',
#  './data/atusrost_2024.dat',
#  './data/atusrost_2016/atusrost_2016.dat']

# %%
#create a dictionary of original column names
(original_columns :=
 {p:{col: col
     for col in 
     pl.read_csv(p).columns
    }
  for p in rost_paths
 }
)
# Out:
# {'./data/atusrost_2003.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TURRP': 'TURRP',
#   'TESEX': 'TESEX',
#   'TERRP': 'TERRP',
#   'TEAGE': 'TEAGE',
#   'TXSEX': 'TXSEX',
#   'TXRRP': 'TXRRP',
#   'TXAGE': 'TXAGE'},
#  './data/atusrost_2004.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TURRP': 'TURRP',
#   'TESEX': 'TESEX',
#   'TERRP': 'TERRP',
#   'TEAGE': 'TEAGE',
#   'TXSEX': 'TXSEX',
#   'TXRRP': 'TXRRP',
#   'TXAGE': 'TXAGE'},
#  './data/atusrost_2005.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2006.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2007.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2008.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2009.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2010.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2011.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2012.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2013.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2014.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2015.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2017.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2018.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2019.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2020.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2021.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2022.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2023.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2024.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2016/atusrost_2016.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'}}

# %%
#create dictionary to assist with renaming columns
(fixed_columns :=
 {**original_columns, 
  **{
      path:{col:col.upper() for col in original_columns.get(path,[])}
     for path in rost_paths
     },  
}
)
# Out:
# {'./data/atusrost_2003.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TURRP': 'TURRP',
#   'TESEX': 'TESEX',
#   'TERRP': 'TERRP',
#   'TEAGE': 'TEAGE',
#   'TXSEX': 'TXSEX',
#   'TXRRP': 'TXRRP',
#   'TXAGE': 'TXAGE'},
#  './data/atusrost_2004.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TURRP': 'TURRP',
#   'TESEX': 'TESEX',
#   'TERRP': 'TERRP',
#   'TEAGE': 'TEAGE',
#   'TXSEX': 'TXSEX',
#   'TXRRP': 'TXRRP',
#   'TXAGE': 'TXAGE'},
#  './data/atusrost_2005.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2006.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2007.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2008.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2009.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2010.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2011.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2012.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2013.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2014.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2015.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2017.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2018.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2019.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2020.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2021.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2022.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2023.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2024.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'},
#  './data/atusrost_2016/atusrost_2016.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TEAGE': 'TEAGE',
#   'TERRP': 'TERRP',
#   'TESEX': 'TESEX',
#   'TXAGE': 'TXAGE',
#   'TXRRP': 'TXRRP',
#   'TXSEX': 'TXSEX'}}

# %%
# create an example of what is considered a "correct table schema"
(example_correct_table := pl.read_csv(rost_paths[0]).head()
)
# Out:
# shape: (5, 9)
# ┌────────────────┬──────────┬───────┬───────┬───┬───────┬───────┬───────┬───────┐
# │ TUCASEID       ┆ TULINENO ┆ TURRP ┆ TESEX ┆ … ┆ TEAGE ┆ TXSEX ┆ TXRRP ┆ TXAGE │
# │ ---            ┆ ---      ┆ ---   ┆ ---   ┆   ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ i64            ┆ i64      ┆ i64   ┆ i64   ┆   ┆ i64   ┆ i64   ┆ i64   ┆ i64   │
# ╞════════════════╪══════════╪═══════╪═══════╪═══╪═══════╪═══════╪═══════╪═══════╡
# │ 20030100013280 ┆ 1        ┆ 18    ┆ 1     ┆ … ┆ 60    ┆ 0     ┆ 0     ┆ 0     │
# │ 20030100013280 ┆ 2        ┆ 20    ┆ 2     ┆ … ┆ 72    ┆ 0     ┆ 0     ┆ 0     │
# │ 20030100013280 ┆ 3        ┆ 22    ┆ 2     ┆ … ┆ 37    ┆ 0     ┆ 0     ┆ 0     │
# │ 20030100013344 ┆ 1        ┆ 18    ┆ 2     ┆ … ┆ 41    ┆ 0     ┆ 0     ┆ 0     │
# │ 20030100013344 ┆ 2        ┆ 20    ┆ 1     ┆ … ┆ 42    ┆ 0     ┆ 0     ┆ 0     │
# └────────────────┴──────────┴───────┴───────┴───┴───────┴───────┴───────┴───────┘

# %%
# pull the int columns from the "correct table"
(int_columns := example_correct_table.select(cs.integer()).columns
)
# Out:
# ['TUCASEID',
#  'TULINENO',
#  'TURRP',
#  'TESEX',
#  'TERRP',
#  'TEAGE',
#  'TXSEX',
#  'TXRRP',
#  'TXAGE']

# %%
# pull the string columns from the "correct table"
(str_columns := example_correct_table.select(cs.string()).columns
)
# Out:
# []

# %%
#combine the int and string columns and map to their type
(col_and_types := {c: pl.String() for c in str_columns
} |    # Merge operator
{c:pl.Int64() for c in int_columns
 if c in roster_columns   # only cast columns that we need     
}
 )
# Out:
# {'TUCASEID': Int64,
#  'TULINENO': Int64,
#  'TESEX': Int64,
#  'TERRP': Int64,
#  'TEAGE': Int64}

# %%
# conduct renaming of columns and handle casting of data types.IT also pulls in each table.

(dfs := [pl.read_csv(p)
       .rename(col_rename)
       .select([
            pl.col(c).cast(t)
            for c, t in col_and_types.items()
            if c in roster_columns # only cast columns that exist
        ]) for p, col_rename in fixed_columns.items()]
)
# Out:
# [shape: (58_911, 5)
#  ┌────────────────┬──────────┬───────┬───────┬───────┐
#  │ TUCASEID       ┆ TULINENO ┆ TESEX ┆ TERRP ┆ TEAGE │
#  │ ---            ┆ ---      ┆ ---   ┆ ---   ┆ ---   │
#  │ i64            ┆ i64      ┆ i64   ┆ i64   ┆ i64   │
#  ╞════════════════╪══════════╪═══════╪═══════╪═══════╡
#  │ 20030100013280 ┆ 1        ┆ 1     ┆ 18    ┆ 60    │
#  │ 20030100013280 ┆ 2        ┆ 2     ┆ 20    ┆ 72    │
#  │ 20030100013280 ┆ 3        ┆ 2     ┆ 22    ┆ 37    │
#  │ 20030100013344 ┆ 1        ┆ 2     ┆ 18    ┆ 41    │
#  │ 20030100013344 ┆ 2        ┆ 1     ┆ 20    ┆ 42    │
#  │ …              ┆ …        ┆ …     ┆ …     ┆ …     │
#  │ 20031212033636 ┆ 2        ┆ 2     ┆ 20    ┆ 47    │
#  │ 20031212033636 ┆ 3        ┆ 2     ┆ 22    ┆ 12    │
#  │ 20031212033636 ┆ 4        ┆ 1     ┆ 22    ┆ 13    │
#  │ 20031212033642 ┆ 1        ┆ 2     ┆ 18    ┆ 54    │
#  │ 20031212033642 ┆ 2        ┆ 1     ┆ 20    ┆ 56    │
#  └────────────────┴──────────┴───────┴───────┴───────┘,
#  shape: (39_401, 5)
#  ┌────────────────┬──────────┬───────┬───────┬───────┐
#  │ TUCASEID       ┆ TULINENO ┆ TESEX ┆ TERRP ┆ TEAGE │
#  │ ---            ┆ ---      ┆ ---   ┆ ---   ┆ ---   │
#  │ i64            ┆ i64      ┆ i64   ┆ i64   ┆ i64   │
#  ╞════════════════╪══════════╪═══════╪═══════╪═══════╡
#  │ 20040101040003 ┆ 1        ┆ 1     ┆ 18    ┆ 71    │
#  │ 20040101040060 ┆ 1        ┆ 2     ┆ 19    ┆ 30    │
#  │ 20040101040060 ┆ 3        ┆ 1     ┆ 21    ┆ 23    │
#  │ 20040101040060 ┆ 4        ┆ 1     ┆ 40    ┆ 11    │
#  │ 20040101040079 ┆ 1        ┆ 1     ┆ 18    ┆ 29    │
#  │ …              ┆ …        ┆ …     ┆ …     ┆ …     │
#  │ 20041212042554 ┆ 4        ┆ 2     ┆ 22    ┆ 11    │
#  │ 20041212042565 ┆ 1        ┆ 1     ┆ 18    ┆ 37    │
#  │ 20041212042565 ┆ 2        ┆ 2     ┆ 20    ┆ 37    │
#  │ 20041212042565 ┆ 3        ┆ 1     ┆ 22    ┆ 7     │
#  │ 20041212042565 ┆ 4        ┆ 2     ┆ 22    ┆ 3     │
#  └────────────────┴──────────┴───────┴───────┴───────┘,
#  shape: (37_390, 5)
#  ┌────────────────┬──────────┬───────┬───────┬───────┐
#  │ TUCASEID       ┆ TULINENO ┆ TESEX ┆ TERRP ┆ TEAGE │
#  │ ---            ┆ ---      ┆ ---   ┆ ---   ┆ ---   │
#  │ i64            ┆ i64      ┆ i64   ┆ i64   ┆ i64   │
#  ╞════════════════╪══════════╪═══════╪═══════╪═══════╡
#  │ 20050101050006 ┆ 1        ┆ 2     ┆ 18    ┆ 51    │
#  │ 20050101050006 ┆ 2        ┆ 1     ┆ 20    ┆ 56    │
#  │ 20050101050012 ┆ 1        ┆ 2     ┆ 18    ┆ 42    │
#  │ 20050101050012 ┆ 2        ┆ 1     ┆ 20    ┆ 42    │
#  │ 20050101050012 ┆ 3        ┆ 1     ┆ 22    ┆ 2     │
#  │ …              ┆ …        ┆ …     ┆ …     ┆ …     │
#  │ 20051212052524 ┆ 5        ┆ 2     ┆ 22    ┆ 1     │
#  │ 20051212052534 ┆ 1        ┆ 2     ┆ 18    ┆ 39    │
#  │ 20051212052534 ┆ 2        ┆ 1     ┆ 20    ┆ 34    │
#  │ 20051212052534 ┆ 3        ┆ 2     ┆ 22    ┆ 9     │
#  │ 20051212052534 ┆ 4        ┆ 1     ┆ 22    ┆ 5     │
#  └────────────────┴──────────┴───────┴───────┴───────┘,
#  shape: (37_147, 5)
#  ┌────────────────┬──────────┬───────┬───────┬───────┐
#  │ TUCASEID       ┆ TULINENO ┆ TESEX ┆ TERRP ┆ TEAGE │
#  │ ---            ┆ ---      ┆ ---   ┆ ---   ┆ ---   │
#  │ i64            ┆ i64      ┆ i64   ┆ i64   ┆ i64   │
#  ╞════════════════╪══════════╪═══════╪═══════╪═══════╡
#  │ 
#  │ 20160101160066 ┆ 1        ┆ 1     ┆ 18    ┆ 69    │
#  │ 20160101160066 ┆ 2        ┆ 2     ┆ 20    ┆ 67    │
#  │ …              ┆ …        ┆ …     ┆ …     ┆ …     │
#  │ 20161212162456 ┆ 1        ┆ 2     ┆ 19    ┆ 80    │
#  │ 20161212162509 ┆ 1        ┆ 2     ┆ 18    ┆ 16    │
#  │ 20161212162509 ┆ 2        ┆ 1     ┆ 24    ┆ 37    │
#  │ 20161212162509 ┆ 3        ┆ 2     ┆ 24    ┆ 38    │
#  │ 20161212162509 ┆ 4        ┆ 2     ┆ 25    ┆ 12    │
#  └────────────────┴──────────┴───────┴───────┴───────┘]

# %%
# find common columns
(common_cols := set(dfs[0].columns))
# Out:
# {'TEAGE', 'TERRP', 'TESEX', 'TUCASEID', 'TULINENO'}

# %%
# remove columns that are not common to each table prior to unioning
for df in dfs[1:]:
    common_cols &= set(df.columns)

# %%
# conduct the initial union
(rost_combiner := pl.concat([df.select(sorted(common_cols)) for df in dfs]))
# Out:
# shape: (687_357, 5)
# ┌───────┬───────┬───────┬────────────────┬──────────┐
# │ TEAGE ┆ TERRP ┆ TESEX ┆ TUCASEID       ┆ TULINENO │
# │ ---   ┆ ---   ┆ ---   ┆ ---            ┆ ---      │
# │ i64   ┆ i64   ┆ i64   ┆ i64            ┆ i64      │
# ╞═══════╪═══════╪═══════╪════════════════╪══════════╡
# │ 60    ┆ 18    ┆ 1     ┆ 20030100013280 ┆ 1        │
# │ 72    ┆ 20    ┆ 2     ┆ 20030100013280 ┆ 2        │
# │ 37    ┆ 22    ┆ 2     ┆ 20030100013280 ┆ 3        │
# │ 41    ┆ 18    ┆ 2     ┆ 20030100013344 ┆ 1        │
# │ 42    ┆ 20    ┆ 1     ┆ 20030100013344 ┆ 2        │
# │ …     ┆ …     ┆ …     ┆ …              ┆ …        │
# │ 80    ┆ 19    ┆ 2     ┆ 20161212162456 ┆ 1        │
# │ 16    ┆ 18    ┆ 2     ┆ 20161212162509 ┆ 1        │
# │ 37    ┆ 24    ┆ 1     ┆ 20161212162509 ┆ 2        │
# │ 38    ┆ 24    ┆ 2     ┆ 20161212162509 ┆ 3        │
# │ 12    ┆ 25    ┆ 2     ┆ 20161212162509 ┆ 4        │
# └───────┴───────┴───────┴────────────────┴──────────┘

# %% [markdown]
# #### filter the roster file after unioning

# %%
# filter the table and create the final format
(rost_combined:=(rost_combiner # select only the married people that are over 18.
 .filter((pl.col('TEAGE').is_between(24,64, closed='right')   ) & (pl.col('TERRP') <= 20))
 .with_columns(ones = 1,housemates =  pl.col('TUCASEID').count().over('TUCASEID'))
 .filter(pl.col('housemates') == 2)
 .drop('TEAGE', 'ones', 'housemates', 'TERRP')
              )
)
#If you dock points for having a row count 16 off from what you got, I WILL cry.
# Out:
# shape: (191_734, 3)
# ┌───────┬────────────────┬──────────┐
# │ TESEX ┆ TUCASEID       ┆ TULINENO │
# │ ---   ┆ ---            ┆ ---      │
# │ i64   ┆ i64            ┆ i64      │
# ╞═══════╪════════════════╪══════════╡
# │ 2     ┆ 20030100013344 ┆ 1        │
# │ 1     ┆ 20030100013344 ┆ 2        │
# │ 2     ┆ 20030100013352 ┆ 1        │
# │ 1     ┆ 20030100013352 ┆ 2        │
# │ 2     ┆ 20030100013848 ┆ 1        │
# │ …     ┆ …              ┆ …        │
# │ 2     ┆ 20161212161953 ┆ 2        │
# │ 1     ┆ 20161212161997 ┆ 1        │
# │ 2     ┆ 20161212161997 ┆ 2        │
# │ 2     ┆ 20161212162217 ┆ 1        │
# │ 1     ┆ 20161212162217 ┆ 2        │
# └───────┴────────────────┴──────────┘

# %% [markdown]
# ### UNION RESPONDENT FILES
#  - in the respondent files there was some issues that BLS noted  about the TUFINLWGT column that will require some extra work for a few reasons.
#      - TUFINLWGT does not exist in all years.
#      -  in 2003-2006 the data in that column was not accurate, so we need to handle that specially.

# %%
# create paths

(resp_paths :=
 glob('./data/atusresp*.dat') + glob('./data/*/atusresp*.dat')
)
# Out:
# ['./data/atusresp_2003.dat',
#  './data/atusresp_2004.dat',
#  './data/atusresp_2005.dat',
#  './data/atusresp_2006.dat',
#  './data/atusresp_2007.dat',
#  './data/atusresp_2008.dat',
#  './data/atusresp_2009.dat',
#  './data/atusresp_2010.dat',
#  './data/atusresp_2011.dat',
#  './data/atusresp_2012.dat',
#  './data/atusresp_2013.dat',
#  './data/atusresp_2014.dat',
#  './data/atusresp_2015.dat',
#  './data/atusresp_2017.dat',
#  './data/atusresp_2018.dat',
#  './data/atusresp_2019.dat',
#  './data/atusresp_2020.dat',
#  './data/atusresp_2021.dat',
#  './data/atusresp_2022.dat',
#  './data/atusresp_2023.dat',
#  './data/atusresp_2024.dat',
#  './data/atusresp_2016/atusresp_2016.dat']

# %%
#create a dictionary of original column names
(original_columns :=
 {p:{col: col
     for col in 
     pl.read_csv(p,n_rows = 1,infer_schema_length=10000).columns
    }
  for p in resp_paths
 }
)
# Out:
# {'./data/atusresp_2003.dat': {'TUYEAR': 'TUYEAR',
#   'TUMONTH': 'TUMONTH',
#   'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TUDIARYDATE': 'TUDIARYDATE',
#   'TUDIARYDAY': 'TUDIARYDAY',
#   'TESPEMPNOT': 'TESPEMPNOT',
#   'TRSPFTPT': 'TRSPFTPT',
#   'TRWERNAL': 'TRWERNAL',
#   'TUIO1MFG': 'TUIO1MFG',
#   'TUDIS1': 'TUDIS1',
#   'TRYHHCHILD': 'TRYHHCHILD',
#   'TRMJIND1': 'TRMJIND1',
#   'TRDTOCC1': 'TRDTOCC1',
#   'TXSPEMPNOT': 'TXSPEMPNOT',
#   'TXRET1': 'TXRET1',
#   'TRIMIND1': 'TRIMIND1',
#   'TRDTIND1': 'TRDTIND1',
#   'TRMJOCGR': 'TRMJOCGR',
#   'TXSPUHRS': 'TXSPUHRS',
#   'TRSPPRES': 'TRSPPRES',
#   'TUABSOT': 'TUABSOT',
#   'TUBUS': 'TUBUS',
#   'TUBUS1': 'TUBUS1',
#   'TUBUS2OT': 'TUBUS2OT',
#   'TUBUSL1': 'TUBUSL1',
#   'TUBUSL2': 'TUBUSL2',
#   'TUBUSL3': 'TUBUSL3',
#   'TUBUSL4': 'TUBUSL4',
#   'TUDIS': 'TUDIS',
#   'TULAY': 'TULAY',
#   'TUFWK': 'TUFWK',
#   'TURETOT': 'TURETOT',
#   'TUSPABS': 'TUSPABS',
#   'TUSPUSFT': 'TUSPUSFT',
#   'TUCC2': 'TUCC2',
#   'TUCC4': 'TUCC4',
#   'TUCC9': 'TUCC9',
#   'TULAY6M': 'TULAY6M',
#   'TULAYAVR': 'TULAYAVR',
#   'TULAYDT': 'TULAYDT',
#   'TULK': 'TULK',
#   'TULKAVR': 'TULKAVR',
#   'TULKM2': 'TULKM2',
#   'TULKM3': 'TULKM3',
#   'TULKM4': 'TULKM4',
#   'TULKM5': 'TULKM5',
#   'TULKM6': 'TULKM6',
#   'TULKDK1': 'TULKDK1',
#   'TULKDK2': 'TULKDK2',
#   'TULKDK3': 'TULKDK3',
#   'TULKDK4': 'TULKDK4',
#   'TULKDK5': 'TULKDK5',
#   'TULKDK6': 'TULKDK6',
#   'TULKPS1': 'TULKPS1',
#   'TULKPS2': 'TULKPS2',
#   'TULKPS3': 'TULKPS3',
#   'TULKPS4': 'TULKPS4',
#   'TULKPS5': 'TULKPS5',
#   'TULKPS6': 'TULKPS6',
#   'TUERNH1C': 'TUERNH1C',
#   'TUERN2': 'TUERN2',
#   'TRMJOCC1': 'TRMJOCC1',
#   'TXTCC': 'TXTCC',
#   'TXTCOC': 'TXTCOC',
#   'TXABSRSN': 'TXABSRSN',
#   'TXMJOT': 'TXMJOT',
#   'TXHRFTPT': 'TXHRFTPT',
#   'TXHRUSL1': 'TXHRUSL1',
#   'TXHRUSL2': 'TXHRUSL2',
#   'TXHRUSLT': 'TXHRUSLT',
#   'TXIO1OCD': 'TXIO1OCD',
#   'TXLAYAVL': 'TXLAYAVL',
#   'TXLAYLK': 'TXLAYLK',
#   'TXLKAVL': 'TXLKAVL',
#   'TXLKM1': 'TXLKM1',
#   'TXERNH1O': 'TXERNH1O',
#   'TXERNHRO': 'TXERNHRO',
#   'TXERNPER': 'TXERNPER',
#   'TXERNUOT': 'TXERNUOT',
#   'TXERNWKP': 'TXERNWKP',
#   'TXERN': 'TXERN',
#   'TXERNH2': 'TXERNH2',
#   'TXSCHENR': 'TXSCHENR',
#   'TXSCHFT': 'TXSCHFT',
#   'TXSCHLVL': 'TXSCHLVL',
#   'TTOT': 'TTOT',
#   'TTWK': 'TTWK',
#   'TRHOLIDAY': 'TRHOLIDAY',
#   'TRTSPONLY': 'TRTSPONLY',
#   'TRTHHFAMILY': 'TRTHHFAMILY',
#   'TRTUNMPART': 'TRTUNMPART',
#   'TEABSRSN': 'TEABSRSN',
#   'TEMJOT': 'TEMJOT',
#   'TEHRFTPT': 'TEHRFTPT',
#   'TEHRUSL1': 'TEHRUSL1',
#   'TEHRUSL2': 'TEHRUSL2',
#   'TEHRUSLT': 'TEHRUSLT',
#   'TEIO1COW': 'TEIO1COW',
#   'TEIO1ICD': 'TEIO1ICD',
#   'TEIO1OCD': 'TEIO1OCD',
#   'TELAYAVL': 'TELAYAVL',
#   'TELAYLK': 'TELAYLK',
#   'TELKAVL': 'TELKAVL',
#   'TELKM1': 'TELKM1',
#   'TEERNH1O': 'TEERNH1O',
#   'TEERNHRO': 'TEERNHRO',
#   'TEERNPER': 'TEERNPER',
#   'TEERNUOT': 'TEERNUOT',
#   'TEERNWKP': 'TEERNWKP',
#   'TEERN': 'TEERN',
#   'TEERNH2': 'TEERNH2',
#   'TEERNRT': 'TEERNRT',
#   'TESCHENR': 'TESCHENR',
#   'TESCHFT': 'TESCHFT',
#   'TESCHLVL': 'TESCHLVL',
#   'TRTALONE': 'TRTALONE',
#   'TRTSPOUSE': 'TRTSPOUSE',
#   'TRTFAMILY': 'TRTFAMILY',
#   'TRTCCC': 'TRTCCC',
#   'TRTFRIEND': 'TRTFRIEND',
#   'TRTOHHCHILD': 'TRTOHHCHILD',
#   'TRTONHHCHILD': 'TRTONHHCHILD',
#   'TRTNOCHILD': 'TRTNOCHILD',
#   'TRTCHILD': 'TRTCHILD',
#   'TELFS': 'TELFS',
#   'TXLFS': 'TXLFS',
#   'TRHERNAL': 'TRHERNAL',
#   'TUSPWK': 'TUSPWK',
#   'TUIODP1': 'TUIODP1',
#   'TUIODP2': 'TUIODP2',
#   'TUIODP3': 'TUIODP3',
#   'TTHR': 'TTHR',
#   'TXIO1COW': 'TXIO1COW',
#   'TXIO1ICD': 'TXIO1ICD',
#   'TXERNRT': 'TXERNRT',
#   'TUFINLWGT': 'TUFINLWGT',
#   'TU06FWGT': 'TU06FWGT',
#   'TUBNCHWGT': 'TUBNCHWGT',
#   'TRTCC': 'TRTCC',
#   'TRTCOC': 'TRTCOC',
#   'TEERNHRY': 'TEERNHRY',
#   'TRERNWA': 'TRERNWA',
#   'TRERNHLY': 'TRERNHLY',
#   'TRERNUPD': 'TRERNUPD',
#   'TESPUHRS': 'TESPUHRS',
#   'TRDPFTPT': 'TRDPFTPT',
#   'TERET1': 'TERET1',
#   'TUDIS2': 'TUDIS2',
#   'TRHHCHILD': 'TRHHCHILD',
#   'TRNHHCHILD': 'TRNHHCHILD',
#   'TRCHILDNUM': 'TRCHILDNUM',
#   'TROHHCHILD': 'TROHHCHILD',
#   'TRTCCTOT': 'TRTCCTOT',
#   'TXERNHRY': 'TXERNHRY',
#   'TUBWGT': 'TUBWGT',
#   'TU04FWGT': 'TU04FWGT'},
#  './data/atusresp_2004.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TUYEAR': 'TUYEAR',
#   'TUMONTH': 'TUMONTH',
#   'TUDIARYDATE': 'TUDIARYDATE',
#   'TUDIARYDAY': 'TUDIARYDAY',
#   'TUABSOT': 'TUABSOT',
#   'TUBUS': 'TUBUS',
#   'TUBUS1': 'TUBUS1',
#   'TUBUS2OT': 'TUBUS2OT',
#   'TUBUSL1': 'TUBUSL1',
#   'TUBUSL2': 'TUBUSL2',
#   'TUBUSL3': 'TUBUSL3',
#   'TUBUSL4': 'TUBUSL4',
#   'TUDIS': 'TUDIS',
#   'TULAY': 'TULAY',
#   'TURETOT': 'TURETOT',
#   'TUSPWK': 'TUSPWK',
#   'TUSPABS': 'TUSPABS',
#   'TUSPUSFT': 'TUSPUSFT',
#   'TUFWK': 'TUFWK',
#   'TUCC2': 'TUCC2',
#   'TUCC4': 'TUCC4',
#   'TUCC9': 'TUCC9',
#   'TUIODP1': 'TUIODP1',
#   'TUIODP2': 'TUIODP2',
#   'TUIODP3': 'TUIODP3',
#   'TULAY6M': 'TULAY6M',
#   'TULAYAVR': 'TULAYAVR',
#   'TULAYDT': 'TULAYDT',
#   'TULK': 'TULK',
#   'TULKAVR': 'TULKAVR',
#   'TULKM2': 'TULKM2',
#   'TULKM3': 'TULKM3',
#   'TULKM4': 'TULKM4',
#   'TULKM5': 'TULKM5',
#   'TULKM6': 'TULKM6',
#   'TULKDK1': 'TULKDK1',
#   'TULKDK2': 'TULKDK2',
#   'TULKDK3': 'TULKDK3',
#   'TULKDK4': 'TULKDK4',
#   'TULKDK5': 'TULKDK5',
#   'TULKDK6': 'TULKDK6',
#   'TULKPS1': 'TULKPS1',
#   'TULKPS2': 'TULKPS2',
#   'TULKPS3': 'TULKPS3',
#   'TULKPS4': 'TULKPS4',
#   'TULKPS5': 'TULKPS5',
#   'TULKPS6': 'TULKPS6',
#   'TUERNH1C': 'TUERNH1C',
#   'TUERN2': 'TUERN2',
#   'TRTALONE': 'TRTALONE',
#   'TRTSPONLY': 'TRTSPONLY',
#   'TRTSPOUSE': 'TRTSPOUSE',
#   'TRTFAMILY': 'TRTFAMILY',
#   'TRTHHFAMILY': 'TRTHHFAMILY',
#   'TRTCCC': 'TRTCCC',
#   'TRTFRIEND': 'TRTFRIEND',
#   'TRTOHHCHILD': 'TRTOHHCHILD',
#   'TRTONHHCHILD': 'TRTONHHCHILD',
#   'TRTNOCHILD': 'TRTNOCHILD',
#   'TRTCHILD': 'TRTCHILD',
#   'TRTUNMPART': 'TRTUNMPART',
#   'TEABSRSN': 'TEABSRSN',
#   'TEMJOT': 'TEMJOT',
#   'TEHRFTPT': 'TEHRFTPT',
#   'TEHRUSL1': 'TEHRUSL1',
#   'TEHRUSL2': 'TEHRUSL2',
#   'TEHRUSLT': 'TEHRUSLT',
#   'TEIO1COW': 'TEIO1COW',
#   'TEIO1ICD': 'TEIO1ICD',
#   'TEIO1OCD': 'TEIO1OCD',
#   'TELAYAVL': 'TELAYAVL',
#   'TELAYLK': 'TELAYLK',
#   'TELKAVL': 'TELKAVL',
#   'TELKM1': 'TELKM1',
#   'TEERNH1O': 'TEERNH1O',
#   'TEERNHRO': 'TEERNHRO',
#   'TEERNPER': 'TEERNPER',
#   'TEERNUOT': 'TEERNUOT',
#   'TEERNWKP': 'TEERNWKP',
#   'TEERN': 'TEERN',
#   'TEERNH2': 'TEERNH2',
#   'TEERNRT': 'TEERNRT',
#   'TESCHENR': 'TESCHENR',
#   'TESCHFT': 'TESCHFT',
#   'TESCHLVL': 'TESCHLVL',
#   'TELFS': 'TELFS',
#   'TXABSRSN': 'TXABSRSN',
#   'TXMJOT': 'TXMJOT',
#   'TXHRFTPT': 'TXHRFTPT',
#   'TXHRUSL1': 'TXHRUSL1',
#   'TXHRUSL2': 'TXHRUSL2',
#   'TXHRUSLT': 'TXHRUSLT',
#   'TXIO1COW': 'TXIO1COW',
#   'TXIO1ICD': 'TXIO1ICD',
#   'TXIO1OCD': 'TXIO1OCD',
#   'TXLAYAVL': 'TXLAYAVL',
#   'TXLAYLK': 'TXLAYLK',
#   'TXLKAVL': 'TXLKAVL',
#   'TXLKM1': 'TXLKM1',
#   'TXERNH1O': 'TXERNH1O',
#   'TXERNHRO': 'TXERNHRO',
#   'TXERNPER': 'TXERNPER',
#   'TXERNUOT': 'TXERNUOT',
#   'TXERNWKP': 'TXERNWKP',
#   'TXERN': 'TXERN',
#   'TXERNH2': 'TXERNH2',
#   'TXERNRT': 'TXERNRT',
#   'TXSCHENR': 'TXSCHENR',
#   'TXSCHFT': 'TXSCHFT',
#   'TXSCHLVL': 'TXSCHLVL',
#   'TXLFS': 'TXLFS',
#   'TRHOLIDAY': 'TRHOLIDAY',
#   'TUFINLWGT': 'TUFINLWGT',
#   'TU06FWGT': 'TU06FWGT',
#   'TRMJOCC1': 'TRMJOCC1',
#   'TRTCC': 'TRTCC',
#   'TXTCC': 'TXTCC',
#   'TRTCOC': 'TRTCOC',
#   'TXTCOC': 'TXTCOC',
#   'TRERNWA': 'TRERNWA',
#   'TRERNHLY': 'TRERNHLY',
#   'TRERNUPD': 'TRERNUPD',
#   'TTOT': 'TTOT',
#   'TTHR': 'TTHR',
#   'TTWK': 'TTWK',
#   'TESPEMPNOT': 'TESPEMPNOT',
#   'TESPUHRS': 'TESPUHRS',
#   'TRSPFTPT': 'TRSPFTPT',
#   'TRDPFTPT': 'TRDPFTPT',
#   'TRWERNAL': 'TRWERNAL',
#   'TRHERNAL': 'TRHERNAL',
#   'TUIO1MFG': 'TUIO1MFG',
#   'TERET1': 'TERET1',
#   'TUDIS1': 'TUDIS1',
#   'TUDIS2': 'TUDIS2',
#   'TXSPEMPNOT': 'TXSPEMPNOT',
#   'TXSPUHRS': 'TXSPUHRS',
#   'TRSPPRES': 'TRSPPRES',
#   'TXRET1': 'TXRET1',
#   'TEERNHRY': 'TEERNHRY',
#   'TXERNHRY': 'TXERNHRY',
#   'TRYHHCHILD': 'TRYHHCHILD',
#   'TRHHCHILD': 'TRHHCHILD',
#   'TRNHHCHILD': 'TRNHHCHILD',
#   'TRCHILDNUM': 'TRCHILDNUM',
#   'TROHHCHILD': 'TROHHCHILD',
#   'TRTCCTOT': 'TRTCCTOT',
#   'TRIMIND1': 'TRIMIND1',
#   'TRMJIND1': 'TRMJIND1',
#   'TRDTIND1': 'TRDTIND1',
#   'TRDTOCC1': 'TRDTOCC1',
#   'TRMJOCGR': 'TRMJOCGR',
#   'TUBWGT': 'TUBWGT',
#   'TRTOHH': 'TRTOHH',
#   'TRTONHH': 'TRTONHH',
#   'TRTNOHH': 'TRTNOHH',
#   'TRTO': 'TRTO',
#   'TRTHH': 'TRTHH',
#   'TXTOHH': 'TXTOHH',
#   'TXTONHH': 'TXTONHH',
#   'TXTNOHH': 'TXTNOHH',
#   'TXTO': 'TXTO',
#   'TXTHH': 'TXTHH',
#   'TXTCCTOT': 'TXTCCTOT'},
#  './data/atusresp_2005.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TUYEAR': 'TUYEAR',
#   'TUMONTH': 'TUMONTH',
#   'TEABSRSN': 'TEABSRSN',
#   'TEERN': 'TEERN',
#   'TEERNH1O': 'TEERNH1O',
#   'TEERNH2': 'TEERNH2',
#   'TEERNHRO': 'TEERNHRO',
#   'TEERNHRY': 'TEERNHRY',
#   'TEERNPER': 'TEERNPER',
#   'TEERNRT': 'TEERNRT',
#   'TEERNUOT': 'TEERNUOT',
#   'TEERNWKP': 'TEERNWKP',
#   'TEHRFTPT': 'TEHRFTPT',
#   'TEHRUSL1': 'TEHRUSL1',
#   'TEHRUSL2': 'TEHRUSL2',
#   'TEHRUSLT': 'TEHRUSLT',
#   'TEIO1COW': 'TEIO1COW',
#   'TEIO1ICD': 'TEIO1ICD',
#   'TEIO1OCD': 'TEIO1OCD',
#   'TELAYAVL': 'TELAYAVL',
#   'TELAYLK': 'TELAYLK',
#   'TELFS': 'TELFS',
#   'TELKAVL': 'TELKAVL',
#   'TELKM1': 'TELKM1',
#   'TEMJOT': 'TEMJOT',
#   'TERET1': 'TERET1',
#   'TESCHENR': 'TESCHENR',
#   'TESCHFT': 'TESCHFT',
#   'TESCHLVL': 'TESCHLVL',
#   'TESPEMPNOT': 'TESPEMPNOT',
#   'TESPUHRS': 'TESPUHRS',
#   'TRCHILDNUM': 'TRCHILDNUM',
#   'TRDPFTPT': 'TRDPFTPT',
#   'TRDTIND1': 'TRDTIND1',
#   'TRDTOCC1': 'TRDTOCC1',
#   'TRERNHLY': 'TRERNHLY',
#   'TRERNUPD': 'TRERNUPD',
#   'TRERNWA': 'TRERNWA',
#   'TRHERNAL': 'TRHERNAL',
#   'TRHHCHILD': 'TRHHCHILD',
#   'TRHOLIDAY': 'TRHOLIDAY',
#   'TRIMIND1': 'TRIMIND1',
#   'TRMJIND1': 'TRMJIND1',
#   'TRMJOCC1': 'TRMJOCC1',
#   'TRMJOCGR': 'TRMJOCGR',
#   'TRNHHCHILD': 'TRNHHCHILD',
#   'TRNUMHOU': 'TRNUMHOU',
#   'TROHHCHILD': 'TROHHCHILD',
#   'TRSPFTPT': 'TRSPFTPT',
#   'TRSPPRES': 'TRSPPRES',
#   'TRTALONE': 'TRTALONE',
#   'TRTCC': 'TRTCC',
#   'TRTCCC': 'TRTCCC',
#   'TRTCCTOT': 'TRTCCTOT',
#   'TRTCHILD': 'TRTCHILD',
#   'TRTCOC': 'TRTCOC',
#   'TRTFAMILY': 'TRTFAMILY',
#   'TRTFRIEND': 'TRTFRIEND',
#   'TRTHH': 'TRTHH',
#   'TRTHHFAMILY': 'TRTHHFAMILY',
#   'TRTNOCHILD': 'TRTNOCHILD',
#   'TRTNOHH': 'TRTNOHH',
#   'TRTO': 'TRTO',
#   'TRTOHH': 'TRTOHH',
#   'TRTOHHCHILD': 'TRTOHHCHILD',
#   'TRTONHH': 'TRTONHH',
#   'TRTONHHCHILD': 'TRTONHHCHILD',
#   'TRTSPONLY': 'TRTSPONLY',
#   'TRTSPOUSE': 'TRTSPOUSE',
#   'TRTUNMPART': 'TRTUNMPART',
#   'TRWERNAL': 'TRWERNAL',
#   'TRYHHCHILD': 'TRYHHCHILD',
#   'TTHR': 'TTHR',
#   'TTOT': 'TTOT',
#   'TTWK': 'TTWK',
#   'TUABSOT': 'TUABSOT',
#   'TUBUS': 'TUBUS',
#   'TUBUS1': 'TUBUS1',
#   'TUBUS2OT': 'TUBUS2OT',
#   'TUBUSL1': 'TUBUSL1',
#   'TUBUSL2': 'TUBUSL2',
#   'TUBUSL3': 'TUBUSL3',
#   'TUBUSL4': 'TUBUSL4',
#   'TUBWGT': 'TUBWGT',
#   'TUCC2': 'TUCC2',
#   'TUCC4': 'TUCC4',
#   'TUCC5B_CK': 'TUCC5B_CK',
#   'TUCC5_CK': 'TUCC5_CK',
#   'TUCC9': 'TUCC9',
#   'TUDIARYDATE': 'TUDIARYDATE',
#   'TUDIARYDAY': 'TUDIARYDAY',
#   'TUDIS': 'TUDIS',
#   'TUDIS1': 'TUDIS1',
#   'TUDIS2': 'TUDIS2',
#   'TUERN2': 'TUERN2',
#   'TUERNH1C': 'TUERNH1C',
#   'TUFINLWGT': 'TUFINLWGT',
#   'TU06FWGT': 'TU06FWGT',
#   'TUFWK': 'TUFWK',
#   'TUIO1MFG': 'TUIO1MFG',
#   'TUIODP1': 'TUIODP1',
#   'TUIODP2': 'TUIODP2',
#   'TUIODP3': 'TUIODP3',
#   'TULAY': 'TULAY',
#   'TULAY6M': 'TULAY6M',
#   'TULAYAVR': 'TULAYAVR',
#   'TULAYDT': 'TULAYDT',
#   'TULK': 'TULK',
#   'TULKAVR': 'TULKAVR',
#   'TULKDK1': 'TULKDK1',
#   'TULKDK2': 'TULKDK2',
#   'TULKDK3': 'TULKDK3',
#   'TULKDK4': 'TULKDK4',
#   'TULKDK5': 'TULKDK5',
#   'TULKDK6': 'TULKDK6',
#   'TULKM2': 'TULKM2',
#   'TULKM3': 'TULKM3',
#   'TULKM4': 'TULKM4',
#   'TULKM5': 'TULKM5',
#   'TULKM6': 'TULKM6',
#   'TULKPS1': 'TULKPS1',
#   'TULKPS2': 'TULKPS2',
#   'TULKPS3': 'TULKPS3',
#   'TULKPS4': 'TULKPS4',
#   'TULKPS5': 'TULKPS5',
#   'TULKPS6': 'TULKPS6',
#   'TURETOT': 'TURETOT',
#   'TUSPABS': 'TUSPABS',
#   'TUSPUSFT': 'TUSPUSFT',
#   'TUSPWK': 'TUSPWK',
#   'TXABSRSN': 'TXABSRSN',
#   'TXERN': 'TXERN',
#   'TXERNH1O': 'TXERNH1O',
#   'TXERNH2': 'TXERNH2',
#   'TXERNHRO': 'TXERNHRO',
#   'TXERNHRY': 'TXERNHRY',
#   'TXERNPER': 'TXERNPER',
#   'TXERNRT': 'TXERNRT',
#   'TXERNUOT': 'TXERNUOT',
#   'TXERNWKP': 'TXERNWKP',
#   'TXHRFTPT': 'TXHRFTPT',
#   'TXHRUSL1': 'TXHRUSL1',
#   'TXHRUSL2': 'TXHRUSL2',
#   'TXHRUSLT': 'TXHRUSLT',
#   'TXIO1COW': 'TXIO1COW',
#   'TXIO1ICD': 'TXIO1ICD',
#   'TXIO1OCD': 'TXIO1OCD',
#   'TXLAYAVL': 'TXLAYAVL',
#   'TXLAYLK': 'TXLAYLK',
#   'TXLFS': 'TXLFS',
#   'TXLKAVL': 'TXLKAVL',
#   'TXLKM1': 'TXLKM1',
#   'TXMJOT': 'TXMJOT',
#   'TXRET1': 'TXRET1',
#   'TXSCHENR': 'TXSCHENR',
#   'TXSCHFT': 'TXSCHFT',
#   'TXSCHLVL': 'TXSCHLVL',
#   'TXSPEMPNOT': 'TXSPEMPNOT',
#   'TXSPUHRS': 'TXSPUHRS',
#   'TXTCC': 'TXTCC',
#   'TXTCCTOT': 'TXTCCTOT',
#   'TXTCOC': 'TXTCOC',
#   'TXTHH': 'TXTHH',
#   'TXTNOHH': 'TXTNOHH',
#   'TXTO': 'TXTO',
#   'TXTOHH': 'TXTOHH',
#   'TXTONHH': 'TXTONHH'},
#  './data/atusresp_2006.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TUYEAR': 'TUYEAR',
#   'TUMONTH': 'TUMONTH',
#   'TEABSRSN': 'TEABSRSN',
#   'TEERN': 'TEERN',
#   'TEERNH1O': 'TEERNH1O',
#   'TEERNH2': 'TEERNH2',
#   'TEERNHRO': 'TEERNHRO',
#   'TEERNHRY': 'TEERNHRY',
#   'TEERNPER': 'TEERNPER',
#   'TEERNRT': 'TEERNRT',
#   'TEERNUOT': 'TEERNUOT',
#   'TEERNWKP': 'TEERNWKP',
#   'TEHRFTPT': 'TEHRFTPT',
#   'TEHRUSL1': 'TEHRUSL1',
#   'TEHRUSL2': 'TEHRUSL2',
#   'TEHRUSLT': 'TEHRUSLT',
#   'TEIO1COW': 'TEIO1COW',
#   'TEIO1ICD': 'TEIO1ICD',
#   'TEIO1OCD': 'TEIO1OCD',
#   'TELAYAVL': 'TELAYAVL',
#   'TELAYLK': 'TELAYLK',
#   'TELFS': 'TELFS',
#   'TELKAVL': 'TELKAVL',
#   'TELKM1': 'TELKM1',
#   'TEMJOT': 'TEMJOT',
#   'TERET1': 'TERET1',
#   'TESCHENR': 'TESCHENR',
#   'TESCHFT': 'TESCHFT',
#   'TESCHLVL': 'TESCHLVL',
#   'TESPEMPNOT': 'TESPEMPNOT',
#   'TESPUHRS': 'TESPUHRS',
#   'TRCHILDNUM': 'TRCHILDNUM',
#   'TRDPFTPT': 'TRDPFTPT',
#   'TRDTIND1': 'TRDTIND1',
#   'TRDTOCC1': 'TRDTOCC1',
#   'TREMODR': 'TREMODR',
#   'TRERNHLY': 'TRERNHLY',
#   'TRERNUPD': 'TRERNUPD',
#   'TRERNWA': 'TRERNWA',
#   'TRHERNAL': 'TRHERNAL',
#   'TRHHCHILD': 'TRHHCHILD',
#   'TRHOLIDAY': 'TRHOLIDAY',
#   'TRIMIND1': 'TRIMIND1',
#   'TRMJIND1': 'TRMJIND1',
#   'TRMJOCC1': 'TRMJOCC1',
#   'TRMJOCGR': 'TRMJOCGR',
#   'TRNHHCHILD': 'TRNHHCHILD',
#   'TRNUMHOU': 'TRNUMHOU',
#   'TROHHCHILD': 'TROHHCHILD',
#   'TRSPFTPT': 'TRSPFTPT',
#   'TRSPPRES': 'TRSPPRES',
#   'TRTALONE': 'TRTALONE',
#   'TRTCC': 'TRTCC',
#   'TRTCCC': 'TRTCCC',
#   'TRTCCTOT': 'TRTCCTOT',
#   'TRTCHILD': 'TRTCHILD',
#   'TRTCOC': 'TRTCOC',
#   'TRTFAMILY': 'TRTFAMILY',
#   'TRTFRIEND': 'TRTFRIEND',
#   'TRTHH': 'TRTHH',
#   'TRTHHFAMILY': 'TRTHHFAMILY',
#   'TRTNOCHILD': 'TRTNOCHILD',
#   'TRTNOHH': 'TRTNOHH',
#   'TRTO': 'TRTO',
#   'TRTOHH': 'TRTOHH',
#   'TRTOHHCHILD': 'TRTOHHCHILD',
#   'TRTONHH': 'TRTONHH',
#   'TRTONHHCHILD': 'TRTONHHCHILD',
#   'TRTSPONLY': 'TRTSPONLY',
#   'TRTSPOUSE': 'TRTSPOUSE',
#   'TRTUNMPART': 'TRTUNMPART',
#   'TRWERNAL': 'TRWERNAL',
#   'TRYHHCHILD': 'TRYHHCHILD',
#   'TTHR': 'TTHR',
#   'TTOT': 'TTOT',
#   'TTWK': 'TTWK',
#   'TUABSOT': 'TUABSOT',
#   'TUBUS': 'TUBUS',
#   'TUBUS1': 'TUBUS1',
#   'TUBUS2OT': 'TUBUS2OT',
#   'TUBUSL1': 'TUBUSL1',
#   'TUBUSL2': 'TUBUSL2',
#   'TUBUSL3': 'TUBUSL3',
#   'TUBUSL4': 'TUBUSL4',
#   'TUBWGT': 'TUBWGT',
#   'TUCC2': 'TUCC2',
#   'TUCC4': 'TUCC4',
#   'TUCC5B_CK': 'TUCC5B_CK',
#   'TUCC5_CK': 'TUCC5_CK',
#   'TUCC9': 'TUCC9',
#   'TUDIARYDATE': 'TUDIARYDATE',
#   'TUDIARYDAY': 'TUDIARYDAY',
#   'TUDIS': 'TUDIS',
#   'TUDIS1': 'TUDIS1',
#   'TUDIS2': 'TUDIS2',
#   'TUERN2': 'TUERN2',
#   'TUERNH1C': 'TUERNH1C',
#   'TUFINLWGT': 'TUFINLWGT',
#   'TUFWK': 'TUFWK',
#   'TUIO1MFG': 'TUIO1MFG',
#   'TUIODP1': 'TUIODP1',
#   'TUIODP2': 'TUIODP2',
#   'TUIODP3': 'TUIODP3',
#   'TULAY': 'TULAY',
#   'TULAY6M': 'TULAY6M',
#   'TULAYAVR': 'TULAYAVR',
#   'TULAYDT': 'TULAYDT',
#   'TULK': 'TULK',
#   'TULKAVR': 'TULKAVR',
#   'TULKDK1': 'TULKDK1',
#   'TULKDK2': 'TULKDK2',
#   'TULKDK3': 'TULKDK3',
#   'TULKDK4': 'TULKDK4',
#   'TULKDK5': 'TULKDK5',
#   'TULKDK6': 'TULKDK6',
#   'TULKM2': 'TULKM2',
#   'TULKM3': 'TULKM3',
#   'TULKM4': 'TULKM4',
#   'TULKM5': 'TULKM5',
#   'TULKM6': 'TULKM6',
#   'TULKPS1': 'TULKPS1',
#   'TULKPS2': 'TULKPS2',
#   'TULKPS3': 'TULKPS3',
#   'TULKPS4': 'TULKPS4',
#   'TULKPS5': 'TULKPS5',
#   'TULKPS6': 'TULKPS6',
#   'TURETOT': 'TURETOT',
#   'TUSPABS': 'TUSPABS',
#   'TUSPUSFT': 'TUSPUSFT',
#   'TUSPWK': 'TUSPWK',
#   'TXABSRSN': 'TXABSRSN',
#   'TXERN': 'TXERN',
#   'TXERNH1O': 'TXERNH1O',
#   'TXERNH2': 'TXERNH2',
#   'TXERNHRO': 'TXERNHRO',
#   'TXERNHRY': 'TXERNHRY',
#   'TXERNPER': 'TXERNPER',
#   'TXERNRT': 'TXERNRT',
#   'TXERNUOT': 'TXERNUOT',
#   'TXERNWKP': 'TXERNWKP',
#   'TXHRFTPT': 'TXHRFTPT',
#   'TXHRUSL1': 'TXHRUSL1',
#   'TXHRUSL2': 'TXHRUSL2',
#   'TXHRUSLT': 'TXHRUSLT',
#   'TXIO1COW': 'TXIO1COW',
#   'TXIO1ICD': 'TXIO1ICD',
#   'TXIO1OCD': 'TXIO1OCD',
#   'TXLAYAVL': 'TXLAYAVL',
#   'TXLAYLK': 'TXLAYLK',
#   'TXLFS': 'TXLFS',
#   'TXLKAVL': 'TXLKAVL',
#   'TXLKM1': 'TXLKM1',
#   'TXMJOT': 'TXMJOT',
#   'TXRET1': 'TXRET1',
#   'TXSCHENR': 'TXSCHENR',
#   'TXSCHFT': 'TXSCHFT',
#   'TXSCHLVL': 'TXSCHLVL',
#   'TXSPEMPNOT': 'TXSPEMPNOT',
#   'TXSPUHRS': 'TXSPUHRS',
#   'TXTCC': 'TXTCC',
#   'TXTCCTOT': 'TXTCCTOT',
#   'TXTCOC': 'TXTCOC',
#   'TXTHH': 'TXTHH',
#   'TXTNOHH': 'TXTNOHH',
#   'TXTO': 'TXTO',
#   'TXTOHH': 'TXTOHH',
#   'TXTONHH': 'TXTONHH'},
#  './data/atusresp_2007.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TUYEAR': 'TUYEAR',
#   'TUMONTH': 'TUMONTH',
#   'TEABSRSN': 'TEABSRSN',
#   'TEERN': 'TEERN',
#   'TEERNH1O': 'TEERNH1O',
#   'TEERNH2': 'TEERNH2',
#   'TEERNHRO': 'TEERNHRO',
#   'TEERNHRY': 'TEERNHRY',
#   'TEERNPER': 'TEERNPER',
#   'TEERNRT': 'TEERNRT',
#   'TEERNUOT': 'TEERNUOT',
#   'TEERNWKP': 'TEERNWKP',
#   'TEHRFTPT': 'TEHRFTPT',
#   'TEHRUSL1': 'TEHRUSL1',
#   'TEHRUSL2': 'TEHRUSL2',
#   'TEHRUSLT': 'TEHRUSLT',
#   'TEIO1COW': 'TEIO1COW',
#   'TEIO1ICD': 'TEIO1ICD',
#   'TEIO1OCD': 'TEIO1OCD',
#   'TELAYAVL': 'TELAYAVL',
#   'TELAYLK': 'TELAYLK',
#   'TELFS': 'TELFS',
#   'TELKAVL': 'TELKAVL',
#   'TELKM1': 'TELKM1',
#   'TEMJOT': 'TEMJOT',
#   'TERET1': 'TERET1',
#   'TESCHENR': 'TESCHENR',
#   'TESCHFT': 'TESCHFT',
#   'TESCHLVL': 'TESCHLVL',
#   'TESPEMPNOT': 'TESPEMPNOT',
#   'TESPUHRS': 'TESPUHRS',
#   'TRCHILDNUM': 'TRCHILDNUM',
#   'TRDPFTPT': 'TRDPFTPT',
#   'TRDTIND1': 'TRDTIND1',
#   'TRDTOCC1': 'TRDTOCC1',
#   'TREMODR': 'TREMODR',
#   'TRERNHLY': 'TRERNHLY',
#   'TRERNUPD': 'TRERNUPD',
#   'TRERNWA': 'TRERNWA',
#   'TRHERNAL': 'TRHERNAL',
#   'TRHHCHILD': 'TRHHCHILD',
#   'TRHOLIDAY': 'TRHOLIDAY',
#   'TRIMIND1': 'TRIMIND1',
#   'TRMJIND1': 'TRMJIND1',
#   'TRMJOCC1': 'TRMJOCC1',
#   'TRMJOCGR': 'TRMJOCGR',
#   'TRNHHCHILD': 'TRNHHCHILD',
#   'TRNUMHOU': 'TRNUMHOU',
#   'TROHHCHILD': 'TROHHCHILD',
#   'TRSPFTPT': 'TRSPFTPT',
#   'TRSPPRES': 'TRSPPRES',
#   'TRTALONE': 'TRTALONE',
#   'TRTCC': 'TRTCC',
#   'TRTCCC': 'TRTCCC',
#   'TRTCCTOT': 'TRTCCTOT',
#   'TRTCHILD': 'TRTCHILD',
#   'TRTCOC': 'TRTCOC',
#   'TRTFAMILY': 'TRTFAMILY',
#   'TRTFRIEND': 'TRTFRIEND',
#   'TRTHH': 'TRTHH',
#   'TRTHHFAMILY': 'TRTHHFAMILY',
#   'TRTNOCHILD': 'TRTNOCHILD',
#   'TRTNOHH': 'TRTNOHH',
#   'TRTO': 'TRTO',
#   'TRTOHH': 'TRTOHH',
#   'TRTOHHCHILD': 'TRTOHHCHILD',
#   'TRTONHH': 'TRTONHH',
#   'TRTONHHCHILD': 'TRTONHHCHILD',
#   'TRTSPONLY': 'TRTSPONLY',
#   'TRTSPOUSE': 'TRTSPOUSE',
#   'TRTUNMPART': 'TRTUNMPART',
#   'TRWERNAL': 'TRWERNAL',
#   'TRYHHCHILD': 'TRYHHCHILD',
#   'TTHR': 'TTHR',
#   'TTOT': 'TTOT',
#   'TTWK': 'TTWK',
#   'TUABSOT': 'TUABSOT',
#   'TUBUS': 'TUBUS',
#   'TUBUS1': 'TUBUS1',
#   'TUBUS2OT': 'TUBUS2OT',
#   'TUBUSL1': 'TUBUSL1',
#   'TUBUSL2': 'TUBUSL2',
#   'TUBUSL3': 'TUBUSL3',
#   'TUBUSL4': 'TUBUSL4',
#   'TUBWGT': 'TUBWGT',
#   'TUCC2': 'TUCC2',
#   'TUCC4': 'TUCC4',
#   'TUCC5B_CK': 'TUCC5B_CK',
#   'TUCC5_CK': 'TUCC5_CK',
#   'TUCC9': 'TUCC9',
#   'TUDIARYDATE': 'TUDIARYDATE',
#   'TUDIARYDAY': 'TUDIARYDAY',
#   'TUDIS': 'TUDIS',
#   'TUDIS1': 'TUDIS1',
#   'TUDIS2': 'TUDIS2',
#   'TUERN2': 'TUERN2',
#   'TUERNH1C': 'TUERNH1C',
#   'TUFINLWGT': 'TUFINLWGT',
#   'TUFWK': 'TUFWK',
#   'TUIO1MFG': 'TUIO1MFG',
#   'TUIODP1': 'TUIODP1',
#   'TUIODP2': 'TUIODP2',
#   'TUIODP3': 'TUIODP3',
#   'TULAY': 'TULAY',
#   'TULAY6M': 'TULAY6M',
#   'TULAYAVR': 'TULAYAVR',
#   'TULAYDT': 'TULAYDT',
#   'TULK': 'TULK',
#   'TULKAVR': 'TULKAVR',
#   'TULKDK1': 'TULKDK1',
#   'TULKDK2': 'TULKDK2',
#   'TULKDK3': 'TULKDK3',
#   'TULKDK4': 'TULKDK4',
#   'TULKDK5': 'TULKDK5',
#   'TULKDK6': 'TULKDK6',
#   'TULKM2': 'TULKM2',
#   'TULKM3': 'TULKM3',
#   'TULKM4': 'TULKM4',
#   'TULKM5': 'TULKM5',
#   'TULKM6': 'TULKM6',
#   'TULKPS1': 'TULKPS1',
#   'TULKPS2': 'TULKPS2',
#   'TULKPS3': 'TULKPS3',
#   'TULKPS4': 'TULKPS4',
#   'TULKPS5': 'TULKPS5',
#   'TULKPS6': 'TULKPS6',
#   'TURETOT': 'TURETOT',
#   'TUSPABS': 'TUSPABS',
#   'TUSPUSFT': 'TUSPUSFT',
#   'TUSPWK': 'TUSPWK',
#   'TXABSRSN': 'TXABSRSN',
#   'TXERN': 'TXERN',
#   'TXERNH1O': 'TXERNH1O',
#   'TXERNH2': 'TXERNH2',
#   'TXERNHRO': 'TXERNHRO',
#   'TXERNHRY': 'TXERNHRY',
#   'TXERNPER': 'TXERNPER',
#   'TXERNRT': 'TXERNRT',
#   'TXERNUOT': 'TXERNUOT',
#   'TXERNWKP': 'TXERNWKP',
#   'TXHRFTPT': 'TXHRFTPT',
#   'TXHRUSL1': 'TXHRUSL1',
#   'TXHRUSL2': 'TXHRUSL2',
#   'TXHRUSLT': 'TXHRUSLT',
#   'TXIO1COW': 'TXIO1COW',
#   'TXIO1ICD': 'TXIO1ICD',
#   'TXIO1OCD': 'TXIO1OCD',
#   'TXLAYAVL': 'TXLAYAVL',
#   'TXLAYLK': 'TXLAYLK',
#   'TXLFS': 'TXLFS',
#   'TXLKAVL': 'TXLKAVL',
#   'TXLKM1': 'TXLKM1',
#   'TXMJOT': 'TXMJOT',
#   'TXRET1': 'TXRET1',
#   'TXSCHENR': 'TXSCHENR',
#   'TXSCHFT': 'TXSCHFT',
#   'TXSCHLVL': 'TXSCHLVL',
#   'TXSPEMPNOT': 'TXSPEMPNOT',
#   'TXSPUHRS': 'TXSPUHRS',
#   'TXTCC': 'TXTCC',
#   'TXTCCTOT': 'TXTCCTOT',
#   'TXTCOC': 'TXTCOC',
#   'TXTHH': 'TXTHH',
#   'TXTNOHH': 'TXTNOHH',
#   'TXTO': 'TXTO',
#   'TXTOHH': 'TXTOHH',
#   'TXTONHH': 'TXTONHH'},
#  './data/atusresp_2008.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TUYEAR': 'TUYEAR',
#   'TUMONTH': 'TUMONTH',
#   'TEABSRSN': 'TEABSRSN',
#   'TEERN': 'TEERN',
#   'TEERNH1O': 'TEERNH1O',
#   'TEERNH2': 'TEERNH2',
#   'TEERNHRO': 'TEERNHRO',
#   'TEERNHRY': 'TEERNHRY',
#   'TEERNPER': 'TEERNPER',
#   'TEERNRT': 'TEERNRT',
#   'TEERNUOT': 'TEERNUOT',
#   'TEERNWKP': 'TEERNWKP',
#   'TEHRFTPT': 'TEHRFTPT',
#   'TEHRUSL1': 'TEHRUSL1',
#   'TEHRUSL2': 'TEHRUSL2',
#   'TEHRUSLT': 'TEHRUSLT',
#   'TEIO1COW': 'TEIO1COW',
#   'TEIO1ICD': 'TEIO1ICD',
#   'TEIO1OCD': 'TEIO1OCD',
#   'TELAYAVL': 'TELAYAVL',
#   'TELAYLK': 'TELAYLK',
#   'TELFS': 'TELFS',
#   'TELKAVL': 'TELKAVL',
#   'TELKM1': 'TELKM1',
#   'TEMJOT': 'TEMJOT',
#   'TERET1': 'TERET1',
#   'TESCHENR': 'TESCHENR',
#   'TESCHFT': 'TESCHFT',
#   'TESCHLVL': 'TESCHLVL',
#   'TESPEMPNOT': 'TESPEMPNOT',
#   'TESPUHRS': 'TESPUHRS',
#   'TRCHILDNUM': 'TRCHILDNUM',
#   'TRDPFTPT': 'TRDPFTPT',
#   'TRDTIND1': 'TRDTIND1',
#   'TRDTOCC1': 'TRDTOCC1',
#   'TREMODR': 'TREMODR',
#   'TRERNHLY': 'TRERNHLY',
#   'TRERNUPD': 'TRERNUPD',
#   'TRERNWA': 'TRERNWA',
#   'TRHERNAL': 'TRHERNAL',
#   'TRHHCHILD': 'TRHHCHILD',
#   'TRHOLIDAY': 'TRHOLIDAY',
#   'TRIMIND1': 'TRIMIND1',
#   'TRMJIND1': 'TRMJIND1',
#   'TRMJOCC1': 'TRMJOCC1',
#   'TRMJOCGR': 'TRMJOCGR',
#   'TRNHHCHILD': 'TRNHHCHILD',
#   'TRNUMHOU': 'TRNUMHOU',
#   'TROHHCHILD': 'TROHHCHILD',
#   'TRSPFTPT': 'TRSPFTPT',
#   'TRSPPRES': 'TRSPPRES',
#   'TRTALONE': 'TRTALONE',
#   'TRTCC': 'TRTCC',
#   'TRTCCC': 'TRTCCC',
#   'TRTCCTOT': 'TRTCCTOT',
#   'TRTCHILD': 'TRTCHILD',
#   'TRTCOC': 'TRTCOC',
#   'TRTFAMILY': 'TRTFAMILY',
#   'TRTFRIEND': 'TRTFRIEND',
#   'TRTHH': 'TRTHH',
#   'TRTHHFAMILY': 'TRTHHFAMILY',
#   'TRTNOCHILD': 'TRTNOCHILD',
#   'TRTNOHH': 'TRTNOHH',
#   'TRTO': 'TRTO',
#   'TRTOHH': 'TRTOHH',
#   'TRTOHHCHILD': 'TRTOHHCHILD',
#   'TRTONHH': 'TRTONHH',
#   'TRTONHHCHILD': 'TRTONHHCHILD',
#   'TRTSPONLY': 'TRTSPONLY',
#   'TRTSPOUSE': 'TRTSPOUSE',
#   'TRTUNMPART': 'TRTUNMPART',
#   'TRWERNAL': 'TRWERNAL',
#   'TRYHHCHILD': 'TRYHHCHILD',
#   'TTHR': 'TTHR',
#   'TTOT': 'TTOT',
#   'TTWK': 'TTWK',
#   'TUABSOT': 'TUABSOT',
#   'TUBUS': 'TUBUS',
#   'TUBUS1': 'TUBUS1',
#   'TUBUS2OT': 'TUBUS2OT',
#   'TUBUSL1': 'TUBUSL1',
#   'TUBUSL2': 'TUBUSL2',
#   'TUBUSL3': 'TUBUSL3',
#   'TUBUSL4': 'TUBUSL4',
#   'TUBWGT': 'TUBWGT',
#   'TUCC2': 'TUCC2',
#   'TUCC4': 'TUCC4',
#   'TUCC5B_CK': 'TUCC5B_CK',
#   'TUCC5_CK': 'TUCC5_CK',
#   'TUCC9': 'TUCC9',
#   'TUDIARYDATE': 'TUDIARYDATE',
#   'TUDIARYDAY': 'TUDIARYDAY',
#   'TUDIS': 'TUDIS',
#   'TUDIS1': 'TUDIS1',
#   'TUDIS2': 'TUDIS2',
#   'TUERN2': 'TUERN2',
#   'TUERNH1C': 'TUERNH1C',
#   'TUFINLWGT': 'TUFINLWGT',
#   'TUFWK': 'TUFWK',
#   'TUIO1MFG': 'TUIO1MFG',
#   'TUIODP1': 'TUIODP1',
#   'TUIODP2': 'TUIODP2',
#   'TUIODP3': 'TUIODP3',
#   'TULAY': 'TULAY',
#   'TULAY6M': 'TULAY6M',
#   'TULAYAVR': 'TULAYAVR',
#   'TULAYDT': 'TULAYDT',
#   'TULK': 'TULK',
#   'TULKAVR': 'TULKAVR',
#   'TULKDK1': 'TULKDK1',
#   'TULKDK2': 'TULKDK2',
#   'TULKDK3': 'TULKDK3',
#   'TULKDK4': 'TULKDK4',
#   'TULKDK5': 'TULKDK5',
#   'TULKDK6': 'TULKDK6',
#   'TULKM2': 'TULKM2',
#   'TULKM3': 'TULKM3',
#   'TULKM4': 'TULKM4',
#   'TULKM5': 'TULKM5',
#   'TULKM6': 'TULKM6',
#   'TULKPS1': 'TULKPS1',
#   'TULKPS2': 'TULKPS2',
#   'TULKPS3': 'TULKPS3',
#   'TULKPS4': 'TULKPS4',
#   'TULKPS5': 'TULKPS5',
#   'TULKPS6': 'TULKPS6',
#   'TURETOT': 'TURETOT',
#   'TUSPABS': 'TUSPABS',
#   'TUSPUSFT': 'TUSPUSFT',
#   'TUSPWK': 'TUSPWK',
#   'TXABSRSN': 'TXABSRSN',
#   'TXERN': 'TXERN',
#   'TXERNH1O': 'TXERNH1O',
#   'TXERNH2': 'TXERNH2',
#   'TXERNHRO': 'TXERNHRO',
#   'TXERNHRY': 'TXERNHRY',
#   'TXERNPER': 'TXERNPER',
#   'TXERNRT': 'TXERNRT',
#   'TXERNUOT': 'TXERNUOT',
#   'TXERNWKP': 'TXERNWKP',
#   'TXHRFTPT': 'TXHRFTPT',
#   'TXHRUSL1': 'TXHRUSL1',
#   'TXHRUSL2': 'TXHRUSL2',
#   'TXHRUSLT': 'TXHRUSLT',
#   'TXIO1COW': 'TXIO1COW',
#   'TXIO1ICD': 'TXIO1ICD',
#   'TXIO1OCD': 'TXIO1OCD',
#   'TXLAYAVL': 'TXLAYAVL',
#   'TXLAYLK': 'TXLAYLK',
#   'TXLFS': 'TXLFS',
#   'TXLKAVL': 'TXLKAVL',
#   'TXLKM1': 'TXLKM1',
#   'TXMJOT': 'TXMJOT',
#   'TXRET1': 'TXRET1',
#   'TXSCHENR': 'TXSCHENR',
#   'TXSCHFT': 'TXSCHFT',
#   'TXSCHLVL': 'TXSCHLVL',
#   'TXSPEMPNOT': 'TXSPEMPNOT',
#   'TXSPUHRS': 'TXSPUHRS',
#   'TXTCC': 'TXTCC',
#   'TXTCCTOT': 'TXTCCTOT',
#   'TXTCOC': 'TXTCOC',
#   'TXTHH': 'TXTHH',
#   'TXTNOHH': 'TXTNOHH',
#   'TXTO': 'TXTO',
#   'TXTOHH': 'TXTOHH',
#   'TXTONHH': 'TXTONHH'},
#  './data/atusresp_2009.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TUYEAR': 'TUYEAR',
#   'TUMONTH': 'TUMONTH',
#   'TEABSRSN': 'TEABSRSN',
#   'TEERN': 'TEERN',
#   'TEERNH1O': 'TEERNH1O',
#   'TEERNH2': 'TEERNH2',
#   'TEERNHRO': 'TEERNHRO',
#   'TEERNHRY': 'TEERNHRY',
#   'TEERNPER': 'TEERNPER',
#   'TEERNRT': 'TEERNRT',
#   'TEERNUOT': 'TEERNUOT',
#   'TEERNWKP': 'TEERNWKP',
#   'TEHRFTPT': 'TEHRFTPT',
#   'TEHRUSL1': 'TEHRUSL1',
#   'TEHRUSL2': 'TEHRUSL2',
#   'TEHRUSLT': 'TEHRUSLT',
#   'TEIO1COW': 'TEIO1COW',
#   'TEIO1ICD': 'TEIO1ICD',
#   'TEIO1OCD': 'TEIO1OCD',
#   'TELAYAVL': 'TELAYAVL',
#   'TELAYLK': 'TELAYLK',
#   'TELFS': 'TELFS',
#   'TELKAVL': 'TELKAVL',
#   'TELKM1': 'TELKM1',
#   'TEMJOT': 'TEMJOT',
#   'TERET1': 'TERET1',
#   'TESCHENR': 'TESCHENR',
#   'TESCHFT': 'TESCHFT',
#   'TESCHLVL': 'TESCHLVL',
#   'TESPEMPNOT': 'TESPEMPNOT',
#   'TESPUHRS': 'TESPUHRS',
#   'TRCHILDNUM': 'TRCHILDNUM',
#   'TRDPFTPT': 'TRDPFTPT',
#   'TRDTIND1': 'TRDTIND1',
#   'TRDTOCC1': 'TRDTOCC1',
#   'TRERNHLY': 'TRERNHLY',
#   'TRERNUPD': 'TRERNUPD',
#   'TRERNWA': 'TRERNWA',
#   'TRHERNAL': 'TRHERNAL',
#   'TRHHCHILD': 'TRHHCHILD',
#   'TRHOLIDAY': 'TRHOLIDAY',
#   'TRIMIND1': 'TRIMIND1',
#   'TRMJIND1': 'TRMJIND1',
#   'TRMJOCC1': 'TRMJOCC1',
#   'TRMJOCGR': 'TRMJOCGR',
#   'TRNHHCHILD': 'TRNHHCHILD',
#   'TRNUMHOU': 'TRNUMHOU',
#   'TROHHCHILD': 'TROHHCHILD',
#   'TRSPFTPT': 'TRSPFTPT',
#   'TRSPPRES': 'TRSPPRES',
#   'TRTALONE': 'TRTALONE',
#   'TRTCC': 'TRTCC',
#   'TRTCCC': 'TRTCCC',
#   'TRTCCTOT': 'TRTCCTOT',
#   'TRTCHILD': 'TRTCHILD',
#   'TRTCOC': 'TRTCOC',
#   'TRTFAMILY': 'TRTFAMILY',
#   'TRTFRIEND': 'TRTFRIEND',
#   'TRTHH': 'TRTHH',
#   'TRTHHFAMILY': 'TRTHHFAMILY',
#   'TRTNOCHILD': 'TRTNOCHILD',
#   'TRTNOHH': 'TRTNOHH',
#   'TRTO': 'TRTO',
#   'TRTOHH': 'TRTOHH',
#   'TRTOHHCHILD': 'TRTOHHCHILD',
#   'TRTONHH': 'TRTONHH',
#   'TRTONHHCHILD': 'TRTONHHCHILD',
#   'TRTSPONLY': 'TRTSPONLY',
#   'TRTSPOUSE': 'TRTSPOUSE',
#   'TRTUNMPART': 'TRTUNMPART',
#   'TRWERNAL': 'TRWERNAL',
#   'TRYHHCHILD': 'TRYHHCHILD',
#   'TTHR': 'TTHR',
#   'TTOT': 'TTOT',
#   'TTWK': 'TTWK',
#   'TUABSOT': 'TUABSOT',
#   'TUBUS': 'TUBUS',
#   'TUBUS1': 'TUBUS1',
#   'TUBUS2OT': 'TUBUS2OT',
#   'TUBUSL1': 'TUBUSL1',
#   'TUBUSL2': 'TUBUSL2',
#   'TUBUSL3': 'TUBUSL3',
#   'TUBUSL4': 'TUBUSL4',
#   'TUBWGT': 'TUBWGT',
#   'TUCC2': 'TUCC2',
#   'TUCC4': 'TUCC4',
#   'TUCC5B_CK': 'TUCC5B_CK',
#   'TUCC5_CK': 'TUCC5_CK',
#   'TUCC9': 'TUCC9',
#   'TUDIARYDATE': 'TUDIARYDATE',
#   'TUDIARYDAY': 'TUDIARYDAY',
#   'TUDIS': 'TUDIS',
#   'TUDIS1': 'TUDIS1',
#   'TUDIS2': 'TUDIS2',
#   'TUERN2': 'TUERN2',
#   'TUERNH1C': 'TUERNH1C',
#   'TUFINLWGT': 'TUFINLWGT',
#   'TUFWK': 'TUFWK',
#   'TUIO1MFG': 'TUIO1MFG',
#   'TUIODP1': 'TUIODP1',
#   'TUIODP2': 'TUIODP2',
#   'TUIODP3': 'TUIODP3',
#   'TULAY': 'TULAY',
#   'TULAY6M': 'TULAY6M',
#   'TULAYAVR': 'TULAYAVR',
#   'TULAYDT': 'TULAYDT',
#   'TULK': 'TULK',
#   'TULKAVR': 'TULKAVR',
#   'TULKDK1': 'TULKDK1',
#   'TULKDK2': 'TULKDK2',
#   'TULKDK3': 'TULKDK3',
#   'TULKDK4': 'TULKDK4',
#   'TULKDK5': 'TULKDK5',
#   'TULKDK6': 'TULKDK6',
#   'TULKM2': 'TULKM2',
#   'TULKM3': 'TULKM3',
#   'TULKM4': 'TULKM4',
#   'TULKM5': 'TULKM5',
#   'TULKM6': 'TULKM6',
#   'TULKPS1': 'TULKPS1',
#   'TULKPS2': 'TULKPS2',
#   'TULKPS3': 'TULKPS3',
#   'TULKPS4': 'TULKPS4',
#   'TULKPS5': 'TULKPS5',
#   'TULKPS6': 'TULKPS6',
#   'TURETOT': 'TURETOT',
#   'TUSPABS': 'TUSPABS',
#   'TUSPUSFT': 'TUSPUSFT',
#   'TUSPWK': 'TUSPWK',
#   'TXABSRSN': 'TXABSRSN',
#   'TXERN': 'TXERN',
#   'TXERNH1O': 'TXERNH1O',
#   'TXERNH2': 'TXERNH2',
#   'TXERNHRO': 'TXERNHRO',
#   'TXERNHRY': 'TXERNHRY',
#   'TXERNPER': 'TXERNPER',
#   'TXERNRT': 'TXERNRT',
#   'TXERNUOT': 'TXERNUOT',
#   'TXERNWKP': 'TXERNWKP',
#   'TXHRFTPT': 'TXHRFTPT',
#   'TXHRUSL1': 'TXHRUSL1',
#   'TXHRUSL2': 'TXHRUSL2',
#   'TXHRUSLT': 'TXHRUSLT',
#   'TXIO1COW': 'TXIO1COW',
#   'TXIO1ICD': 'TXIO1ICD',
#   'TXIO1OCD': 'TXIO1OCD',
#   'TXLAYAVL': 'TXLAYAVL',
#   'TXLAYLK': 'TXLAYLK',
#   'TXLFS': 'TXLFS',
#   'TXLKAVL': 'TXLKAVL',
#   'TXLKM1': 'TXLKM1',
#   'TXMJOT': 'TXMJOT',
#   'TXRET1': 'TXRET1',
#   'TXSCHENR': 'TXSCHENR',
#   'TXSCHFT': 'TXSCHFT',
#   'TXSCHLVL': 'TXSCHLVL',
#   'TXSPEMPNOT': 'TXSPEMPNOT',
#   'TXSPUHRS': 'TXSPUHRS',
#   'TXTCC': 'TXTCC',
#   'TXTCCTOT': 'TXTCCTOT',
#   'TXTCOC': 'TXTCOC',
#   'TXTHH': 'TXTHH',
#   'TXTNOHH': 'TXTNOHH',
#   'TXTO': 'TXTO',
#   'TXTOHH': 'TXTOHH',
#   'TXTONHH': 'TXTONHH'},
#  './data/atusresp_2010.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TUYEAR': 'TUYEAR',
#   'TUMONTH': 'TUMONTH',
#   'TEABSRSN': 'TEABSRSN',
#   'TEERN': 'TEERN',
#   'TEERNH1O': 'TEERNH1O',
#   'TEERNH2': 'TEERNH2',
#   'TEERNHRO': 'TEERNHRO',
#   'TEERNHRY': 'TEERNHRY',
#   'TEERNPER': 'TEERNPER',
#   'TEERNRT': 'TEERNRT',
#   'TEERNUOT': 'TEERNUOT',
#   'TEERNWKP': 'TEERNWKP',
#   'TEHRFTPT': 'TEHRFTPT',
#   'TEHRUSL1': 'TEHRUSL1',
#   'TEHRUSL2': 'TEHRUSL2',
#   'TEHRUSLT': 'TEHRUSLT',
#   'TEIO1COW': 'TEIO1COW',
#   'TEIO1ICD': 'TEIO1ICD',
#   'TEIO1OCD': 'TEIO1OCD',
#   'TELAYAVL': 'TELAYAVL',
#   'TELAYLK': 'TELAYLK',
#   'TELFS': 'TELFS',
#   'TELKAVL': 'TELKAVL',
#   'TELKM1': 'TELKM1',
#   'TEMJOT': 'TEMJOT',
#   'TERET1': 'TERET1',
#   'TESCHENR': 'TESCHENR',
#   'TESCHFT': 'TESCHFT',
#   'TESCHLVL': 'TESCHLVL',
#   'TESPEMPNOT': 'TESPEMPNOT',
#   'TESPUHRS': 'TESPUHRS',
#   'TRCHILDNUM': 'TRCHILDNUM',
#   'TRDPFTPT': 'TRDPFTPT',
#   'TRDTIND1': 'TRDTIND1',
#   'TRDTOCC1': 'TRDTOCC1',
#   'TRERNHLY': 'TRERNHLY',
#   'TRERNUPD': 'TRERNUPD',
#   'TRERNWA': 'TRERNWA',
#   'TRHERNAL': 'TRHERNAL',
#   'TRHHCHILD': 'TRHHCHILD',
#   'TRHOLIDAY': 'TRHOLIDAY',
#   'TRIMIND1': 'TRIMIND1',
#   'TRMJIND1': 'TRMJIND1',
#   'TRMJOCC1': 'TRMJOCC1',
#   'TRMJOCGR': 'TRMJOCGR',
#   'TRNHHCHILD': 'TRNHHCHILD',
#   'TRNUMHOU': 'TRNUMHOU',
#   'TROHHCHILD': 'TROHHCHILD',
#   'TRSPFTPT': 'TRSPFTPT',
#   'TRSPPRES': 'TRSPPRES',
#   'TRTALONE': 'TRTALONE',
#   'TRTALONE_WK': 'TRTALONE_WK',
#   'TRTCC': 'TRTCC',
#   'TRTCCC': 'TRTCCC',
#   'TRTCCC_WK': 'TRTCCC_WK',
#   'TRTCCTOT': 'TRTCCTOT',
#   'TRTCHILD': 'TRTCHILD',
#   'TRTCOC': 'TRTCOC',
#   'TRTFAMILY': 'TRTFAMILY',
#   'TRTFRIEND': 'TRTFRIEND',
#   'TRTHH': 'TRTHH',
#   'TRTHHFAMILY': 'TRTHHFAMILY',
#   'TRTNOCHILD': 'TRTNOCHILD',
#   'TRTNOHH': 'TRTNOHH',
#   'TRTO': 'TRTO',
#   'TRTOHH': 'TRTOHH',
#   'TRTOHHCHILD': 'TRTOHHCHILD',
#   'TRTONHH': 'TRTONHH',
#   'TRTONHHCHILD': 'TRTONHHCHILD',
#   'TRTSPONLY': 'TRTSPONLY',
#   'TRTSPOUSE': 'TRTSPOUSE',
#   'TRTUNMPART': 'TRTUNMPART',
#   'TRWBMODR': 'TRWBMODR',
#   'TRWERNAL': 'TRWERNAL',
#   'TRYHHCHILD': 'TRYHHCHILD',
#   'TTHR': 'TTHR',
#   'TTOT': 'TTOT',
#   'TTWK': 'TTWK',
#   'TUABSOT': 'TUABSOT',
#   'TUBUS': 'TUBUS',
#   'TUBUS1': 'TUBUS1',
#   'TUBUS2OT': 'TUBUS2OT',
#   'TUBUSL1': 'TUBUSL1',
#   'TUBUSL2': 'TUBUSL2',
#   'TUBUSL3': 'TUBUSL3',
#   'TUBUSL4': 'TUBUSL4',
#   'TUCC2': 'TUCC2',
#   'TUCC4': 'TUCC4',
#   'TUCC5B_CK': 'TUCC5B_CK',
#   'TUCC5_CK': 'TUCC5_CK',
#   'TUCC9': 'TUCC9',
#   'TUDIARYDATE': 'TUDIARYDATE',
#   'TUDIARYDAY': 'TUDIARYDAY',
#   'TUDIS': 'TUDIS',
#   'TUDIS1': 'TUDIS1',
#   'TUDIS2': 'TUDIS2',
#   'TUERN2': 'TUERN2',
#   'TUERNH1C': 'TUERNH1C',
#   'TUFINLWGT': 'TUFINLWGT',
#   'TUFWK': 'TUFWK',
#   'TUIO1MFG': 'TUIO1MFG',
#   'TUIODP1': 'TUIODP1',
#   'TUIODP2': 'TUIODP2',
#   'TUIODP3': 'TUIODP3',
#   'TULAY': 'TULAY',
#   'TULAY6M': 'TULAY6M',
#   'TULAYAVR': 'TULAYAVR',
#   'TULAYDT': 'TULAYDT',
#   'TULK': 'TULK',
#   'TULKAVR': 'TULKAVR',
#   'TULKDK1': 'TULKDK1',
#   'TULKDK2': 'TULKDK2',
#   'TULKDK3': 'TULKDK3',
#   'TULKDK4': 'TULKDK4',
#   'TULKDK5': 'TULKDK5',
#   'TULKDK6': 'TULKDK6',
#   'TULKM2': 'TULKM2',
#   'TULKM3': 'TULKM3',
#   'TULKM4': 'TULKM4',
#   'TULKM5': 'TULKM5',
#   'TULKM6': 'TULKM6',
#   'TULKPS1': 'TULKPS1',
#   'TULKPS2': 'TULKPS2',
#   'TULKPS3': 'TULKPS3',
#   'TULKPS4': 'TULKPS4',
#   'TULKPS5': 'TULKPS5',
#   'TULKPS6': 'TULKPS6',
#   'TURETOT': 'TURETOT',
#   'TUSPABS': 'TUSPABS',
#   'TUSPUSFT': 'TUSPUSFT',
#   'TUSPWK': 'TUSPWK',
#   'TXABSRSN': 'TXABSRSN',
#   'TXERN': 'TXERN',
#   'TXERNH1O': 'TXERNH1O',
#   'TXERNH2': 'TXERNH2',
#   'TXERNHRO': 'TXERNHRO',
#   'TXERNHRY': 'TXERNHRY',
#   'TXERNPER': 'TXERNPER',
#   'TXERNRT': 'TXERNRT',
#   'TXERNUOT': 'TXERNUOT',
#   'TXERNWKP': 'TXERNWKP',
#   'TXHRFTPT': 'TXHRFTPT',
#   'TXHRUSL1': 'TXHRUSL1',
#   'TXHRUSL2': 'TXHRUSL2',
#   'TXHRUSLT': 'TXHRUSLT',
#   'TXIO1COW': 'TXIO1COW',
#   'TXIO1ICD': 'TXIO1ICD',
#   'TXIO1OCD': 'TXIO1OCD',
#   'TXLAYAVL': 'TXLAYAVL',
#   'TXLAYLK': 'TXLAYLK',
#   'TXLFS': 'TXLFS',
#   'TXLKAVL': 'TXLKAVL',
#   'TXLKM1': 'TXLKM1',
#   'TXMJOT': 'TXMJOT',
#   'TXRET1': 'TXRET1',
#   'TXSCHENR': 'TXSCHENR',
#   'TXSCHFT': 'TXSCHFT',
#   'TXSCHLVL': 'TXSCHLVL',
#   'TXSPEMPNOT': 'TXSPEMPNOT',
#   'TXSPUHRS': 'TXSPUHRS',
#   'TXTCC': 'TXTCC',
#   'TXTCCTOT': 'TXTCCTOT',
#   'TXTCOC': 'TXTCOC',
#   'TXTHH': 'TXTHH',
#   'TXTNOHH': 'TXTNOHH',
#   'TXTO': 'TXTO',
#   'TXTOHH': 'TXTOHH',
#   'TXTONHH': 'TXTONHH'},
#  './data/atusresp_2011.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TUYEAR': 'TUYEAR',
#   'TUMONTH': 'TUMONTH',
#   'TEABSRSN': 'TEABSRSN',
#   'TEERN': 'TEERN',
#   'TEERNH1O': 'TEERNH1O',
#   'TEERNH2': 'TEERNH2',
#   'TEERNHRO': 'TEERNHRO',
#   'TEERNHRY': 'TEERNHRY',
#   'TEERNPER': 'TEERNPER',
#   'TEERNRT': 'TEERNRT',
#   'TEERNUOT': 'TEERNUOT',
#   'TEERNWKP': 'TEERNWKP',
#   'TEHRFTPT': 'TEHRFTPT',
#   'TEHRUSL1': 'TEHRUSL1',
#   'TEHRUSL2': 'TEHRUSL2',
#   'TEHRUSLT': 'TEHRUSLT',
#   'TEIO1COW': 'TEIO1COW',
#   'TEIO1ICD': 'TEIO1ICD',
#   'TEIO1OCD': 'TEIO1OCD',
#   'TELAYAVL': 'TELAYAVL',
#   'TELAYLK': 'TELAYLK',
#   'TELFS': 'TELFS',
#   'TELKAVL': 'TELKAVL',
#   'TELKM1': 'TELKM1',
#   'TEMJOT': 'TEMJOT',
#   'TERET1': 'TERET1',
#   'TESCHENR': 'TESCHENR',
#   'TESCHFT': 'TESCHFT',
#   'TESCHLVL': 'TESCHLVL',
#   'TESPEMPNOT': 'TESPEMPNOT',
#   'TESPUHRS': 'TESPUHRS',
#   'TRCHILDNUM': 'TRCHILDNUM',
#   'TRDPFTPT': 'TRDPFTPT',
#   'TRDTIND1': 'TRDTIND1',
#   'TRDTOCC1': 'TRDTOCC1',
#   'TRERNHLY': 'TRERNHLY',
#   'TRERNUPD': 'TRERNUPD',
#   'TRERNWA': 'TRERNWA',
#   'TRHERNAL': 'TRHERNAL',
#   'TRHHCHILD': 'TRHHCHILD',
#   'TRHOLIDAY': 'TRHOLIDAY',
#   'TRIMIND1': 'TRIMIND1',
#   'TRLVMODR': 'TRLVMODR',
#   'TRMJIND1': 'TRMJIND1',
#   'TRMJOCC1': 'TRMJOCC1',
#   'TRMJOCGR': 'TRMJOCGR',
#   'TRNHHCHILD': 'TRNHHCHILD',
#   'TRNUMHOU': 'TRNUMHOU',
#   'TROHHCHILD': 'TROHHCHILD',
#   'TRSPFTPT': 'TRSPFTPT',
#   'TRSPPRES': 'TRSPPRES',
#   'TRTALONE': 'TRTALONE',
#   'TRTALONE_WK': 'TRTALONE_WK',
#   'TRTCC': 'TRTCC',
#   'TRTCCC': 'TRTCCC',
#   'TRTCCC_WK': 'TRTCCC_WK',
#   'TRTCCTOT': 'TRTCCTOT',
#   'TRTCHILD': 'TRTCHILD',
#   'TRTCOC': 'TRTCOC',
#   'TRTEC': 'TRTEC',
#   'TRTFAMILY': 'TRTFAMILY',
#   'TRTFRIEND': 'TRTFRIEND',
#   'TRTHH': 'TRTHH',
#   'TRTHHFAMILY': 'TRTHHFAMILY',
#   'TRTNOCHILD': 'TRTNOCHILD',
#   'TRTNOHH': 'TRTNOHH',
#   'TRTO': 'TRTO',
#   'TRTOHH': 'TRTOHH',
#   'TRTOHHCHILD': 'TRTOHHCHILD',
#   'TRTONHH': 'TRTONHH',
#   'TRTONHHCHILD': 'TRTONHHCHILD',
#   'TRTSPONLY': 'TRTSPONLY',
#   'TRTSPOUSE': 'TRTSPOUSE',
#   'TRTUNMPART': 'TRTUNMPART',
#   'TRWERNAL': 'TRWERNAL',
#   'TRYHHCHILD': 'TRYHHCHILD',
#   'TTHR': 'TTHR',
#   'TTOT': 'TTOT',
#   'TTWK': 'TTWK',
#   'TUABSOT': 'TUABSOT',
#   'TUBUS': 'TUBUS',
#   'TUBUS1': 'TUBUS1',
#   'TUBUS2OT': 'TUBUS2OT',
#   'TUBUSL1': 'TUBUSL1',
#   'TUBUSL2': 'TUBUSL2',
#   'TUBUSL3': 'TUBUSL3',
#   'TUBUSL4': 'TUBUSL4',
#   'TUCC2': 'TUCC2',
#   'TUCC4': 'TUCC4',
#   'TUCC5B_CK': 'TUCC5B_CK',
#   'TUCC5_CK': 'TUCC5_CK',
#   'TUCC9': 'TUCC9',
#   'TUDIARYDATE': 'TUDIARYDATE',
#   'TUDIARYDAY': 'TUDIARYDAY',
#   'TUDIS': 'TUDIS',
#   'TUDIS1': 'TUDIS1',
#   'TUDIS2': 'TUDIS2',
#   'TUECYTD': 'TUECYTD',
#   'TUELDER': 'TUELDER',
#   'TUELFREQ': 'TUELFREQ',
#   'TUELNUM': 'TUELNUM',
#   'TUERN2': 'TUERN2',
#   'TUERNH1C': 'TUERNH1C',
#   'TUFINLWGT': 'TUFINLWGT',
#   'TUFWK': 'TUFWK',
#   'TUIO1MFG': 'TUIO1MFG',
#   'TUIODP1': 'TUIODP1',
#   'TUIODP2': 'TUIODP2',
#   'TUIODP3': 'TUIODP3',
#   'TULAY': 'TULAY',
#   'TULAY6M': 'TULAY6M',
#   'TULAYAVR': 'TULAYAVR',
#   'TULAYDT': 'TULAYDT',
#   'TULK': 'TULK',
#   'TULKAVR': 'TULKAVR',
#   'TULKDK1': 'TULKDK1',
#   'TULKDK2': 'TULKDK2',
#   'TULKDK3': 'TULKDK3',
#   'TULKDK4': 'TULKDK4',
#   'TULKDK5': 'TULKDK5',
#   'TULKDK6': 'TULKDK6',
#   'TULKM2': 'TULKM2',
#   'TULKM3': 'TULKM3',
#   'TULKM4': 'TULKM4',
#   'TULKM5': 'TULKM5',
#   'TULKM6': 'TULKM6',
#   'TULKPS1': 'TULKPS1',
#   'TULKPS2': 'TULKPS2',
#   'TULKPS3': 'TULKPS3',
#   'TULKPS4': 'TULKPS4',
#   'TULKPS5': 'TULKPS5',
#   'TULKPS6': 'TULKPS6',
#   'TURETOT': 'TURETOT',
#   'TUSPABS': 'TUSPABS',
#   'TUSPUSFT': 'TUSPUSFT',
#   'TUSPWK': 'TUSPWK',
#   'TXABSRSN': 'TXABSRSN',
#   'TXERN': 'TXERN',
#   'TXERNH1O': 'TXERNH1O',
#   'TXERNH2': 'TXERNH2',
#   'TXERNHRO': 'TXERNHRO',
#   'TXERNHRY': 'TXERNHRY',
#   'TXERNPER': 'TXERNPER',
#   'TXERNRT': 'TXERNRT',
#   'TXERNUOT': 'TXERNUOT',
#   'TXERNWKP': 'TXERNWKP',
#   'TXHRFTPT': 'TXHRFTPT',
#   'TXHRUSL1': 'TXHRUSL1',
#   'TXHRUSL2': 'TXHRUSL2',
#   'TXHRUSLT': 'TXHRUSLT',
#   'TXIO1COW': 'TXIO1COW',
#   'TXIO1ICD': 'TXIO1ICD',
#   'TXIO1OCD': 'TXIO1OCD',
#   'TXLAYAVL': 'TXLAYAVL',
#   'TXLAYLK': 'TXLAYLK',
#   'TXLFS': 'TXLFS',
#   'TXLKAVL': 'TXLKAVL',
#   'TXLKM1': 'TXLKM1',
#   'TXMJOT': 'TXMJOT',
#   'TXRET1': 'TXRET1',
#   'TXSCHENR': 'TXSCHENR',
#   'TXSCHFT': 'TXSCHFT',
#   'TXSCHLVL': 'TXSCHLVL',
#   'TXSPEMPNOT': 'TXSPEMPNOT',
#   'TXSPUHRS': 'TXSPUHRS',
#   'TXTCC': 'TXTCC',
#   'TXTCCTOT': 'TXTCCTOT',
#   'TXTCOC': 'TXTCOC',
#   'TXTHH': 'TXTHH',
#   'TXTNOHH': 'TXTNOHH',
#   'TXTO': 'TXTO',
#   'TXTOHH': 'TXTOHH',
#   'TXTONHH': 'TXTONHH'},
#  './data/atusresp_2012.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TUYEAR': 'TUYEAR',
#   'TUMONTH': 'TUMONTH',
#   'TEABSRSN': 'TEABSRSN',
#   'TEERN': 'TEERN',
#   'TEERNH1O': 'TEERNH1O',
#   'TEERNH2': 'TEERNH2',
#   'TEERNHRO': 'TEERNHRO',
#   'TEERNHRY': 'TEERNHRY',
#   'TEERNPER': 'TEERNPER',
#   'TEERNRT': 'TEERNRT',
#   'TEERNUOT': 'TEERNUOT',
#   'TEERNWKP': 'TEERNWKP',
#   'TEHRFTPT': 'TEHRFTPT',
#   'TEHRUSL1': 'TEHRUSL1',
#   'TEHRUSL2': 'TEHRUSL2',
#   'TEHRUSLT': 'TEHRUSLT',
#   'TEIO1COW': 'TEIO1COW',
#   'TEIO1ICD': 'TEIO1ICD',
#   'TEIO1OCD': 'TEIO1OCD',
#   'TELAYAVL': 'TELAYAVL',
#   'TELAYLK': 'TELAYLK',
#   'TELFS': 'TELFS',
#   'TELKAVL': 'TELKAVL',
#   'TELKM1': 'TELKM1',
#   'TEMJOT': 'TEMJOT',
#   'TERET1': 'TERET1',
#   'TESCHENR': 'TESCHENR',
#   'TESCHFT': 'TESCHFT',
#   'TESCHLVL': 'TESCHLVL',
#   'TESPEMPNOT': 'TESPEMPNOT',
#   'TESPUHRS': 'TESPUHRS',
#   'TRCHILDNUM': 'TRCHILDNUM',
#   'TRDPFTPT': 'TRDPFTPT',
#   'TRDTIND1': 'TRDTIND1',
#   'TRDTOCC1': 'TRDTOCC1',
#   'TRERNHLY': 'TRERNHLY',
#   'TRERNUPD': 'TRERNUPD',
#   'TRERNWA': 'TRERNWA',
#   'TRHERNAL': 'TRHERNAL',
#   'TRHHCHILD': 'TRHHCHILD',
#   'TRHOLIDAY': 'TRHOLIDAY',
#   'TRIMIND1': 'TRIMIND1',
#   'TRMJIND1': 'TRMJIND1',
#   'TRMJOCC1': 'TRMJOCC1',
#   'TRMJOCGR': 'TRMJOCGR',
#   'TRNHHCHILD': 'TRNHHCHILD',
#   'TRNUMHOU': 'TRNUMHOU',
#   'TROHHCHILD': 'TROHHCHILD',
#   'TRSPFTPT': 'TRSPFTPT',
#   'TRSPPRES': 'TRSPPRES',
#   'TRTALONE': 'TRTALONE',
#   'TRTALONE_WK': 'TRTALONE_WK',
#   'TRTCC': 'TRTCC',
#   'TRTCCC': 'TRTCCC',
#   'TRTCCC_WK': 'TRTCCC_WK',
#   'TRTCCTOT': 'TRTCCTOT',
#   'TRTCHILD': 'TRTCHILD',
#   'TRTCOC': 'TRTCOC',
#   'TRTEC': 'TRTEC',
#   'TRTFAMILY': 'TRTFAMILY',
#   'TRTFRIEND': 'TRTFRIEND',
#   'TRTHH': 'TRTHH',
#   'TRTHHFAMILY': 'TRTHHFAMILY',
#   'TRTNOCHILD': 'TRTNOCHILD',
#   'TRTNOHH': 'TRTNOHH',
#   'TRTO': 'TRTO',
#   'TRTOHH': 'TRTOHH',
#   'TRTOHHCHILD': 'TRTOHHCHILD',
#   'TRTONHH': 'TRTONHH',
#   'TRTONHHCHILD': 'TRTONHHCHILD',
#   'TRTSPONLY': 'TRTSPONLY',
#   'TRTSPOUSE': 'TRTSPOUSE',
#   'TRTUNMPART': 'TRTUNMPART',
#   'TRWBMODR': 'TRWBMODR',
#   'TRWERNAL': 'TRWERNAL',
#   'TRYHHCHILD': 'TRYHHCHILD',
#   'TTHR': 'TTHR',
#   'TTOT': 'TTOT',
#   'TTWK': 'TTWK',
#   'TUABSOT': 'TUABSOT',
#   'TUBUS': 'TUBUS',
#   'TUBUS1': 'TUBUS1',
#   'TUBUS2OT': 'TUBUS2OT',
#   'TUBUSL1': 'TUBUSL1',
#   'TUBUSL2': 'TUBUSL2',
#   'TUBUSL3': 'TUBUSL3',
#   'TUBUSL4': 'TUBUSL4',
#   'TUCC2': 'TUCC2',
#   'TUCC4': 'TUCC4',
#   'TUCC5B_CK': 'TUCC5B_CK',
#   'TUCC5_CK': 'TUCC5_CK',
#   'TUCC9': 'TUCC9',
#   'TUDIARYDATE': 'TUDIARYDATE',
#   'TUDIARYDAY': 'TUDIARYDAY',
#   'TUDIS': 'TUDIS',
#   'TUDIS1': 'TUDIS1',
#   'TUDIS2': 'TUDIS2',
#   'TUECYTD': 'TUECYTD',
#   'TUELDER': 'TUELDER',
#   'TUELFREQ': 'TUELFREQ',
#   'TUELNUM': 'TUELNUM',
#   'TUERN2': 'TUERN2',
#   'TUERNH1C': 'TUERNH1C',
#   'TUFINLWGT': 'TUFINLWGT',
#   'TUFWK': 'TUFWK',
#   'TUIO1MFG': 'TUIO1MFG',
#   'TUIODP1': 'TUIODP1',
#   'TUIODP2': 'TUIODP2',
#   'TUIODP3': 'TUIODP3',
#   'TULAY': 'TULAY',
#   'TULAY6M': 'TULAY6M',
#   'TULAYAVR': 'TULAYAVR',
#   'TULAYDT': 'TULAYDT',
#   'TULK': 'TULK',
#   'TULKAVR': 'TULKAVR',
#   'TULKDK1': 'TULKDK1',
#   'TULKDK2': 'TULKDK2',
#   'TULKDK3': 'TULKDK3',
#   'TULKDK4': 'TULKDK4',
#   'TULKDK5': 'TULKDK5',
#   'TULKDK6': 'TULKDK6',
#   'TULKM2': 'TULKM2',
#   'TULKM3': 'TULKM3',
#   'TULKM4': 'TULKM4',
#   'TULKM5': 'TULKM5',
#   'TULKM6': 'TULKM6',
#   'TULKPS1': 'TULKPS1',
#   'TULKPS2': 'TULKPS2',
#   'TULKPS3': 'TULKPS3',
#   'TULKPS4': 'TULKPS4',
#   'TULKPS5': 'TULKPS5',
#   'TULKPS6': 'TULKPS6',
#   'TURETOT': 'TURETOT',
#   'TUSPABS': 'TUSPABS',
#   'TUSPUSFT': 'TUSPUSFT',
#   'TUSPWK': 'TUSPWK',
#   'TXABSRSN': 'TXABSRSN',
#   'TXERN': 'TXERN',
#   'TXERNH1O': 'TXERNH1O',
#   'TXERNH2': 'TXERNH2',
#   'TXERNHRO': 'TXERNHRO',
#   'TXERNHRY': 'TXERNHRY',
#   'TXERNPER': 'TXERNPER',
#   'TXERNRT': 'TXERNRT',
#   'TXERNUOT': 'TXERNUOT',
#   'TXERNWKP': 'TXERNWKP',
#   'TXHRFTPT': 'TXHRFTPT',
#   'TXHRUSL1': 'TXHRUSL1',
#   'TXHRUSL2': 'TXHRUSL2',
#   'TXHRUSLT': 'TXHRUSLT',
#   'TXIO1COW': 'TXIO1COW',
#   'TXIO1ICD': 'TXIO1ICD',
#   'TXIO1OCD': 'TXIO1OCD',
#   'TXLAYAVL': 'TXLAYAVL',
#   'TXLAYLK': 'TXLAYLK',
#   'TXLFS': 'TXLFS',
#   'TXLKAVL': 'TXLKAVL',
#   'TXLKM1': 'TXLKM1',
#   'TXMJOT': 'TXMJOT',
#   'TXRET1': 'TXRET1',
#   'TXSCHENR': 'TXSCHENR',
#   'TXSCHFT': 'TXSCHFT',
#   'TXSCHLVL': 'TXSCHLVL',
#   'TXSPEMPNOT': 'TXSPEMPNOT',
#   'TXSPUHRS': 'TXSPUHRS',
#   'TXTCC': 'TXTCC',
#   'TXTCCTOT': 'TXTCCTOT',
#   'TXTCOC': 'TXTCOC',
#   'TXTHH': 'TXTHH',
#   'TXTNOHH': 'TXTNOHH',
#   'TXTO': 'TXTO',
#   'TXTOHH': 'TXTOHH',
#   'TXTONHH': 'TXTONHH'},
#  './data/atusresp_2013.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TUYEAR': 'TUYEAR',
#   'TUMONTH': 'TUMONTH',
#   'TEABSRSN': 'TEABSRSN',
#   'TEERN': 'TEERN',
#   'TEERNH1O': 'TEERNH1O',
#   'TEERNH2': 'TEERNH2',
#   'TEERNHRO': 'TEERNHRO',
#   'TEERNHRY': 'TEERNHRY',
#   'TEERNPER': 'TEERNPER',
#   'TEERNRT': 'TEERNRT',
#   'TEERNUOT': 'TEERNUOT',
#   'TEERNWKP': 'TEERNWKP',
#   'TEHRFTPT': 'TEHRFTPT',
#   'TEHRUSL1': 'TEHRUSL1',
#   'TEHRUSL2': 'TEHRUSL2',
#   'TEHRUSLT': 'TEHRUSLT',
#   'TEIO1COW': 'TEIO1COW',
#   'TEIO1ICD': 'TEIO1ICD',
#   'TEIO1OCD': 'TEIO1OCD',
#   'TELAYAVL': 'TELAYAVL',
#   'TELAYLK': 'TELAYLK',
#   'TELFS': 'TELFS',
#   'TELKAVL': 'TELKAVL',
#   'TELKM1': 'TELKM1',
#   'TEMJOT': 'TEMJOT',
#   'TERET1': 'TERET1',
#   'TESCHENR': 'TESCHENR',
#   'TESCHFT': 'TESCHFT',
#   'TESCHLVL': 'TESCHLVL',
#   'TESPEMPNOT': 'TESPEMPNOT',
#   'TESPUHRS': 'TESPUHRS',
#   'TRCHILDNUM': 'TRCHILDNUM',
#   'TRDPFTPT': 'TRDPFTPT',
#   'TRDTIND1': 'TRDTIND1',
#   'TRDTOCC1': 'TRDTOCC1',
#   'TRERNHLY': 'TRERNHLY',
#   'TRERNUPD': 'TRERNUPD',
#   'TRERNWA': 'TRERNWA',
#   'TRHERNAL': 'TRHERNAL',
#   'TRHHCHILD': 'TRHHCHILD',
#   'TRHOLIDAY': 'TRHOLIDAY',
#   'TRIMIND1': 'TRIMIND1',
#   'TRMJIND1': 'TRMJIND1',
#   'TRMJOCC1': 'TRMJOCC1',
#   'TRMJOCGR': 'TRMJOCGR',
#   'TRNHHCHILD': 'TRNHHCHILD',
#   'TRNUMHOU': 'TRNUMHOU',
#   'TROHHCHILD': 'TROHHCHILD',
#   'TRSPFTPT': 'TRSPFTPT',
#   'TRSPPRES': 'TRSPPRES',
#   'TRTALONE': 'TRTALONE',
#   'TRTALONE_WK': 'TRTALONE_WK',
#   'TRTCC': 'TRTCC',
#   'TRTCCC': 'TRTCCC',
#   'TRTCCC_WK': 'TRTCCC_WK',
#   'TRTCCTOT': 'TRTCCTOT',
#   'TRTCHILD': 'TRTCHILD',
#   'TRTCOC': 'TRTCOC',
#   'TRTEC': 'TRTEC',
#   'TRTFAMILY': 'TRTFAMILY',
#   'TRTFRIEND': 'TRTFRIEND',
#   'TRTHH': 'TRTHH',
#   'TRTHHFAMILY': 'TRTHHFAMILY',
#   'TRTNOCHILD': 'TRTNOCHILD',
#   'TRTNOHH': 'TRTNOHH',
#   'TRTO': 'TRTO',
#   'TRTOHH': 'TRTOHH',
#   'TRTOHHCHILD': 'TRTOHHCHILD',
#   'TRTONHH': 'TRTONHH',
#   'TRTONHHCHILD': 'TRTONHHCHILD',
#   'TRTSPONLY': 'TRTSPONLY',
#   'TRTSPOUSE': 'TRTSPOUSE',
#   'TRTUNMPART': 'TRTUNMPART',
#   'TRWBMODR': 'TRWBMODR',
#   'TRWERNAL': 'TRWERNAL',
#   'TRYHHCHILD': 'TRYHHCHILD',
#   'TTHR': 'TTHR',
#   'TTOT': 'TTOT',
#   'TTWK': 'TTWK',
#   'TUABSOT': 'TUABSOT',
#   'TUBUS': 'TUBUS',
#   'TUBUS1': 'TUBUS1',
#   'TUBUS2OT': 'TUBUS2OT',
#   'TUBUSL1': 'TUBUSL1',
#   'TUBUSL2': 'TUBUSL2',
#   'TUBUSL3': 'TUBUSL3',
#   'TUBUSL4': 'TUBUSL4',
#   'TUCC2': 'TUCC2',
#   'TUCC4': 'TUCC4',
#   'TUCC5B_CK': 'TUCC5B_CK',
#   'TUCC5_CK': 'TUCC5_CK',
#   'TUCC9': 'TUCC9',
#   'TUDIARYDATE': 'TUDIARYDATE',
#   'TUDIARYDAY': 'TUDIARYDAY',
#   'TUDIS': 'TUDIS',
#   'TUDIS1': 'TUDIS1',
#   'TUDIS2': 'TUDIS2',
#   'TUECYTD': 'TUECYTD',
#   'TUELDER': 'TUELDER',
#   'TUELFREQ': 'TUELFREQ',
#   'TUELNUM': 'TUELNUM',
#   'TUERN2': 'TUERN2',
#   'TUERNH1C': 'TUERNH1C',
#   'TUFINLWGT': 'TUFINLWGT',
#   'TUFWK': 'TUFWK',
#   'TUIO1MFG': 'TUIO1MFG',
#   'TUIODP1': 'TUIODP1',
#   'TUIODP2': 'TUIODP2',
#   'TUIODP3': 'TUIODP3',
#   'TULAY': 'TULAY',
#   'TULAY6M': 'TULAY6M',
#   'TULAYAVR': 'TULAYAVR',
#   'TULAYDT': 'TULAYDT',
#   'TULK': 'TULK',
#   'TULKAVR': 'TULKAVR',
#   'TULKDK1': 'TULKDK1',
#   'TULKDK2': 'TULKDK2',
#   'TULKDK3': 'TULKDK3',
#   'TULKDK4': 'TULKDK4',
#   'TULKDK5': 'TULKDK5',
#   'TULKDK6': 'TULKDK6',
#   'TULKM2': 'TULKM2',
#   'TULKM3': 'TULKM3',
#   'TULKM4': 'TULKM4',
#   'TULKM5': 'TULKM5',
#   'TULKM6': 'TULKM6',
#   'TULKPS1': 'TULKPS1',
#   'TULKPS2': 'TULKPS2',
#   'TULKPS3': 'TULKPS3',
#   'TULKPS4': 'TULKPS4',
#   'TULKPS5': 'TULKPS5',
#   'TULKPS6': 'TULKPS6',
#   'TURETOT': 'TURETOT',
#   'TUSPABS': 'TUSPABS',
#   'TUSPUSFT': 'TUSPUSFT',
#   'TUSPWK': 'TUSPWK',
#   'TXABSRSN': 'TXABSRSN',
#   'TXERN': 'TXERN',
#   'TXERNH1O': 'TXERNH1O',
#   'TXERNH2': 'TXERNH2',
#   'TXERNHRO': 'TXERNHRO',
#   'TXERNHRY': 'TXERNHRY',
#   'TXERNPER': 'TXERNPER',
#   'TXERNRT': 'TXERNRT',
#   'TXERNUOT': 'TXERNUOT',
#   'TXERNWKP': 'TXERNWKP',
#   'TXHRFTPT': 'TXHRFTPT',
#   'TXHRUSL1': 'TXHRUSL1',
#   'TXHRUSL2': 'TXHRUSL2',
#   'TXHRUSLT': 'TXHRUSLT',
#   'TXIO1COW': 'TXIO1COW',
#   'TXIO1ICD': 'TXIO1ICD',
#   'TXIO1OCD': 'TXIO1OCD',
#   'TXLAYAVL': 'TXLAYAVL',
#   'TXLAYLK': 'TXLAYLK',
#   'TXLFS': 'TXLFS',
#   'TXLKAVL': 'TXLKAVL',
#   'TXLKM1': 'TXLKM1',
#   'TXMJOT': 'TXMJOT',
#   'TXRET1': 'TXRET1',
#   'TXSCHENR': 'TXSCHENR',
#   'TXSCHFT': 'TXSCHFT',
#   'TXSCHLVL': 'TXSCHLVL',
#   'TXSPEMPNOT': 'TXSPEMPNOT',
#   'TXSPUHRS': 'TXSPUHRS',
#   'TXTCC': 'TXTCC',
#   'TXTCCTOT': 'TXTCCTOT',
#   'TXTCOC': 'TXTCOC',
#   'TXTHH': 'TXTHH',
#   'TXTNOHH': 'TXTNOHH',
#   'TXTO': 'TXTO',
#   'TXTOHH': 'TXTOHH',
#   'TXTONHH': 'TXTONHH'},
#  './data/atusresp_2014.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TUYEAR': 'TUYEAR',
#   'TUMONTH': 'TUMONTH',
#   'TEABSRSN': 'TEABSRSN',
#   'TEERN': 'TEERN',
#   'TEERNH1O': 'TEERNH1O',
#   'TEERNH2': 'TEERNH2',
#   'TEERNHRO': 'TEERNHRO',
#   'TEERNHRY': 'TEERNHRY',
#   'TEERNPER': 'TEERNPER',
#   'TEERNRT': 'TEERNRT',
#   'TEERNUOT': 'TEERNUOT',
#   'TEERNWKP': 'TEERNWKP',
#   'TEHRFTPT': 'TEHRFTPT',
#   'TEHRUSL1': 'TEHRUSL1',
#   'TEHRUSL2': 'TEHRUSL2',
#   'TEHRUSLT': 'TEHRUSLT',
#   'TEIO1COW': 'TEIO1COW',
#   'TEIO1ICD': 'TEIO1ICD',
#   'TEIO1OCD': 'TEIO1OCD',
#   'TELAYAVL': 'TELAYAVL',
#   'TELAYLK': 'TELAYLK',
#   'TELFS': 'TELFS',
#   'TELKAVL': 'TELKAVL',
#   'TELKM1': 'TELKM1',
#   'TEMJOT': 'TEMJOT',
#   'TERET1': 'TERET1',
#   'TESCHENR': 'TESCHENR',
#   'TESCHFT': 'TESCHFT',
#   'TESCHLVL': 'TESCHLVL',
#   'TESPEMPNOT': 'TESPEMPNOT',
#   'TESPUHRS': 'TESPUHRS',
#   'TRCHILDNUM': 'TRCHILDNUM',
#   'TRDPFTPT': 'TRDPFTPT',
#   'TRDTIND1': 'TRDTIND1',
#   'TRDTOCC1': 'TRDTOCC1',
#   'TRERNHLY': 'TRERNHLY',
#   'TRERNUPD': 'TRERNUPD',
#   'TRERNWA': 'TRERNWA',
#   'TRHERNAL': 'TRHERNAL',
#   'TRHHCHILD': 'TRHHCHILD',
#   'TRHOLIDAY': 'TRHOLIDAY',
#   'TRIMIND1': 'TRIMIND1',
#   'TRMJIND1': 'TRMJIND1',
#   'TRMJOCC1': 'TRMJOCC1',
#   'TRMJOCGR': 'TRMJOCGR',
#   'TRNHHCHILD': 'TRNHHCHILD',
#   'TRNUMHOU': 'TRNUMHOU',
#   'TROHHCHILD': 'TROHHCHILD',
#   'TRSPFTPT': 'TRSPFTPT',
#   'TRSPPRES': 'TRSPPRES',
#   'TRTALONE': 'TRTALONE',
#   'TRTALONE_WK': 'TRTALONE_WK',
#   'TRTCC': 'TRTCC',
#   'TRTCCC': 'TRTCCC',
#   'TRTCCC_WK': 'TRTCCC_WK',
#   'TRTCCTOT': 'TRTCCTOT',
#   'TRTCHILD': 'TRTCHILD',
#   'TRTCOC': 'TRTCOC',
#   'TRTEC': 'TRTEC',
#   'TRTFAMILY': 'TRTFAMILY',
#   'TRTFRIEND': 'TRTFRIEND',
#   'TRTHH': 'TRTHH',
#   'TRTHHFAMILY': 'TRTHHFAMILY',
#   'TRTNOCHILD': 'TRTNOCHILD',
#   'TRTNOHH': 'TRTNOHH',
#   'TRTO': 'TRTO',
#   'TRTOHH': 'TRTOHH',
# ...
#   'TRTCC': 'TRTCC',
#   'TRTCCC': 'TRTCCC',
#   'TRTCCC_WK': 'TRTCCC_WK',
#   'TRTCCTOT': 'TRTCCTOT',
#   'TRTCHILD': 'TRTCHILD',
#   'TRTCOC': 'TRTCOC',
#   'TRTEC': 'TRTEC',
#   'TRTFAMILY': 'TRTFAMILY',
#   'TRTFRIEND': 'TRTFRIEND',
#   'TRTHH': 'TRTHH',
#   'TRTHHFAMILY': 'TRTHHFAMILY',
#   'TRTNOCHILD': 'TRTNOCHILD',
#   'TRTNOHH': 'TRTNOHH',
#   'TRTO': 'TRTO',
#   'TRTOHH': 'TRTOHH',
#   'TRTOHHCHILD': 'TRTOHHCHILD',
#   'TRTONHH': 'TRTONHH',
#   'TRTONHHCHILD': 'TRTONHHCHILD',
#   'TRTSPONLY': 'TRTSPONLY',
#   'TRTSPOUSE': 'TRTSPOUSE',
#   'TRTUNMPART': 'TRTUNMPART',
#   'TRWERNAL': 'TRWERNAL',
#   'TRYHHCHILD': 'TRYHHCHILD',
#   'TTHR': 'TTHR',
#   'TTOT': 'TTOT',
#   'TTWK': 'TTWK',
#   'TUABSOT': 'TUABSOT',
#   'TUBUS': 'TUBUS',
#   'TUBUS1': 'TUBUS1',
#   'TUBUS2OT': 'TUBUS2OT',
#   'TUBUSL1': 'TUBUSL1',
#   'TUBUSL2': 'TUBUSL2',
#   'TUBUSL3': 'TUBUSL3',
#   'TUBUSL4': 'TUBUSL4',
#   'TUCC2': 'TUCC2',
#   'TUCC4': 'TUCC4',
#   'TUCC5B_CK': 'TUCC5B_CK',
#   'TUCC5_CK': 'TUCC5_CK',
#   'TUCC9': 'TUCC9',
#   'TUDIARYDATE': 'TUDIARYDATE',
#   'TUDIARYDAY': 'TUDIARYDAY',
#   'TUDIS': 'TUDIS',
#   'TUDIS1': 'TUDIS1',
#   'TUDIS2': 'TUDIS2',
#   'TUECYTD': 'TUECYTD',
#   'TUELDER': 'TUELDER',
#   'TUELFREQ': 'TUELFREQ',
#   'TUELNUM': 'TUELNUM',
#   'TUERN2': 'TUERN2',
#   'TUERNH1C': 'TUERNH1C',
#   'TUFINLWGT': 'TUFINLWGT',
#   'TUFWK': 'TUFWK',
#   'TUIO1MFG': 'TUIO1MFG',
#   'TUIODP1': 'TUIODP1',
#   'TUIODP2': 'TUIODP2',
#   'TUIODP3': 'TUIODP3',
#   'TULAY': 'TULAY',
#   'TULAY6M': 'TULAY6M',
#   'TULAYAVR': 'TULAYAVR',
#   'TULAYDT': 'TULAYDT',
#   'TULK': 'TULK',
#   'TULKAVR': 'TULKAVR',
#   'TULKDK1': 'TULKDK1',
#   'TULKDK2': 'TULKDK2',
#   'TULKDK3': 'TULKDK3',
#   'TULKDK4': 'TULKDK4',
#   'TULKDK5': 'TULKDK5',
#   'TULKDK6': 'TULKDK6',
#   'TULKM2': 'TULKM2',
#   'TULKM3': 'TULKM3',
#   'TULKM4': 'TULKM4',
#   'TULKM5': 'TULKM5',
#   'TULKM6': 'TULKM6',
#   'TULKPS1': 'TULKPS1',
#   'TULKPS2': 'TULKPS2',
#   'TULKPS3': 'TULKPS3',
#   'TULKPS4': 'TULKPS4',
#   'TULKPS5': 'TULKPS5',
#   'TULKPS6': 'TULKPS6',
#   'TURETOT': 'TURETOT',
#   'TUSPABS': 'TUSPABS',
#   'TUSPUSFT': 'TUSPUSFT',
#   'TUSPWK': 'TUSPWK',
#   'TXABSRSN': 'TXABSRSN',
#   'TXERN': 'TXERN',
#   'TXERNH1O': 'TXERNH1O',
#   'TXERNH2': 'TXERNH2',
#   'TXERNHRO': 'TXERNHRO',
#   'TXERNHRY': 'TXERNHRY',
#   'TXERNPER': 'TXERNPER',
#   'TXERNRT': 'TXERNRT',
#   'TXERNUOT': 'TXERNUOT',
#   'TXERNWKP': 'TXERNWKP',
#   'TXHRFTPT': 'TXHRFTPT',
#   'TXHRUSL1': 'TXHRUSL1',
#   'TXHRUSL2': 'TXHRUSL2',
#   'TXHRUSLT': 'TXHRUSLT',
#   'TXIO1COW': 'TXIO1COW',
#   'TXIO1ICD': 'TXIO1ICD',
#   'TXIO1OCD': 'TXIO1OCD',
#   'TXLAYAVL': 'TXLAYAVL',
#   'TXLAYLK': 'TXLAYLK',
#   'TXLFS': 'TXLFS',
#   'TXLKAVL': 'TXLKAVL',
#   'TXLKM1': 'TXLKM1',
#   'TXMJOT': 'TXMJOT',
#   'TXRET1': 'TXRET1',
#   'TXSCHENR': 'TXSCHENR',
#   'TXSCHFT': 'TXSCHFT',
#   'TXSCHLVL': 'TXSCHLVL',
#   'TXSPEMPNOT': 'TXSPEMPNOT',
#   'TXSPUHRS': 'TXSPUHRS',
#   'TXTCC': 'TXTCC',
#   'TXTCCTOT': 'TXTCCTOT',
#   'TXTCOC': 'TXTCOC',
#   'TXTHH': 'TXTHH',
#   'TXTNOHH': 'TXTNOHH',
#   'TXTO': 'TXTO',
#   'TXTOHH': 'TXTOHH',
#   'TXTONHH': 'TXTONHH',
#   'TREMODR': 'TREMODR'},
#  './data/atusresp_2023.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TUYEAR': 'TUYEAR',
#   'TUMONTH': 'TUMONTH',
#   'TEABSRSN': 'TEABSRSN',
#   'TEERN': 'TEERN',
#   'TEERNH1O': 'TEERNH1O',
#   'TEERNH2': 'TEERNH2',
#   'TEERNHRO': 'TEERNHRO',
#   'TEERNHRY': 'TEERNHRY',
#   'TEERNPER': 'TEERNPER',
#   'TEERNRT': 'TEERNRT',
#   'TEERNUOT': 'TEERNUOT',
#   'TEERNWKP': 'TEERNWKP',
#   'TEHRFTPT': 'TEHRFTPT',
#   'TEHRUSL1': 'TEHRUSL1',
#   'TEHRUSL2': 'TEHRUSL2',
#   'TEHRUSLT': 'TEHRUSLT',
#   'TEIO1COW': 'TEIO1COW',
#   'TEIO1ICD': 'TEIO1ICD',
#   'TEIO1OCD': 'TEIO1OCD',
#   'TELAYAVL': 'TELAYAVL',
#   'TELAYLK': 'TELAYLK',
#   'TELFS': 'TELFS',
#   'TELKAVL': 'TELKAVL',
#   'TELKM1': 'TELKM1',
#   'TEMJOT': 'TEMJOT',
#   'TERET1': 'TERET1',
#   'TESCHENR': 'TESCHENR',
#   'TESCHFT': 'TESCHFT',
#   'TESCHLVL': 'TESCHLVL',
#   'TESPEMPNOT': 'TESPEMPNOT',
#   'TESPUHRS': 'TESPUHRS',
#   'TRCHILDNUM': 'TRCHILDNUM',
#   'TRDPFTPT': 'TRDPFTPT',
#   'TRDTIND1': 'TRDTIND1',
#   'TRDTOCC1': 'TRDTOCC1',
#   'TRERNHLY': 'TRERNHLY',
#   'TRERNUPD': 'TRERNUPD',
#   'TRERNWA': 'TRERNWA',
#   'TRHERNAL': 'TRHERNAL',
#   'TRHHCHILD': 'TRHHCHILD',
#   'TRHOLIDAY': 'TRHOLIDAY',
#   'TRIMIND1': 'TRIMIND1',
#   'TRMJIND1': 'TRMJIND1',
#   'TRMJOCC1': 'TRMJOCC1',
#   'TRMJOCGR': 'TRMJOCGR',
#   'TRNHHCHILD': 'TRNHHCHILD',
#   'TRNUMHOU': 'TRNUMHOU',
#   'TROHHCHILD': 'TROHHCHILD',
#   'TRSPFTPT': 'TRSPFTPT',
#   'TRSPPRES': 'TRSPPRES',
#   'TRTALONE': 'TRTALONE',
#   'TRTALONE_WK': 'TRTALONE_WK',
#   'TRTCC': 'TRTCC',
#   'TRTCCC': 'TRTCCC',
#   'TRTCCC_WK': 'TRTCCC_WK',
#   'TRTCCTOT': 'TRTCCTOT',
#   'TRTCHILD': 'TRTCHILD',
#   'TRTCOC': 'TRTCOC',
#   'TRTEC': 'TRTEC',
#   'TRTFAMILY': 'TRTFAMILY',
#   'TRTFRIEND': 'TRTFRIEND',
#   'TRTHH': 'TRTHH',
#   'TRTHHFAMILY': 'TRTHHFAMILY',
#   'TRTNOCHILD': 'TRTNOCHILD',
#   'TRTNOHH': 'TRTNOHH',
#   'TRTO': 'TRTO',
#   'TRTOHH': 'TRTOHH',
#   'TRTOHHCHILD': 'TRTOHHCHILD',
#   'TRTONHH': 'TRTONHH',
#   'TRTONHHCHILD': 'TRTONHHCHILD',
#   'TRTSPONLY': 'TRTSPONLY',
#   'TRTSPOUSE': 'TRTSPOUSE',
#   'TRTUNMPART': 'TRTUNMPART',
#   'TRWERNAL': 'TRWERNAL',
#   'TRYHHCHILD': 'TRYHHCHILD',
#   'TTHR': 'TTHR',
#   'TTOT': 'TTOT',
#   'TTWK': 'TTWK',
#   'TUABSOT': 'TUABSOT',
#   'TUBUS': 'TUBUS',
#   'TUBUS1': 'TUBUS1',
#   'TUBUS2OT': 'TUBUS2OT',
#   'TUBUSL1': 'TUBUSL1',
#   'TUBUSL2': 'TUBUSL2',
#   'TUBUSL3': 'TUBUSL3',
#   'TUBUSL4': 'TUBUSL4',
#   'TUCC2': 'TUCC2',
#   'TUCC4': 'TUCC4',
#   'TUCC5B_CK': 'TUCC5B_CK',
#   'TUCC5_CK': 'TUCC5_CK',
#   'TUCC9': 'TUCC9',
#   'TUDIARYDATE': 'TUDIARYDATE',
#   'TUDIARYDAY': 'TUDIARYDAY',
#   'TUDIS': 'TUDIS',
#   'TUDIS1': 'TUDIS1',
#   'TUDIS2': 'TUDIS2',
#   'TUECYTD': 'TUECYTD',
#   'TUELDER': 'TUELDER',
#   'TUELFREQ': 'TUELFREQ',
#   'TUELNUM': 'TUELNUM',
#   'TUERN2': 'TUERN2',
#   'TUERNH1C': 'TUERNH1C',
#   'TUFINLWGT': 'TUFINLWGT',
#   'TUFWK': 'TUFWK',
#   'TUIO1MFG': 'TUIO1MFG',
#   'TUIODP1': 'TUIODP1',
#   'TUIODP2': 'TUIODP2',
#   'TUIODP3': 'TUIODP3',
#   'TULAY': 'TULAY',
#   'TULAY6M': 'TULAY6M',
#   'TULAYAVR': 'TULAYAVR',
#   'TULAYDT': 'TULAYDT',
#   'TULK': 'TULK',
#   'TULKAVR': 'TULKAVR',
#   'TULKDK1': 'TULKDK1',
#   'TULKDK2': 'TULKDK2',
#   'TULKDK3': 'TULKDK3',
#   'TULKDK4': 'TULKDK4',
#   'TULKDK5': 'TULKDK5',
#   'TULKDK6': 'TULKDK6',
#   'TULKM2': 'TULKM2',
#   'TULKM3': 'TULKM3',
#   'TULKM4': 'TULKM4',
#   'TULKM5': 'TULKM5',
#   'TULKM6': 'TULKM6',
#   'TULKPS1': 'TULKPS1',
#   'TULKPS2': 'TULKPS2',
#   'TULKPS3': 'TULKPS3',
#   'TULKPS4': 'TULKPS4',
#   'TULKPS5': 'TULKPS5',
#   'TULKPS6': 'TULKPS6',
#   'TURETOT': 'TURETOT',
#   'TUSPABS': 'TUSPABS',
#   'TUSPUSFT': 'TUSPUSFT',
#   'TUSPWK': 'TUSPWK',
#   'TXABSRSN': 'TXABSRSN',
#   'TXERN': 'TXERN',
#   'TXERNH1O': 'TXERNH1O',
#   'TXERNH2': 'TXERNH2',
#   'TXERNHRO': 'TXERNHRO',
#   'TXERNHRY': 'TXERNHRY',
#   'TXERNPER': 'TXERNPER',
#   'TXERNRT': 'TXERNRT',
#   'TXERNUOT': 'TXERNUOT',
#   'TXERNWKP': 'TXERNWKP',
#   'TXHRFTPT': 'TXHRFTPT',
#   'TXHRUSL1': 'TXHRUSL1',
#   'TXHRUSL2': 'TXHRUSL2',
#   'TXHRUSLT': 'TXHRUSLT',
#   'TXIO1COW': 'TXIO1COW',
#   'TXIO1ICD': 'TXIO1ICD',
#   'TXIO1OCD': 'TXIO1OCD',
#   'TXLAYAVL': 'TXLAYAVL',
#   'TXLAYLK': 'TXLAYLK',
#   'TXLFS': 'TXLFS',
#   'TXLKAVL': 'TXLKAVL',
#   'TXLKM1': 'TXLKM1',
#   'TXMJOT': 'TXMJOT',
#   'TXRET1': 'TXRET1',
#   'TXSCHENR': 'TXSCHENR',
#   'TXSCHFT': 'TXSCHFT',
#   'TXSCHLVL': 'TXSCHLVL',
#   'TXSPEMPNOT': 'TXSPEMPNOT',
#   'TXSPUHRS': 'TXSPUHRS',
#   'TXTCC': 'TXTCC',
#   'TXTCCTOT': 'TXTCCTOT',
#   'TXTCOC': 'TXTCOC',
#   'TXTHH': 'TXTHH',
#   'TXTNOHH': 'TXTNOHH',
#   'TXTO': 'TXTO',
#   'TXTOHH': 'TXTOHH',
#   'TXTONHH': 'TXTONHH',
#   'TREMODR': 'TREMODR'},
#  './data/atusresp_2024.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TUYEAR': 'TUYEAR',
#   'TUMONTH': 'TUMONTH',
#   'TEABSRSN': 'TEABSRSN',
#   'TEERN': 'TEERN',
#   'TEERNH1O': 'TEERNH1O',
#   'TEERNH2': 'TEERNH2',
#   'TEERNHRO': 'TEERNHRO',
#   'TEERNHRY': 'TEERNHRY',
#   'TEERNPER': 'TEERNPER',
#   'TEERNRT': 'TEERNRT',
#   'TEERNUOT': 'TEERNUOT',
#   'TEERNWKP': 'TEERNWKP',
#   'TEHRFTPT': 'TEHRFTPT',
#   'TEHRUSL1': 'TEHRUSL1',
#   'TEHRUSL2': 'TEHRUSL2',
#   'TEHRUSLT': 'TEHRUSLT',
#   'TEIO1COW': 'TEIO1COW',
#   'TEIO1ICD': 'TEIO1ICD',
#   'TEIO1OCD': 'TEIO1OCD',
#   'TELAYAVL': 'TELAYAVL',
#   'TELAYLK': 'TELAYLK',
#   'TELFS': 'TELFS',
#   'TELKAVL': 'TELKAVL',
#   'TELKM1': 'TELKM1',
#   'TEMJOT': 'TEMJOT',
#   'TERET1': 'TERET1',
#   'TESCHENR': 'TESCHENR',
#   'TESCHFT': 'TESCHFT',
#   'TESCHLVL': 'TESCHLVL',
#   'TESPEMPNOT': 'TESPEMPNOT',
#   'TESPUHRS': 'TESPUHRS',
#   'TRCHILDNUM': 'TRCHILDNUM',
#   'TRDPFTPT': 'TRDPFTPT',
#   'TRDTIND1': 'TRDTIND1',
#   'TRDTOCC1': 'TRDTOCC1',
#   'TRERNHLY': 'TRERNHLY',
#   'TRERNUPD': 'TRERNUPD',
#   'TRERNWA': 'TRERNWA',
#   'TRHERNAL': 'TRHERNAL',
#   'TRHHCHILD': 'TRHHCHILD',
#   'TRHOLIDAY': 'TRHOLIDAY',
#   'TRIMIND1': 'TRIMIND1',
#   'TRMJIND1': 'TRMJIND1',
#   'TRMJOCC1': 'TRMJOCC1',
#   'TRMJOCGR': 'TRMJOCGR',
#   'TRNHHCHILD': 'TRNHHCHILD',
#   'TRNUMHOU': 'TRNUMHOU',
#   'TROHHCHILD': 'TROHHCHILD',
#   'TRSPFTPT': 'TRSPFTPT',
#   'TRSPPRES': 'TRSPPRES',
#   'TRTALONE': 'TRTALONE',
#   'TRTALONE_WK': 'TRTALONE_WK',
#   'TRTCC': 'TRTCC',
#   'TRTCCC': 'TRTCCC',
#   'TRTCCC_WK': 'TRTCCC_WK',
#   'TRTCCTOT': 'TRTCCTOT',
#   'TRTCHILD': 'TRTCHILD',
#   'TRTCOC': 'TRTCOC',
#   'TRTEC': 'TRTEC',
#   'TRTFAMILY': 'TRTFAMILY',
#   'TRTFRIEND': 'TRTFRIEND',
#   'TRTHH': 'TRTHH',
#   'TRTHHFAMILY': 'TRTHHFAMILY',
#   'TRTNOCHILD': 'TRTNOCHILD',
#   'TRTNOHH': 'TRTNOHH',
#   'TRTO': 'TRTO',
#   'TRTOHH': 'TRTOHH',
#   'TRTOHHCHILD': 'TRTOHHCHILD',
#   'TRTONHH': 'TRTONHH',
#   'TRTONHHCHILD': 'TRTONHHCHILD',
#   'TRTSPONLY': 'TRTSPONLY',
#   'TRTSPOUSE': 'TRTSPOUSE',
#   'TRTUNMPART': 'TRTUNMPART',
#   'TRWERNAL': 'TRWERNAL',
#   'TRYHHCHILD': 'TRYHHCHILD',
#   'TTHR': 'TTHR',
#   'TTOT': 'TTOT',
#   'TTWK': 'TTWK',
#   'TUABSOT': 'TUABSOT',
#   'TUBUS': 'TUBUS',
#   'TUBUS1': 'TUBUS1',
#   'TUBUS2OT': 'TUBUS2OT',
#   'TUBUSL1': 'TUBUSL1',
#   'TUBUSL2': 'TUBUSL2',
#   'TUBUSL3': 'TUBUSL3',
#   'TUBUSL4': 'TUBUSL4',
#   'TUCC2': 'TUCC2',
#   'TUCC4': 'TUCC4',
#   'TUCC5B_CK': 'TUCC5B_CK',
#   'TUCC5_CK': 'TUCC5_CK',
#   'TUCC9': 'TUCC9',
#   'TUDIARYDATE': 'TUDIARYDATE',
#   'TUDIARYDAY': 'TUDIARYDAY',
#   'TUDIS': 'TUDIS',
#   'TUDIS1': 'TUDIS1',
#   'TUDIS2': 'TUDIS2',
#   'TUECYTD': 'TUECYTD',
#   'TUELDER': 'TUELDER',
#   'TUELFREQ': 'TUELFREQ',
#   'TUELNUM': 'TUELNUM',
#   'TUERN2': 'TUERN2',
#   'TUERNH1C': 'TUERNH1C',
#   'TUFINLWGT': 'TUFINLWGT',
#   'TUFWK': 'TUFWK',
#   'TUIO1MFG': 'TUIO1MFG',
#   'TUIODP1': 'TUIODP1',
#   'TUIODP2': 'TUIODP2',
#   'TUIODP3': 'TUIODP3',
#   'TULAY': 'TULAY',
#   'TULAY6M': 'TULAY6M',
#   'TULAYAVR': 'TULAYAVR',
#   'TULAYDT': 'TULAYDT',
#   'TULK': 'TULK',
#   'TULKAVR': 'TULKAVR',
#   'TULKDK1': 'TULKDK1',
#   'TULKDK2': 'TULKDK2',
#   'TULKDK3': 'TULKDK3',
#   'TULKDK4': 'TULKDK4',
#   'TULKDK5': 'TULKDK5',
#   'TULKDK6': 'TULKDK6',
#   'TULKM2': 'TULKM2',
#   'TULKM3': 'TULKM3',
#   'TULKM4': 'TULKM4',
#   'TULKM5': 'TULKM5',
#   'TULKM6': 'TULKM6',
#   'TULKPS1': 'TULKPS1',
#   'TULKPS2': 'TULKPS2',
#   'TULKPS3': 'TULKPS3',
#   'TULKPS4': 'TULKPS4',
#   'TULKPS5': 'TULKPS5',
#   'TULKPS6': 'TULKPS6',
#   'TURETOT': 'TURETOT',
#   'TUSPABS': 'TUSPABS',
#   'TUSPUSFT': 'TUSPUSFT',
#   'TUSPWK': 'TUSPWK',
#   'TXABSRSN': 'TXABSRSN',
#   'TXERN': 'TXERN',
#   'TXERNH1O': 'TXERNH1O',
#   'TXERNH2': 'TXERNH2',
#   'TXERNHRO': 'TXERNHRO',
#   'TXERNHRY': 'TXERNHRY',
#   'TXERNPER': 'TXERNPER',
#   'TXERNRT': 'TXERNRT',
#   'TXERNUOT': 'TXERNUOT',
#   'TXERNWKP': 'TXERNWKP',
#   'TXHRFTPT': 'TXHRFTPT',
#   'TXHRUSL1': 'TXHRUSL1',
#   'TXHRUSL2': 'TXHRUSL2',
#   'TXHRUSLT': 'TXHRUSLT',
#   'TXIO1COW': 'TXIO1COW',
#   'TXIO1ICD': 'TXIO1ICD',
#   'TXIO1OCD': 'TXIO1OCD',
#   'TXLAYAVL': 'TXLAYAVL',
#   'TXLAYLK': 'TXLAYLK',
#   'TXLFS': 'TXLFS',
#   'TXLKAVL': 'TXLKAVL',
#   'TXLKM1': 'TXLKM1',
#   'TXMJOT': 'TXMJOT',
#   'TXRET1': 'TXRET1',
#   'TXSCHENR': 'TXSCHENR',
#   'TXSCHFT': 'TXSCHFT',
#   'TXSCHLVL': 'TXSCHLVL',
#   'TXSPEMPNOT': 'TXSPEMPNOT',
#   'TXSPUHRS': 'TXSPUHRS',
#   'TXTCC': 'TXTCC',
#   'TXTCCTOT': 'TXTCCTOT',
#   'TXTCOC': 'TXTCOC',
#   'TXTHH': 'TXTHH',
#   'TXTNOHH': 'TXTNOHH',
#   'TXTO': 'TXTO',
#   'TXTOHH': 'TXTOHH',
#   'TXTONHH': 'TXTONHH',
#   'TRLVMODR': 'TRLVMODR'},
#  './data/atusresp_2016/atusresp_2016.dat': {'TUCASEID': 'TUCASEID',
#   'TULINENO': 'TULINENO',
#   'TUYEAR': 'TUYEAR',
#   'TUMONTH': 'TUMONTH',
#   'TEABSRSN': 'TEABSRSN',
#   'TEERN': 'TEERN',
#   'TEERNH1O': 'TEERNH1O',
#   'TEERNH2': 'TEERNH2',
#   'TEERNHRO': 'TEERNHRO',
#   'TEERNHRY': 'TEERNHRY',
#   'TEERNPER': 'TEERNPER',
#   'TEERNRT': 'TEERNRT',
#   'TEERNUOT': 'TEERNUOT',
#   'TEERNWKP': 'TEERNWKP',
#   'TEHRFTPT': 'TEHRFTPT',
#   'TEHRUSL1': 'TEHRUSL1',
#   'TEHRUSL2': 'TEHRUSL2',
#   'TEHRUSLT': 'TEHRUSLT',
#   'TEIO1COW': 'TEIO1COW',
#   'TEIO1ICD': 'TEIO1ICD',
#   'TEIO1OCD': 'TEIO1OCD',
#   'TELAYAVL': 'TELAYAVL',
#   'TELAYLK': 'TELAYLK',
#   'TELFS': 'TELFS',
#   'TELKAVL': 'TELKAVL',
#   'TELKM1': 'TELKM1',
#   'TEMJOT': 'TEMJOT',
#   'TERET1': 'TERET1',
#   'TESCHENR': 'TESCHENR',
#   'TESCHFT': 'TESCHFT',
#   'TESCHLVL': 'TESCHLVL',
#   'TESPEMPNOT': 'TESPEMPNOT',
#   'TESPUHRS': 'TESPUHRS',
#   'TRCHILDNUM': 'TRCHILDNUM',
#   'TRDPFTPT': 'TRDPFTPT',
#   'TRDTIND1': 'TRDTIND1',
#   'TRDTOCC1': 'TRDTOCC1',
#   'TRERNHLY': 'TRERNHLY',
#   'TRERNUPD': 'TRERNUPD',
#   'TRERNWA': 'TRERNWA',
#   'TRHERNAL': 'TRHERNAL',
#   'TRHHCHILD': 'TRHHCHILD',
#   'TRHOLIDAY': 'TRHOLIDAY',
#   'TRIMIND1': 'TRIMIND1',
#   'TRMJIND1': 'TRMJIND1',
#   'TRMJOCC1': 'TRMJOCC1',
#   'TRMJOCGR': 'TRMJOCGR',
#   'TRNHHCHILD': 'TRNHHCHILD',
#   'TRNUMHOU': 'TRNUMHOU',
#   'TROHHCHILD': 'TROHHCHILD',
#   'TRSPFTPT': 'TRSPFTPT',
#   'TRSPPRES': 'TRSPPRES',
#   'TRTALONE': 'TRTALONE',
#   'TRTALONE_WK': 'TRTALONE_WK',
#   'TRTCC': 'TRTCC',
#   'TRTCCC': 'TRTCCC',
#   'TRTCCC_WK': 'TRTCCC_WK',
#   'TRTCCTOT': 'TRTCCTOT',
#   'TRTCHILD': 'TRTCHILD',
#   'TRTCOC': 'TRTCOC',
#   'TRTEC': 'TRTEC',
#   'TRTFAMILY': 'TRTFAMILY',
#   'TRTFRIEND': 'TRTFRIEND',
#   'TRTHH': 'TRTHH',
#   'TRTHHFAMILY': 'TRTHHFAMILY',
#   'TRTNOCHILD': 'TRTNOCHILD',
#   'TRTNOHH': 'TRTNOHH',
#   'TRTO': 'TRTO',
#   'TRTOHH': 'TRTOHH',
#   'TRTOHHCHILD': 'TRTOHHCHILD',
#   'TRTONHH': 'TRTONHH',
#   'TRTONHHCHILD': 'TRTONHHCHILD',
#   'TRTSPONLY': 'TRTSPONLY',
#   'TRTSPOUSE': 'TRTSPOUSE',
#   'TRTUNMPART': 'TRTUNMPART',
#   'TREMODR': 'TREMODR',
#   'TRWERNAL': 'TRWERNAL',
#   'TRYHHCHILD': 'TRYHHCHILD',
#   'TTHR': 'TTHR',
#   'TTOT': 'TTOT',
#   'TTWK': 'TTWK',
#   'TUABSOT': 'TUABSOT',
#   'TUBUS': 'TUBUS',
#   'TUBUS1': 'TUBUS1',
#   'TUBUS2OT': 'TUBUS2OT',
#   'TUBUSL1': 'TUBUSL1',
#   'TUBUSL2': 'TUBUSL2',
#   'TUBUSL3': 'TUBUSL3',
#   'TUBUSL4': 'TUBUSL4',
#   'TUCC2': 'TUCC2',
#   'TUCC4': 'TUCC4',
#   'TUCC5B_CK': 'TUCC5B_CK',
#   'TUCC5_CK': 'TUCC5_CK',
#   'TUCC9': 'TUCC9',
#   'TUDIARYDATE': 'TUDIARYDATE',
#   'TUDIARYDAY': 'TUDIARYDAY',
#   'TUDIS': 'TUDIS',
#   'TUDIS1': 'TUDIS1',
#   'TUDIS2': 'TUDIS2',
#   'TUECYTD': 'TUECYTD',
#   'TUELDER': 'TUELDER',
#   'TUELFREQ': 'TUELFREQ',
#   'TUELNUM': 'TUELNUM',
#   'TUERN2': 'TUERN2',
#   'TUERNH1C': 'TUERNH1C',
#   'TUFINLWGT': 'TUFINLWGT',
#   'TUFWK': 'TUFWK',
#   'TUIO1MFG': 'TUIO1MFG',
#   'TUIODP1': 'TUIODP1',
#   'TUIODP2': 'TUIODP2',
#   'TUIODP3': 'TUIODP3',
#   'TULAY': 'TULAY',
#   'TULAY6M': 'TULAY6M',
#   'TULAYAVR': 'TULAYAVR',
#   'TULAYDT': 'TULAYDT',
#   'TULK': 'TULK',
#   'TULKAVR': 'TULKAVR',
#   'TULKDK1': 'TULKDK1',
#   'TULKDK2': 'TULKDK2',
#   'TULKDK3': 'TULKDK3',
#   'TULKDK4': 'TULKDK4',
#   'TULKDK5': 'TULKDK5',
#   'TULKDK6': 'TULKDK6',
#   'TULKM2': 'TULKM2',
#   'TULKM3': 'TULKM3',
#   'TULKM4': 'TULKM4',
#   'TULKM5': 'TULKM5',
#   'TULKM6': 'TULKM6',
#   'TULKPS1': 'TULKPS1',
#   'TULKPS2': 'TULKPS2',
#   'TULKPS3': 'TULKPS3',
#   'TULKPS4': 'TULKPS4',
#   'TULKPS5': 'TULKPS5',
#   'TULKPS6': 'TULKPS6',
#   'TURETOT': 'TURETOT',
#   'TUSPABS': 'TUSPABS',
#   'TUSPUSFT': 'TUSPUSFT',
#   'TUSPWK': 'TUSPWK',
#   'TXABSRSN': 'TXABSRSN',
#   'TXERN': 'TXERN',
#   'TXERNH1O': 'TXERNH1O',
#   'TXERNH2': 'TXERNH2',
#   'TXERNHRO': 'TXERNHRO',
#   'TXERNHRY': 'TXERNHRY',
#   'TXERNPER': 'TXERNPER',
#   'TXERNRT': 'TXERNRT',
#   'TXERNUOT': 'TXERNUOT',
#   'TXERNWKP': 'TXERNWKP',
#   'TXHRFTPT': 'TXHRFTPT',
#   'TXHRUSL1': 'TXHRUSL1',
#   'TXHRUSL2': 'TXHRUSL2',
#   'TXHRUSLT': 'TXHRUSLT',
#   'TXIO1COW': 'TXIO1COW',
#   'TXIO1ICD': 'TXIO1ICD',
#   'TXIO1OCD': 'TXIO1OCD',
#   'TXLAYAVL': 'TXLAYAVL',
#   'TXLAYLK': 'TXLAYLK',
#   'TXLFS': 'TXLFS',
#   'TXLKAVL': 'TXLKAVL',
#   'TXLKM1': 'TXLKM1',
#   'TXMJOT': 'TXMJOT',
#   'TXRET1': 'TXRET1',
#   'TXSCHENR': 'TXSCHENR',
#   'TXSCHFT': 'TXSCHFT',
#   'TXSCHLVL': 'TXSCHLVL',
#   'TXSPEMPNOT': 'TXSPEMPNOT',
#   'TXSPUHRS': 'TXSPUHRS',
#   'TXTCC': 'TXTCC',
#   'TXTCCTOT': 'TXTCCTOT',
#   'TXTCOC': 'TXTCOC',
#   'TXTHH': 'TXTHH',
#   'TXTNOHH': 'TXTNOHH',
#   'TXTO': 'TXTO',
#   'TXTOHH': 'TXTOHH',
#   'TXTONHH': 'TXTONHH'}}

# %% [markdown]
# #### Handle the issues inside of the weight column

# %%
#create dictionary to assist with renaming columns
(fixed_columns := {
    **original_columns, 
    **{
        path: {
            col: "weight" 
            for col in original_columns.get(path, [])
            if col in ['TU06FWGT', 'TU20FWGT']
            or (col == 'TUFINLWGT' and not any(str(year) in path for year in range(2003, 2006)))
        }
        for path in resp_paths
    }
}
)
# Out:
# {'./data/atusresp_2003.dat': {'TU06FWGT': 'weight'},
#  './data/atusresp_2004.dat': {'TU06FWGT': 'weight'},
#  './data/atusresp_2005.dat': {'TU06FWGT': 'weight'},
#  './data/atusresp_2006.dat': {'TUFINLWGT': 'weight'},
#  './data/atusresp_2007.dat': {'TUFINLWGT': 'weight'},
#  './data/atusresp_2008.dat': {'TUFINLWGT': 'weight'},
#  './data/atusresp_2009.dat': {'TUFINLWGT': 'weight'},
#  './data/atusresp_2010.dat': {'TUFINLWGT': 'weight'},
#  './data/atusresp_2011.dat': {'TUFINLWGT': 'weight'},
#  './data/atusresp_2012.dat': {'TUFINLWGT': 'weight'},
#  './data/atusresp_2013.dat': {'TUFINLWGT': 'weight'},
#  './data/atusresp_2014.dat': {'TUFINLWGT': 'weight'},
#  './data/atusresp_2015.dat': {'TUFINLWGT': 'weight'},
#  './data/atusresp_2017.dat': {'TUFINLWGT': 'weight'},
#  './data/atusresp_2018.dat': {'TUFINLWGT': 'weight'},
#  './data/atusresp_2019.dat': {'TUFINLWGT': 'weight'},
#  './data/atusresp_2020.dat': {'TU20FWGT': 'weight'},
#  './data/atusresp_2021.dat': {'TUFINLWGT': 'weight'},
#  './data/atusresp_2022.dat': {'TUFINLWGT': 'weight'},
#  './data/atusresp_2023.dat': {'TUFINLWGT': 'weight'},
#  './data/atusresp_2024.dat': {'TUFINLWGT': 'weight'},
#  './data/atusresp_2016/atusresp_2016.dat': {'TUFINLWGT': 'weight'}}

# %%
# create an example of what is considered a "correct table schema"
(example_correct_table := pl.read_csv(resp_paths[0],n_rows = 1000,infer_schema_length=10000).head()
)
# Out:
# shape: (5, 157)
# ┌────────┬─────────┬────────────────┬──────────┬───┬──────────┬──────────┬──────────────┬──────────┐
# │ TUYEAR ┆ TUMONTH ┆ TUCASEID       ┆ TULINENO ┆ … ┆ TRTCCTOT ┆ TXERNHRY ┆ TUBWGT       ┆ TU04FWGT │
# │ ---    ┆ ---     ┆ ---            ┆ ---      ┆   ┆ ---      ┆ ---      ┆ ---          ┆ ---      │
# │ i64    ┆ i64     ┆ i64            ┆ i64      ┆   ┆ i64      ┆ i64      ┆ f64          ┆ f64      │
# ╞════════╪═════════╪════════════════╪══════════╪═══╪══════════╪══════════╪══════════════╪══════════╡
# │ 2003   ┆ 1       ┆ 20030100013280 ┆ 1        ┆ … ┆ 0        ┆ 41       ┆ 7848.584109  ┆ 3.7798e6 │
# │ 2003   ┆ 1       ┆ 20030100013344 ┆ 1        ┆ … ┆ 170      ┆ 41       ┆ 7421.117608  ┆ 1.6440e6 │
# │ 2003   ┆ 1       ┆ 20030100013352 ┆ 1        ┆ … ┆ 0        ┆ 0        ┆ 13326.156827 ┆ 3.5759e6 │
# │ 2003   ┆ 1       ┆ 20030100013848 ┆ 1        ┆ … ┆ 715      ┆ -1       ┆ 7595.906825  ┆ 5.0380e6 │
# │ 2003   ┆ 1       ┆ 20030100014165 ┆ 1        ┆ … ┆ 0        ┆ -1       ┆ 4900.934095  ┆ 2.5147e6 │
# └────────┴─────────┴────────────────┴──────────┴───┴──────────┴──────────┴──────────────┴──────────┘

# %%
# pull the int columns from the "correct table"
(int_columns := example_correct_table.select(cs.integer()).columns
)
# Out:
# ['TUYEAR',
#  'TUMONTH',
#  'TUCASEID',
#  'TULINENO',
#  'TUDIARYDATE',
#  'TUDIARYDAY',
#  'TESPEMPNOT',
#  'TRSPFTPT',
#  'TRWERNAL',
#  'TUIO1MFG',
#  'TUDIS1',
#  'TRYHHCHILD',
#  'TRMJIND1',
#  'TRDTOCC1',
#  'TXSPEMPNOT',
#  'TXRET1',
#  'TRIMIND1',
#  'TRDTIND1',
#  'TRMJOCGR',
#  'TXSPUHRS',
#  'TRSPPRES',
#  'TUABSOT',
#  'TUBUS',
#  'TUBUS1',
#  'TUBUS2OT',
#  'TUBUSL1',
#  'TUBUSL2',
#  'TUBUSL3',
#  'TUBUSL4',
#  'TUDIS',
#  'TULAY',
#  'TUFWK',
#  'TURETOT',
#  'TUSPABS',
#  'TUSPUSFT',
#  'TUCC9',
#  'TULAY6M',
#  'TULAYAVR',
#  'TULAYDT',
#  'TULK',
#  'TULKAVR',
#  'TULKM2',
#  'TULKM3',
#  'TULKM4',
#  'TULKM5',
#  'TULKM6',
#  'TULKDK1',
#  'TULKDK2',
#  'TULKDK3',
#  'TULKDK4',
#  'TULKDK5',
#  'TULKDK6',
#  'TULKPS1',
#  'TULKPS2',
#  'TULKPS3',
#  'TULKPS4',
#  'TULKPS5',
#  'TULKPS6',
#  'TUERNH1C',
#  'TUERN2',
#  'TRMJOCC1',
#  'TXTCC',
#  'TXTCOC',
#  'TXABSRSN',
#  'TXMJOT',
#  'TXHRFTPT',
#  'TXHRUSL1',
#  'TXHRUSL2',
#  'TXHRUSLT',
#  'TXIO1OCD',
#  'TXLAYAVL',
#  'TXLAYLK',
#  'TXLKAVL',
#  'TXLKM1',
#  'TXERNH1O',
#  'TXERNHRO',
#  'TXERNPER',
#  'TXERNUOT',
#  'TXERNWKP',
#  'TXERN',
#  'TXERNH2',
#  'TXSCHENR',
#  'TXSCHFT',
#  'TXSCHLVL',
#  'TTOT',
#  'TTWK',
#  'TRHOLIDAY',
#  'TRTSPONLY',
#  'TRTHHFAMILY',
#  'TRTUNMPART',
#  'TEABSRSN',
#  'TEMJOT',
#  'TEHRFTPT',
#  'TEHRUSL1',
#  'TEHRUSL2',
#  'TEHRUSLT',
#  'TEIO1COW',
#  'TEIO1ICD',
#  'TEIO1OCD',
#  'TELAYAVL',
#  'TELAYLK',
#  'TELKAVL',
#  'TELKM1',
#  'TEERNHRO',
#  'TEERNPER',
#  'TEERNUOT',
#  'TEERNWKP',
#  'TEERN',
#  'TEERNH2',
#  'TEERNRT',
#  'TESCHENR',
#  'TESCHFT',
#  'TESCHLVL',
#  'TRTALONE',
#  'TRTSPOUSE',
#  'TRTFAMILY',
#  'TRTCCC',
#  'TRTFRIEND',
#  'TRTOHHCHILD',
#  'TRTONHHCHILD',
#  'TRTNOCHILD',
#  'TRTCHILD',
#  'TELFS',
#  'TXLFS',
#  'TRHERNAL',
#  'TUSPWK',
#  'TUIODP1',
#  'TUIODP2',
#  'TUIODP3',
#  'TTHR',
#  'TXIO1COW',
#  'TXIO1ICD',
#  'TXERNRT',
#  'TRTCC',
#  'TRTCOC',
#  'TEERNHRY',
#  'TRERNWA',
#  'TRERNUPD',
#  'TESPUHRS',
#  'TRDPFTPT',
#  'TERET1',
#  'TUDIS2',
#  'TRHHCHILD',
#  'TRNHHCHILD',
#  'TRCHILDNUM',
#  'TROHHCHILD',
#  'TRTCCTOT',
#  'TXERNHRY']

# %%
# pull the string columns from the "correct table"
(str_columns := example_correct_table.select(cs.string()).columns
)
# Out:
# ['TUCC2', 'TUCC4']

# %%
#combine the int and string columns and map to their type
(col_and_types := {c: pl.String() for c in str_columns
} |    # Merge operator
{c:pl.Int64() for c in int_columns
 if c in respondent_columns  # only cast columns that we need      
}
 )
# Out:
# {'TUCC2': String,
#  'TUCC4': String,
#  'TUYEAR': Int64,
#  'TUCASEID': Int64,
#  'TULINENO': Int64}

# %%
# set the type for the  new weight column.
col_and_types['weight'] = pl.Int64()

# %%
# conduct renaming of columns and handle casting of data types. IT also pulls in each table.

(dfs := [pl.read_csv(p,infer_schema_length=10000)
       .rename(col_rename)
       .select([
            pl.col(c).cast(t)
            for c, t in col_and_types.items()
            if c in respondent_columns  # only cast columns that exist
        ]) for p, col_rename in fixed_columns.items()])
# Out:
# [shape: (20_720, 4)
#  ┌────────┬────────────────┬──────────┬─────────┐
#  │ TUYEAR ┆ TUCASEID       ┆ TULINENO ┆ weight  │
#  │ ---    ┆ ---            ┆ ---      ┆ ---     │
#  │ i64    ┆ i64            ┆ i64      ┆ i64     │
#  ╞════════╪════════════════╪══════════╪═════════╡
#  │ 2003   ┆ 20030100013280 ┆ 1        ┆ 8155462 │
#  │ 2003   ┆ 20030100013344 ┆ 1        ┆ 1735322 │
#  │ 2003   ┆ 20030100013352 ┆ 1        ┆ 3830527 │
#  │ 2003   ┆ 20030100013848 ┆ 1        ┆ 6622022 │
#  │ 2003   ┆ 20030100014165 ┆ 1        ┆ 3068387 │
#  │ …      ┆ …              ┆ …        ┆ …       │
#  │ 2003   ┆ 20031212033591 ┆ 1        ┆ 1731625 │
#  │ 2003   ┆ 20031212033597 ┆ 1        ┆ 3575899 │
#  │ 2003   ┆ 20031212033621 ┆ 1        ┆ 6004256 │
#  │ 2003   ┆ 20031212033636 ┆ 1        ┆ 1402276 │
#  │ 2003   ┆ 20031212033642 ┆ 1        ┆ 6374127 │
#  └────────┴────────────────┴──────────┴─────────┘,
#  shape: (13_973, 4)
#  ┌────────┬────────────────┬──────────┬──────────┐
#  │ TUYEAR ┆ TUCASEID       ┆ TULINENO ┆ weight   │
#  │ ---    ┆ ---            ┆ ---      ┆ ---      │
#  │ i64    ┆ i64            ┆ i64      ┆ i64      │
#  ╞════════╪════════════════╪══════════╪══════════╡
#  │ 2004   ┆ 20040101040003 ┆ 1        ┆ 3158614  │
#  │ 2004   ┆ 20040101040060 ┆ 1        ┆ 6181583  │
#  │ 2004   ┆ 20040101040079 ┆ 1        ┆ 7423105  │
#  │ 2004   ┆ 20040101040080 ┆ 1        ┆ 12133562 │
#  │ 2004   ┆ 20040101040110 ┆ 1        ┆ 9062125  │
#  │ …      ┆ …              ┆ …        ┆ …        │
#  │ 2004   ┆ 20041212042528 ┆ 1        ┆ 10581421 │
#  │ 2004   ┆ 20041212042541 ┆ 1        ┆ 1801375  │
#  │ 2004   ┆ 20041212042547 ┆ 1        ┆ 5311596  │
#  │ 2004   ┆ 20041212042554 ┆ 1        ┆ 2324860  │
#  │ 2004   ┆ 20041212042565 ┆ 1        ┆ 1831027  │
#  └────────┴────────────────┴──────────┴──────────┘,
#  shape: (13_038, 4)
#  ┌────────┬────────────────┬──────────┬──────────┐
#  │ TUYEAR ┆ TUCASEID       ┆ TULINENO ┆ weight   │
#  │ ---    ┆ ---            ┆ ---      ┆ ---      │
#  │ i64    ┆ i64            ┆ i64      ┆ i64      │
#  ╞════════╪════════════════╪══════════╪══════════╡
#  │ 
────┐
#  │ TUYEAR ┆ TUCASEID       ┆ TULINENO ┆ weight  │
#  │ ---    ┆ ---            ┆ ---      ┆ ---     │
#  │ i64    ┆ i64            ┆ i64      ┆ i64     │
#  ╞════════╪════════════════╪══════════╪═════════╡
#  │ 2009   ┆ 20090101090037 ┆ 1        ┆ 9713933 │
#  │ 2009   ┆ 20090101090064 ┆ 1        ┆ 6279975 │
#  │ 2009   ┆ 20090101090070 ┆ 1        ┆ 8349106 │
#  │ 2009   ┆ 20090101090504 ┆ 1        ┆ 2512149 │
#  │ 2009   ┆ 20090101090518 ┆ 1        ┆ 1770271 │
#  │ …      ┆ …              ┆ …        ┆ …       │
#  │ 2009   ┆ 20091212092449 ┆ 1        ┆ 1860348 │
#  │ 2009   ┆ 20091212092471 ┆ 1        ┆ 2887179 │
#  │ 2009   ┆ 20091212092479 ┆ 1        ┆ 6680395 │
#  │ 2009   ┆ 20091212092493 ┆ 1        ┆ 5269192 │
#  │ 2009   ┆ 20091212092496 ┆ 1        ┆ 8474303 │
#  └────────┴────────────────┴──────────┴─────────┘,
#  shape: (13_260, 4)
#  ┌────────┬────────────────┬──────────┬──────────┐
#  │ TUYEAR ┆ TUCASEID       ┆ TULINENO ┆ weight   │
#  │ ---    ┆ ---            ┆ ---      ┆ ---      │
#  │ i64    ┆ i64            ┆ i64      ┆ i64      │
#  ╞════════╪════════════════╪══════════╪══════════╡
#  │ 2010   ┆ 20100101100019 ┆ 1        ┆ 1482765  │
#  │ 2010   ┆ 20100101100020 ┆ 1        ┆ 2771433  │
#  │ 2010   ┆ 20100101100045 ┆ 1        ┆ 17093086 │
#  │ 2010   ┆ 20100101100050 ┆ 1        ┆ 7976843  │
#  │ 2010   ┆ 20100101100053 ┆ 1        ┆ 3661488  │
#  │ …      ┆ …              ┆ …        ┆ …        │
#  │ 2010   ┆ 20101212102483 ┆ 1        ┆ 4267393  │
#  │ 2010   ┆ 20101212102505 ┆ 1        ┆ 6613830  │
#  │ 2010   ┆ 20101212102506 ┆ 1        ┆ 12727688 │
#  │ 2010   ┆ 20101212102516 ┆ 1        ┆ 2185649  │
#  │ 2010   ┆ 20101212102524 ┆ 1        ┆ 1518657  │
#  └────────┴────────────────┴──────────┴──────────┘,
#  shape: (12_479, 4)
#  ┌────────┬────────────────┬──────────┬──────────┐
#  │ TUYEAR ┆ TUCASEID       ┆ TULINENO ┆ weight   │
#  │ ---    ┆ ---            ┆ ---      ┆ ---      │
#  │ i64    ┆ i64            ┆ i64      ┆ i64      │
#  ╞════════╪════════════════╪══════════╪══════════╡
#  │ 2011   ┆ 20110101110010 ┆ 1        ┆ 1418123  │
#  │ 2011   ┆ 20110101110072 ┆ 1        ┆ 8091096  │
#  │ 2011   ┆ 20110101110074 ┆ 1        ┆ 25198135 │
#  │ 2011   ┆ 20110101110081 ┆ 1        ┆ 12544499 │
#  │ 2011   ┆ 20110101110082 ┆ 1        ┆ 6573077  │
#  │ …      ┆ …              ┆ …        ┆ …        │
#  │ 2011   ┆ 20111212112197 ┆ 1        ┆ 41789339 │
#  │ 2011   ┆ 20111212112202 ┆ 1        ┆ 6735858  │
#  │ 2011   ┆ 20111212112235 ┆ 1        ┆ 12915915 │
#  │ 2011   ┆ 20111212112243 ┆ 1        ┆ 7844413  │
#  │ 2011   ┆ 20111212112377 ┆ 1        ┆ 6456710  │
#  └────────┴────────────────┴──────────┴──────────┘,
#  shape: (12_443, 4)
#  ┌────────┬────────────────┬──────────┬─────────┐
#  │ TUYEAR ┆ TUCASEID       ┆ TULINENO ┆ weight  │
#  │ ---    ┆ ---            ┆ ---      ┆ ---     │
#  │ i64    ┆ i64            ┆ i64      ┆ i64     │
#  ╞════════╪════════════════╪══════════╪═════════╡
#  │ 2012   ┆ 20120101120022 ┆ 1        ┆ 5241490 │
#  │ 2012   ┆ 20120101120026 ┆ 1        ┆ 8379003 │
#  │ 2012   ┆ 20120101120032 ┆ 1        ┆ 2383445 │
#  │ 2012   ┆ 20120101120061 ┆ 1        ┆ 9128554 │
#  │ 2012   ┆ 20120101120068 ┆ 1        ┆ 5360439 │
#  │ …      ┆ …              ┆ …        ┆ …       │
│
#  └────────┴────────────────┴──────────┴──────────┘,
#  shape: (8_136, 4)
#  ┌────────┬────────────────┬──────────┬──────────┐
#  │ TUYEAR ┆ TUCASEID       ┆ TULINENO ┆ weight   │
#  │ ---    ┆ ---            ┆ ---      ┆ ---      │
#  │ i64    ┆ i64            ┆ i64      ┆ i64      │
#  ╞════════╪════════════════╪══════════╪══════════╡
#  │ 2022   ┆ 20220101220017 ┆ 1        ┆ 31372411 │
#  │ 2022   ┆ 20220101220500 ┆ 1        ┆ 41333240 │
#  │ 2022   ┆ 20220101220504 ┆ 1        ┆ 5708959  │
#  │ 2022   ┆ 20220101220507 ┆ 1        ┆ 5024633  │
#  │ 2022   ┆ 20220101220552 ┆ 1        ┆ 12479838 │
#  │ …      ┆ …              ┆ …        ┆ …        │
#  │ 2022   ┆ 20221212222086 ┆ 1        ┆ 24180877 │
#  │ 2022   ┆ 20221212222264 ┆ 1        ┆ 14476487 │
#  │ 2022   ┆ 20221212222322 ┆ 1        ┆ 9266696  │
#  │ 2022   ┆ 20221212222359 ┆ 1        ┆ 9239151  │
#  │ 2022   ┆ 20221212222501 ┆ 1        ┆ 7760211  │
#  └────────┴────────────────┴──────────┴──────────┘,
#  shape: (8_548, 4)
#  ┌────────┬────────────────┬──────────┬──────────┐
#  │ TUYEAR ┆ TUCASEID       ┆ TULINENO ┆ weight   │
#  │ ---    ┆ ---            ┆ ---      ┆ ---      │
#  │ i64    ┆ i64            ┆ i64      ┆ i64      │
#  ╞════════╪════════════════╪══════════╪══════════╡
#  │ 2023   ┆ 20230101230035 ┆ 1        ┆ 26705616 │
#  │ 2023   ┆ 20230101230077 ┆ 1        ┆ 3700731  │
#  │ 2023   ┆ 20230101230105 ┆ 1        ┆ 8207137  │
#  │ 2023   ┆ 20230101230522 ┆ 1        ┆ 2654852  │
#  │ 2023   ┆ 20230101230524 ┆ 1        ┆ 13765863 │
#  │ …      ┆ …              ┆ …        ┆ …        │
#  │ 2023   ┆ 20231212232082 ┆ 1        ┆ 3879849  │
#  │ 2023   ┆ 20231212232141 ┆ 1        ┆ 6857398  │
#  │ 2023   ┆ 20231212232214 ┆ 1        ┆ 9022789  │
#  │ 2023   ┆ 20231212232271 ┆ 1        ┆ 8532813  │
#  │ 2023   ┆ 20231212232280 ┆ 1        ┆ 17900855 │
#  └────────┴────────────────┴──────────┴──────────┘,
#  shape: (7_669, 4)
#  ┌────────┬────────────────┬──────────┬──────────┐
#  │ TUYEAR ┆ TUCASEID       ┆ TULINENO ┆ weight   │
#  │ ---    ┆ ---            ┆ ---      ┆ ---      │
#  │ i64    ┆ i64            ┆ i64      ┆ i64      │
#  ╞════════╪════════════════╪══════════╪══════════╡
#  │ 2024   ┆ 20240101240005 ┆ 1        ┆ 18318135 │
#  │ 2024   ┆ 20240101240020 ┆ 1        ┆ 7884307  │
#  │ 2024   ┆ 20240101240098 ┆ 1        ┆ 20930362 │
#  │ 2024   ┆ 20240101240107 ┆ 1        ┆ 6038839  │
#  │ 2024   ┆ 20240101240123 ┆ 1        ┆ 8892221  │
#  │ …      ┆ …              ┆ …        ┆ …        │
#  │ 2024   ┆ 20241212242238 ┆ 1        ┆ 22937529 │
#  │ 2024   ┆ 20241212242273 ┆ 1        ┆ 10272309 │
#  │ 2024   ┆ 20241212242280 ┆ 1        ┆ 5305071  │
#  │ 2024   ┆ 20241212242281 ┆ 1        ┆ 8865700  │
#  │ 2024   ┆ 20241212242303 ┆ 1        ┆ 15279890 │
#  └────────┴────────────────┴──────────┴──────────┘,
#  shape: (10_493, 4)
#  ┌────────┬────────────────┬──────────┬──────────┐
#  │ TUYEAR ┆ TUCASEID       ┆ TULINENO ┆ weight   │
#  │ ---    ┆ ---            ┆ ---      ┆ ---      │
#  │ i64    ┆ i64            ┆ i64      ┆ i64      │
#  ╞════════╪════════════════╪══════════╪══════════╡
#  │ 2016   ┆ 20160101160045 ┆ 1        ┆ 24588650 │
#  │ 2016   ┆ 20160101160066 ┆ 1        ┆ 5445941  │
#  │ 2016   ┆ 20160101160069 ┆ 1        ┆ 8782621  │
#  │ 2016   ┆ 20160101160083 ┆ 1        ┆ 3035909  │
#  │ 2016   ┆ 20160101160084 ┆ 1        ┆ 6978586  │
#  │ …      ┆ …              ┆ …        ┆ …        │
#  │ 2016   ┆ 20161212162307 ┆ 1        ┆ 12958833 │
#  │ 2016   ┆ 20161212162357 ┆ 1        ┆ 4899612  │
#  │ 2016   ┆ 20161212162426 ┆ 1        ┆ 15977916 │
#  │ 2016   ┆ 20161212162456 ┆ 1        ┆ 6280644  │
#  │ 2016   ┆ 20161212162509 ┆ 1        ┆ 14854053 │
#  └────────┴────────────────┴──────────┴──────────┘]

# %%
# Find the common columns between tables
(common_cols := set(dfs[0].columns))
# Out:
# {'TUCASEID', 'TULINENO', 'TUYEAR', 'weight'}

# %%
# remove columns that are not common to each table prior to unioning
for df in dfs[1:]:
    common_cols &= set(df.columns)

# %%
# conduct the union
(resp_combined := pl.concat([df.select(sorted(common_cols)) for df in dfs]))
# Out:
# shape: (252_808, 4)
# ┌────────────────┬──────────┬────────┬──────────┐
# │ TUCASEID       ┆ TULINENO ┆ TUYEAR ┆ weight   │
# │ ---            ┆ ---      ┆ ---    ┆ ---      │
# │ i64            ┆ i64      ┆ i64    ┆ i64      │
# ╞════════════════╪══════════╪════════╪══════════╡
# │ 20030100013280 ┆ 1        ┆ 2003   ┆ 8155462  │
# │ 20030100013344 ┆ 1        ┆ 2003   ┆ 1735322  │
# │ 20030100013352 ┆ 1        ┆ 2003   ┆ 3830527  │
# │ 20030100013848 ┆ 1        ┆ 2003   ┆ 6622022  │
# │ 20030100014165 ┆ 1        ┆ 2003   ┆ 3068387  │
# │ …              ┆ …        ┆ …      ┆ …        │
# │ 20161212162307 ┆ 1        ┆ 2016   ┆ 12958833 │
# │ 20161212162357 ┆ 1        ┆ 2016   ┆ 4899612  │
# │ 20161212162426 ┆ 1        ┆ 2016   ┆ 15977916 │
# │ 20161212162456 ┆ 1        ┆ 2016   ┆ 6280644  │
# │ 20161212162509 ┆ 1        ┆ 2016   ┆ 14854053 │
# └────────────────┴──────────┴────────┴──────────┘

# %% [markdown]
# ## CONDUCT JOINS

# %%
(joined := (rost_combined # joined is the generic data that will be used in both charts.
          .join(resp_combined
                ,on = ["TUCASEID"]
                ,how ="left")
          .join(who_combined 
                  ,on = ["TUCASEID", "TULINENO"]
                  ,how = "left")
          .join(act_combined 
                 ,on = ["TUCASEID", "TUACTIVITY_N"]
                 ,how ="left")
).drop('TUTIER1CODE')
)
# Out:
# shape: (330_539, 10)
# ┌───────┬────────────┬──────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ TESEX ┆ TUCASEID   ┆ TULINENO ┆ TULINENO_r ┆ … ┆ TUACTIVITY ┆ TUACTDUR24 ┆ TUTIER2CO ┆ TUTIER3CO │
# │ ---   ┆ ---        ┆ ---      ┆ ight       ┆   ┆ _N         ┆ ---        ┆ DE        ┆ DE        │
# │ i64   ┆ i64        ┆ i64      ┆ ---        ┆   ┆ ---        ┆ i64        ┆ ---       ┆ ---       │
# │       ┆            ┆          ┆ i64        ┆   ┆ i64        ┆            ┆ i64       ┆ i64       │
# ╞═══════╪════════════╪══════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 2     ┆ 2003010001 ┆ 1        ┆ 1          ┆ … ┆ null       ┆ null       ┆ null      ┆ null      │
# │       ┆ 3344       ┆          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 1     ┆ 2003010001 ┆ 2        ┆ 1          ┆ … ┆ null       ┆ null       ┆ null      ┆ null      │
# │       ┆ 3344       ┆          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 2     ┆ 2003010001 ┆ 1        ┆ 1          ┆ … ┆ 7          ┆ 15         ┆ 1         ┆ 4         │
# │       ┆ 3352       ┆          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 2     ┆ 2003010001 ┆ 1        ┆ 1          ┆ … ┆ 10         ┆ 180        ┆ 2         ┆ 1         │
# │       ┆ 3352       ┆          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 1     ┆ 2003010001 ┆ 2        ┆ 1          ┆ … ┆ 14         ┆ 60         ┆ 2         ┆ 3         │
# │       ┆ 3352       ┆          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ …     ┆ …          ┆ …        ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ 2     ┆ 2016121216 ┆ 1        ┆ 1          ┆ … ┆ 23         ┆ 15         ┆ 9         ┆ 4         │
# │       ┆ 2217       ┆          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 2     ┆ 2016121216 ┆ 1        ┆ 1          ┆ … ┆ 24         ┆ 30         ┆ 9         ┆ 4         │
# │       ┆ 2217       ┆          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 2     ┆ 2016121216 ┆ 1        ┆ 1          ┆ … ┆ 25         ┆ 15         ┆ 9         ┆ 2         │
# │       ┆ 2217       ┆          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 2     ┆ 2016121216 ┆ 1        ┆ 1          ┆ … ┆ 28         ┆ 15         ┆ 1         ┆ 2         │
# │       ┆ 2217       ┆          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 1     ┆ 2016121216 ┆ 2        ┆ 1          ┆ … ┆ null       ┆ null       ┆ null      ┆ null      │
# │       ┆ 2217       ┆          ┆            ┆   ┆            ┆            ┆           ┆           │
# └───────┴────────────┴──────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
# next we will add a few columns that will be needed in both  of our charts in  the next step of the workbook and handle a few renamings.
( final_data := joined
 .with_columns(TUACTDUR24=pl.col('TUACTDUR24').fill_null(0)  
       ,TESEX = pl.when(pl.col('TESEX')==1) #gender recode.
             .then(pl.lit("Male"))
             .when(pl.col('TESEX')==2)
             .then(pl.lit('Female'))
       ,activity_type = pl.when((pl.col('TUTIER2CODE')==1) & (pl.col('TUTIER3CODE')==1)) # activity types recode.
              .then(pl.lit("Interior_Cleaning"))
              .when((pl.col('TUTIER2CODE')==1) & (pl.col('TUTIER3CODE')==2))
              .then(pl.lit('Laundry'))
              .when((pl.col('TUTIER2CODE')==2) & (pl.col('TUTIER3CODE').is_in([1,2,3])))
              .then(pl.lit('Food_Prep_And_Cleanup'))
       ,year = pl.when(pl.col('TUYEAR').is_not_null()) # using to fill any null years.
               .then(pl.col('TUYEAR'))
               .when(pl.col('TUYEAR').is_null())
               .then(pl.col('TUCASEID').cast(pl.Utf8).str.slice(0,4).cast(pl.Int64))
              )
 .rename({'TESEX':'gender','TUACTDUR24':'avg_weighted_duration'})
.drop('TUYEAR')
)
# Out:
# shape: (330_539, 11)
# ┌────────┬─────────────┬──────────┬─────────────┬───┬─────────────┬────────────┬────────────┬──────┐
# │ gender ┆ TUCASEID    ┆ TULINENO ┆ TULINENO_ri ┆ … ┆ TUTIER2CODE ┆ TUTIER3COD ┆ activity_t ┆ year │
# │ ---    ┆ ---         ┆ ---      ┆ ght         ┆   ┆ ---         ┆ E          ┆ ype        ┆ ---  │
# │ str    ┆ i64         ┆ i64      ┆ ---         ┆   ┆ i64         ┆ ---        ┆ ---        ┆ i64  │
# │        ┆             ┆          ┆ i64         ┆   ┆             ┆ i64        ┆ str        ┆      │
# ╞════════╪═════════════╪══════════╪═════════════╪═══╪═════════════╪════════════╪════════════╪══════╡
# │ Female ┆ 20030100013 ┆ 1        ┆ 1           ┆ … ┆ null        ┆ null       ┆ null       ┆ 2003 │
# │        ┆ 344         ┆          ┆             ┆   ┆             ┆            ┆            ┆      │
# │ Male   ┆ 20030100013 ┆ 2        ┆ 1           ┆ … ┆ null        ┆ null       ┆ null       ┆ 2003 │
# │        ┆ 344         ┆          ┆             ┆   ┆             ┆            ┆            ┆      │
# │ Female ┆ 20030100013 ┆ 1        ┆ 1           ┆ … ┆ 1           ┆ 4          ┆ null       ┆ 2003 │
# │        ┆ 352         ┆          ┆             ┆   ┆             ┆            ┆            ┆      │
# │ Female ┆ 20030100013 ┆ 1        ┆ 1           ┆ … ┆ 2           ┆ 1          ┆ Food_Prep_ ┆ 2003 │
# │        ┆ 352         ┆          ┆             ┆   ┆             ┆            ┆ And_Cleanu ┆      │
# │        ┆             ┆          ┆             ┆   ┆             ┆            ┆ p          ┆      │
# │ Male   ┆ 20030100013 ┆ 2        ┆ 1           ┆ … ┆ 2           ┆ 3          ┆ Food_Prep_ ┆ 2003 │
# │        ┆ 352         ┆          ┆             ┆   ┆             ┆            ┆ And_Cleanu ┆      │
# │        ┆             ┆          ┆             ┆   ┆             ┆            ┆ p          ┆      │
# │ …      ┆ …           ┆ …        ┆ …           ┆ … ┆ …           ┆ …          ┆ …          ┆ …    │
# │ Female ┆ 20161212162 ┆ 1        ┆ 1           ┆ … ┆ 9           ┆ 4          ┆ null       ┆ 2016 │
# │        ┆ 217         ┆          ┆             ┆   ┆             ┆            ┆            ┆      │
# │ Female ┆ 20161212162 ┆ 1        ┆ 1           ┆ … ┆ 9           ┆ 4          ┆ null       ┆ 2016 │
# │        ┆ 217         ┆          ┆             ┆   ┆             ┆            ┆            ┆      │
# │ Female ┆ 20161212162 ┆ 1        ┆ 1           ┆ … ┆ 9           ┆ 2          ┆ null       ┆ 2016 │
# │        ┆ 217         ┆          ┆             ┆   ┆             ┆            ┆            ┆      │
# │ Female ┆ 20161212162 ┆ 1        ┆ 1           ┆ … ┆ 1           ┆ 2          ┆ Laundry    ┆ 2016 │
# │        ┆ 217         ┆          ┆             ┆   ┆             ┆            ┆            ┆      │
# │ Male   ┆ 20161212162 ┆ 2        ┆ 1           ┆ … ┆ null        ┆ null       ┆ null       ┆ 2016 │
# │        ┆ 217         ┆          ┆             ┆   ┆             ┆            ┆            ┆      │
# └────────┴─────────────┴──────────┴─────────────┴───┴─────────────┴────────────┴────────────┴──────┘

# %% [markdown]
# ## EXPORT DATA

# %%
(final_data.write_csv('./data/union_joined.csv'))
